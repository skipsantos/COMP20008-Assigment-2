# %%
import numpy as np
import pandas as pd
import nltk
import os
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

for dirname, _, filenames in os.walk('../Data-Files/Raw-Files'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/EODP2/BX-NewBooksRatings.csv
# /content/EODP2/BX-Books.csv
# /content/EODP2/BX-NewBooks.csv
# /content/EODP2/BX-Users.csv
# /content/EODP2/BX-NewBooksUsers.csv
# /content/EODP2/BX-Ratings.csv
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
import re

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer


def load_data(input_path):
    # Load and return all datasets
    ratings = pd.read_csv(os.path.join(input_path, 'BX-Ratings.csv'))
    new_ratings = pd.read_csv(os.path.join(input_path, 'BX-NewBooksRatings.csv'))
    books_old = pd.read_csv(os.path.join(input_path, 'BX-Books.csv'))
    new_books = pd.read_csv(os.path.join(input_path, 'BX-NewBooks.csv'))
    books = pd.concat([books_old, new_books]).drop_duplicates(subset=["Book-Title"], keep='first')
    ratings = pd.concat([ratings, new_ratings])
    return ratings, books

"""Function for age string preprocessing"""
def onlyNumber(age):
  try:
      string_age = str(age)
      cleaned_age = int(re.sub(r'[^0-9]', '', string_age))
      if cleaned_age < 2 or cleaned_age> 123:
        #oldest person in the world is 122 years old and the youngest is 2 years old
          return np.nan
      return cleaned_age
  except:
      return np.nan

def has_special_characters(s):
  s = str(s)
  return any(ord(char) > 127 for char in s)

def abbreviate(s):
  text = s.split()
  new_string = []
  for i in range(len(text)):
      if i < (len(text) - 1):
          new_string.append(text[i][0])
      else:
          new_string.append(text[i])
  return ' '.join(new_string)

# Joins together consecutive single characters in a string
def process_strings(s):
  text = s.split()
  curr = ''
  new_words = []
  # joining together single letters
  for word in text:
      if len(word) == 1:
          curr += word
      else:
          if curr:
              new_words.append(curr)
              curr = ''
          new_words.append(word)

  if curr:
      new_words.append(curr)

  return ' '.join(new_words)

# Preprocesses titles
def title_preprocess(doc, stop_words, lemmatizer):
  doc = str(doc)
  doc = doc.lower()
  # Fixing special cases (periods with no spaces)
  doc_special = re.sub(r'\.(?=\w)', '. ', doc)

  # Removing all punctuation
  doc_punct = re.sub(r'[^A-Za-z0-9\s]', '', doc_special)

  # Remove all instances of 'paperback' in titles
  processed_doc = re.sub(r'paperback\s*', '', doc_punct)

  # Tokenising, removing stop words, then lemmatizing the tokens
  tokens = word_tokenize(processed_doc)
  tokens = [w for w in tokens if not w in stop_words]
  lemmatized = [lemmatizer.lemmatize(w) for w in tokens]

  return ' '.join(lemmatized)

# Preprocesses publishers
def publisher_preprocess(doc, stop_words, lemmatizer):
  doc = doc.lower()
  # Fixing special cases (periods with no spaces)
  doc_special = re.sub(r'\.(?=\w)', '. ', doc)

  # Removing all punctuation
  doc_punct = re.sub(r'[^A-Za-z0-9\s]', '', doc_special)

  # Join single characters (initials)
  doc_joined = process_strings(doc_punct)

  # Removing irrelevant words in publishers
  processed_doc = re.sub(r'\b(?:paperback|books|press|publishing|paperbacks)\b', '', doc_joined)

  # Tokenising, removing stop words, then lemmatizing the tokens
  tokens = word_tokenize(processed_doc)
  tokens = [w for w in tokens if not w in stop_words]
  lemmatized = [lemmatizer.lemmatize(w) for w in tokens]
  return ' '.join(lemmatized)

def prepare_data(books):

    # Filter out all non ASCII characters
    books = books[~books['Book-Title'].apply(has_special_characters)]
    books = books[~books['Book-Author'].apply(has_special_characters)]
    books = books[~books['Book-Publisher'].apply(has_special_characters)]

    # Book Title preprocessing steps
    # Initialising lemmatizer, stopwords, and tfidf
    lemmatizer = WordNetLemmatizer()
    stop_words = set(stopwords.words('english'))

    processed_titles = []
    for i, title in enumerate(books['Book-Title']):
        processed_titles.append(title_preprocess(title, stop_words,lemmatizer))
    books['Title-Tokens'] = [word_tokenize(t) for t in processed_titles]

    # Author preprocessing steps
    # Setting all author names to lowercase
    books['Book-Author'] = books['Book-Author'].astype(str)
    books['Book-Author'] = books['Book-Author'].apply(lambda x: x.lower())

    # Fixing special cases (periods with no spaces)
    author_special = books['Book-Author'].apply(lambda x: re.sub(r'\.(?=\w)', '. ', x))

    # Removing All punctuations
    author_punct = author_special.apply(lambda x: re.sub(r'[^A-Za-z\s]', '', x))

    # Abbreviating then joining together single letters into one word (for name initials)
    books['Book-Author'] = author_punct.apply(abbreviate)
    books['Book-Author'] = books['Book-Author'].apply(process_strings)
    books['Author-Tokens'] = books['Book-Author'].apply(word_tokenize)

    # Publishing Year Preprocessing Steps
    # Convert all years outside plausible range to 0
    books.loc[~books['Year-Of-Publication'].between(1920, 2005), 'Year-Of-Publication'] = 0
    filtered_books = books[books['Year-Of-Publication'] != 0]

    # Get average year of publication for each author
    publish_years = filtered_books.groupby('Book-Author')['Year-Of-Publication'].mean().reset_index()

    # Replace 0 values with corresponding author mean
    books = books.merge(publish_years, on='Book-Author', suffixes=('', '_mean'))
    books['Year-Of-Publication'] = books.apply(lambda row: row['Year-Of-Publication_mean']
        if row['Year-Of-Publication'] == 0 else row['Year-Of-Publication'], axis=1)

    books['Year-Of-Publication'] = books['Year-Of-Publication'].astype(int)
    books.drop(columns='Year-Of-Publication_mean', inplace=True)

    # Publisher Preprocessing Steps
    processed_publishers = []
    for i, title in enumerate(books['Book-Publisher']):
        processed_publishers.append(publisher_preprocess(title, stop_words,lemmatizer))

    books['Publisher-Tokens'] = books['Book-Publisher'].apply(word_tokenize)
    return books.drop_duplicates(subset=["Book-Title"], keep='first').dropna()

def combine_tokens(books):

    tokens = ["Year-Of-Publication-Tokens","Title-Tokens", "Author-Tokens", "Publisher-Tokens"]
    books["Year-Of-Publication-Tokens"] = books["Year-Of-Publication"].astype(str).apply(lambda x: [x])

    # Combine the token arrays from different columns into a single array
    books['Combined-Tokens'] = books[tokens].apply(lambda x: np.concatenate(x), axis=1)

    # Create a new DataFrame with 'ISBN' and 'Combined-Tokens' columns
    df_tokens = books[['ISBN', 'Combined-Tokens']]
    return df_tokens

def prepare_tfidf(books):

    df_tokens = combine_tokens(books)

    # Apply TF-IDF vectorization to the combined token column
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_matrix = tfidf_vectorizer.fit_transform(df_tokens['Combined-Tokens'].apply(lambda x: ' '.join(x)))

    # Create a DataFrame with TF-IDF values and 'ISBN' as the index
    df_tfidf = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out(), index=df_tokens['ISBN'])
    return df_tfidf

def prepare_vector(books):

    df_tokens = combine_tokens(books)
    cv = CountVectorizer(max_features=500, stop_words="english")
    vectors_matrix = cv.fit_transform(df_tokens["Combined-Tokens"].apply(lambda x: ' '.join(x)))
    df_vector = pd.DataFrame(vectors_matrix.toarray(), columns=cv.get_feature_names_out(), index=df_tokens['ISBN'])

    return df_vector

def find_similar_books(book_id, books, vector, recommend_number = 5):
    # Calculate similarity and find similar books

    similarity = cosine_similarity(vector)
    try:
        book_idx = books.index[books['ISBN'] == book_id].tolist()[0]
        #default is set at recommending 10 books this value will also affect predicted rating
        similar_books = sorted(list(enumerate(similarity[book_idx])), key=lambda x: x[1], reverse=True)[1:recommend_number]

        return similar_books

    except IndexError:
        print("Book ID not found in dataset.")

        return []

def recommend_books_vector(ratings, books, similar_books):
    # predicting books rating based on the cosine similarity scores of the vector based word processing

    rating_sims = []
    for idx, sim_score in similar_books:
        similar_isbn = books.iloc[idx]['ISBN']
        if similar_isbn in books['ISBN'].values:
            book_title = books.iloc[idx]['Book-Title']
            book_author = books.iloc[idx]['Book-Author']
            isbn_ratings = ratings[ratings["ISBN"] == similar_isbn]
            book_year = books.iloc[idx]['Year-Of-Publication']
            book_publisher = books.iloc[idx]['Book-Publisher']
            if not isbn_ratings.empty:
                mean_rating = isbn_ratings['Book-Rating'].mean()
                adjusted_score = mean_rating * sim_score
                rating_sims.append(float(adjusted_score))
    if rating_sims:
        average_adjusted_score = sum(rating_sims) / len(rating_sims)
        print(f"\nPredicted Rating: {average_adjusted_score:.2f}")

        return average_adjusted_score

def recommend_books_tfidf(ratings, books, similar_books):
    # Recommend books based on the cosine similarity scores of the tfidf based word processing

    for idx, sim_score in similar_books:
        similar_isbn = books.iloc[idx]['ISBN']
        if similar_isbn in books['ISBN'].values:
            book_title = books.iloc[idx]['Book-Title']
            book_author = books.iloc[idx]['Book-Author']
            isbn_ratings = ratings[ratings["ISBN"] == similar_isbn]
            book_year = books.iloc[idx]['Year-Of-Publication']
            book_publisher = books.iloc[idx]['Book-Publisher']
            if not isbn_ratings.empty:
                print(f"{book_title} by {book_author} published in {book_year} by {book_publisher}")

def recommend( wanted_book,books,ratings, recommend_state = False):
    print("\nChoosen book: ",wanted_book)
    added_books = pd.concat([books,wanted_book])
    books = prepare_data(added_books)

    print("\nPreprocessed data finished\n")
    wanted_ISBN = wanted_book.iloc[0]['ISBN']

    #These section is for the rating prediction
    vector = prepare_vector(books)
    print("Vectorized data finished\n")

    similar_books_vector = find_similar_books(wanted_ISBN, books, vector)

    # These section is for recommendation section
    if recommend_state:
      tfidf_books = prepare_data(added_books)
      tfidf = prepare_tfidf(tfidf_books)
      similar_books_tfidf = find_similar_books(wanted_ISBN, tfidf_books, tfidf)
    print("Find Similarity finished\n")

    if similar_books_vector:
        #this section will calculate and return the recommend books

        if recommend_state:
          print("\nRecommend Book\n")
          recommend_books_tfidf(ratings, tfidf_books, similar_books_tfidf)

        #this section will calculate and return the predicted value
        return recommend_books_vector(ratings, books, similar_books_vector)

"""This is the recommendation model that use cosine similarity to recommend
    book based on the user input book which it will give the predicted rating
    and give recommending books based on the tfidf vector. The recommend functionality
    is very computing intensive so it is set as False by default. However you can
    try and run it with the recommend_state = True like the following cell.
    """
def RecommendationSystem(wanted_book,books,ratings,recommend_state =False):

    return recommend(wanted_book,books,ratings,recommend_state)

# %%
#Please don't forget to provide the file path to the load_data
ratings, books = load_data('../../Data-Files/Raw-Files')
#It also recommend to run this program in cloud based ipynb as it is very computing intensive
#Our group use the kaggle and Google Colab to run these and the setting is cpu runtime type with high-ram
#if using the free version it will not run as it exceed googlecolab ram limit
RecommendationSystem((pd.DataFrame({'ISBN': ['0425163091'],
                                    'Book-Title': ['Chocolate Jesus'],
                                    'Book-Author': ['s jaramillo'],
                                    'Year-Of-Publication': [1998],
                                    'Book-Publisher': ['Berkley Publishing Group']})),
                     books,ratings,recommend_state =True)
# Out:
# Choosen book:           ISBN       Book-Title  Book-Author  Year-Of-Publication  \
# 0  0425163091  Chocolate Jesus  s jaramillo                 1998
#
#              Book-Publisher
# 0  Berkley Publishing Group
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Recommend Book
#
# Chocolate Quake by n fairbanks published in 2003 by Berkley Publishing Group
# Jesus Freaks: DC Talk and The Voice of the Martyrs - Stories of Those Who Stood For Jesus, the Ultimate Jesus Freaks by d talk published in 1999 by Bethany House Publishers
# Here on Earth by a hoffman published in 1998 by Berkley Publishing Group
# N or M? by a christie published in 1996 by Berkley Publishing Group
#
# Predicted Rating: 6.36
# 6.360266135096248

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
def delete_records_by_isbn(df, isbn):
    #Function for making train data set by delete the test data set out off the dataframe

    isbn_set = set(isbn['ISBN'])
    mask = (df['ISBN'].apply(lambda x: x not in isbn_set))
    updated_df = df[mask]
    return updated_df

def select_random_data(df, percentage):
    # Function for sampling a percentage of the dataframe using for test dataset

    return df.sample(n=int(len(df) * percentage))

def evaluate_model(percentage = 0.001): # this is fractional percentage 0.001 mean 0.1%
  #This function will evaluate the model which use mse, rmse, mae and r2 for evaluation
  ratings, books = load_data('../../Data-Files/Raw-Files')
  books = prepare_data(books)
  test_books = select_random_data(books,percentage)
  train_books = delete_records_by_isbn(books,test_books)
  train_ratings = delete_records_by_isbn(ratings,test_books)
  test_rating = ratings.groupby('ISBN')['Book-Rating'].mean().reset_index()
  test_rating.rename(columns={'Book-Rating': 'Avg-Book-Rating'}, inplace=True)
  test_rating = pd.merge(test_books,test_rating,on ="ISBN")
  pred_rate = []

  # Print the recommendations for each book
  for _, row in test_books.iterrows():
    row = (pd.DataFrame(row)).transpose()
    pred_rate.append(RecommendationSystem(row, train_books, train_ratings))
  #linear_rating = ratings.groupby('ISBN')['Book-Rating'].mean().reset_index()
  mse = mean_squared_error(test_rating['Avg-Book-Rating'], pred_rate)
  rmse = np.sqrt(mse)
  mae = mean_absolute_error(test_rating['Avg-Book-Rating'], pred_rate)
  r2 = r2_score(test_rating['Avg-Book-Rating'], pred_rate)
  print(f"R-squared: {r2:.2f}")
  print(f"Mean Squared Error: {mse:.2f}")
  print(f"Root Mean Squared Error: {rmse:.2f}")
  print(f"Mean Absolute Error: {mae:.2f}")

# %%
evaluate_model()
# Out:
# Choosen book:               ISBN                      Book-Title Book-Author  \
# 14739  0671769944  Sanctuary (Star Trek, Book 61)  j vornholt
#
#       Year-Of-Publication Book-Publisher                       Title-Tokens  \
# 14739                1992      Star Trek  [sanctuary, star, trek, book, 61]
#
#        Author-Tokens Publisher-Tokens
# 14739  [j, vornholt]     [Star, Trek]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.52
#
# Choosen book:              ISBN                       Book-Title  Book-Author  \
# 1104  0061000035  The Dark Wind (Jim Chee Novels)  t hillerman
#
#      Year-Of-Publication Book-Publisher                    Title-Tokens  \
# 1104                1990    HarperTorch  [dark, wind, jim, chee, novel]
#
#        Author-Tokens Publisher-Tokens
# 1104  [t, hillerman]    [HarperTorch]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.91
#
# Choosen book:              ISBN                                   Book-Title Book-Author  \
# 7674  0836278445  Don'T Step In The Leadership:A Dilbert Book     s adams
#
#      Year-Of-Publication             Book-Publisher  \
# 7674                1999  Andrews McMeel Publishing
#
#                                   Title-Tokens Author-Tokens  \
# 7674  [dont, step, leadershipa, dilbert, book]    [s, adams]
#
#                    Publisher-Tokens
# 7674  [Andrews, McMeel, Publishing]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.75
#
# Choosen book:               ISBN                                         Book-Title  \
# 16257  0312975376  Large Target : A Josephine Fuller Mystery (A J...
#
#       Book-Author Year-Of-Publication           Book-Publisher  \
# 16257    l murray                2001  St. Martin's Paperbacks
#
#                                             Title-Tokens Author-Tokens  \
# 16257  [large, target, josephine, fuller, mystery, jo...   [l, murray]
#
#                     Publisher-Tokens
# 16257  [St., Martin, 's, Paperbacks]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.75
#
# Choosen book:               ISBN           Book-Title Book-Author Year-Of-Publication  \
# 17862  0307021491  Alice in Wonderland    j werner                1920
#
#       Book-Publisher         Title-Tokens Author-Tokens Publisher-Tokens
# 17862   Golden Books  [alice, wonderland]   [j, werner]  [Golden, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.60
#
# Choosen book:               ISBN                                Book-Title Book-Author  \
# 21362  0373030967  High Heaven (Harlequin Romance, No 3096)    q wilder
#
#       Year-Of-Publication Book-Publisher  \
# 21362                1990      Harlequin
#
#                                    Title-Tokens Author-Tokens Publisher-Tokens
# 21362  [high, heaven, harlequin, romance, 3096]   [q, wilder]      [Harlequin]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.67
#
# Choosen book:            ISBN   Book-Title Book-Author Year-Of-Publication   Book-Publisher  \
# 94  0375406328  Lying Awake   m salzman                2000  Alfred A. Knopf
#
#       Title-Tokens Author-Tokens     Publisher-Tokens
# 94  [lying, awake]  [m, salzman]  [Alfred, A., Knopf]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.14
#
# Choosen book:              ISBN           Book-Title Book-Author Year-Of-Publication  \
# 5733  0743506669  Shopgirl Unabridged    s martin                2000
#
#      Book-Publisher            Title-Tokens Author-Tokens Publisher-Tokens
# 5733     Audioworks  [shopgirl, unabridged]   [s, martin]     [Audioworks]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.27
#
# Choosen book:              ISBN                   Book-Title Book-Author Year-Of-Publication  \
# 6053  1400033543  You Shall Know Our Velocity    d eggers                2003
#
#      Book-Publisher             Title-Tokens Author-Tokens Publisher-Tokens
# 6053        Vintage  [shall, know, velocity]   [d, eggers]        [Vintage]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.36
#
# Choosen book:               ISBN                                         Book-Title  \
# 11399  0375727019  The Elementary Particles (Vintage Internationa...
#
#          Book-Author Year-Of-Publication     Book-Publisher  \
# 11399  m houellebecq                2001  Vintage Books USA
#
#                                          Title-Tokens     Author-Tokens  \
# 11399  [elementary, particle, vintage, international]  [m, houellebecq]
#
#             Publisher-Tokens
# 11399  [Vintage, Books, USA]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.12
#
# Choosen book:              ISBN      Book-Title Book-Author Year-Of-Publication  \
# 5172  0553298178  Garden of Rama   ac clarke                1992
#
#      Book-Publisher    Title-Tokens Author-Tokens Publisher-Tokens
# 5172         Bantam  [garden, rama]  [ac, clarke]         [Bantam]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.84
#
# Choosen book:               ISBN                              Book-Title Book-Author  \
# 19667  088001380X  Worshipful Company of Fletchers: Poems      j tate
#
#       Year-Of-Publication       Book-Publisher  \
# 19667                1994  W W Norton & Co Inc
#
#                                 Title-Tokens Author-Tokens  \
# 19667  [worshipful, company, fletcher, poem]     [j, tate]
#
#                  Publisher-Tokens
# 19667  [W, W, Norton, &, Co, Inc]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.02
#
# Choosen book:              ISBN                                         Book-Title  \
# 5646  0375702709  A Lesson Before Dying (Vintage Contemporaries ...
#
#      Book-Author Year-Of-Publication     Book-Publisher  \
# 5646   ej gaines                1997  Vintage Books USA
#
#                                 Title-Tokens Author-Tokens  \
# 5646  [lesson, dying, vintage, contemporary]  [ej, gaines]
#
#            Publisher-Tokens
# 5646  [Vintage, Books, USA]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.03
#
# Choosen book:               ISBN                                         Book-Title  \
# 12187  0743474325  Speaks the Nightbird, Volume I : Judgment of t...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 12187  r mccammon                2003   Pocket Books
#
#                                        Title-Tokens  Author-Tokens  \
# 12187  [speaks, nightbird, volume, judgment, witch]  [r, mccammon]
#
#       Publisher-Tokens
# 12187  [Pocket, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.65
#
# Choosen book:               ISBN                                         Book-Title  \
# 11830  0060193395  Body for Life: 12 Weeks to Mental and Physical...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 11830  b phillips                1999  HarperCollins
#
#                                             Title-Tokens  Author-Tokens  \
# 11830  [body, life, 12, week, mental, physical, stren...  [b, phillips]
#
#       Publisher-Tokens
# 11830  [HarperCollins]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.03
#
# Choosen book:               ISBN                                         Book-Title  \
# 22308  037327209X  TAMING JESSE JAMES - OUTLAW HARTES (Silhouette...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 22308    r thayne                2002     Silhouette
#
#                                             Title-Tokens Author-Tokens  \
# 22308  [taming, jesse, james, outlaw, harte, silhouet...   [r, thayne]
#
#       Publisher-Tokens
# 22308     [Silhouette]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.11
#
# Choosen book:               ISBN          Book-Title Book-Author Year-Of-Publication  \
# 13710  0440413729  Belle Prater's Boy     r white                1998
#
#       Book-Publisher          Title-Tokens Author-Tokens Publisher-Tokens
# 13710       Yearling  [belle, prater, boy]    [r, white]       [Yearling]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.92
#
# Choosen book:               ISBN  Book-Title  Book-Author Year-Of-Publication Book-Publisher  \
# 14610  044921852X  Angel Eyes  e lustbader                1993  Fawcett Books
#
#        Title-Tokens   Author-Tokens  Publisher-Tokens
# 14610  [angel, eye]  [e, lustbader]  [Fawcett, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.97
#
# Choosen book:              ISBN    Book-Title   Book-Author Year-Of-Publication  \
# 2398  0671024183  Morgan's Run  c mccullough                2002
#
#      Book-Publisher   Title-Tokens    Author-Tokens Publisher-Tokens
# 2398         Pocket  [morgan, run]  [c, mccullough]         [Pocket]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.61
#
# Choosen book:               ISBN                     Book-Title Book-Author  \
# 15374  0380716984  Amelia Bedelia's Family Album    p parish
#
#       Year-Of-Publication                Book-Publisher  \
# 15374                1994  Harpercollins Juvenile Books
#
#                             Title-Tokens Author-Tokens  \
# 15374  [amelia, bedelias, family, album]   [p, parish]
#
#                        Publisher-Tokens
# 15374  [Harpercollins, Juvenile, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.74
#
# Choosen book:               ISBN  Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 20550  0446610941  Misfortune     n geary                2002   Warner Books
#
#        Title-Tokens Author-Tokens Publisher-Tokens
# 20550  [misfortune]    [n, geary]  [Warner, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.14
#
# Choosen book:               ISBN                                         Book-Title  \
# 22348  0393313425  Sudden Fiction (Continued): 60 New Short-Short...
#
#       Book-Author Year-Of-Publication          Book-Publisher  \
# 22348   r shapard                1996  W. W. Norton & Company
#
#                                             Title-Tokens Author-Tokens  \
# 22348  [sudden, fiction, continued, 60, new, shortsho...  [r, shapard]
#
#                    Publisher-Tokens
# 22348  [W., W., Norton, &, Company]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.53
#
# Choosen book:              ISBN             Book-Title Book-Author Year-Of-Publication  \
# 4630  0446400718  Piper On the Mountain    e peters                1996
#
#      Book-Publisher       Title-Tokens Author-Tokens Publisher-Tokens
# 4630   Warner Books  [piper, mountain]   [e, peters]  [Warner, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.19
# R-squared: -5.43
# Mean Squared Error: 3.16
# Root Mean Squared Error: 1.78
# Mean Absolute Error: 1.55

# %%
evaluate_model(0.01)
# Out:
# Choosen book:               ISBN                                         Book-Title  \
# 10734  0373223188  Till Death Us Do Part (43 Light St.) (Harlequi...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 10734      r york                1995      Harlequin
#
#                                             Title-Tokens Author-Tokens  \
# 10734  [till, death, u, part, 43, light, st, harlequi...     [r, york]
#
#       Publisher-Tokens
# 10734      [Harlequin]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.13
#
# Choosen book:               ISBN                                 Book-Title Book-Author  \
# 14279  0486266842  Turn of the Screw (Dover Thrift Editions)     h james
#
#       Year-Of-Publication      Book-Publisher  \
# 14279                1991  Dover Publications
#
#                                 Title-Tokens Author-Tokens  \
# 14279  [turn, screw, dover, thrift, edition]    [h, james]
#
#             Publisher-Tokens
# 14279  [Dover, Publications]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.32
#
# Choosen book:               ISBN                                         Book-Title  \
# 23330  0679769560  Different Loving: The World of Sexual Dominanc...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 23330    gg brame                1996  Villard Books
#
#                                             Title-Tokens Author-Tokens  \
# 23330  [different, loving, world, sexual, dominance, ...   [gg, brame]
#
#        Publisher-Tokens
# 23330  [Villard, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.07
#
# Choosen book:               ISBN                                        Book-Title  \
# 13213  037570745X  In the Fall (Vintage Contemporaries (Paperback))
#
#       Book-Author Year-Of-Publication     Book-Publisher  \
# 13213      j lent                2001  Vintage Books USA
#
#                         Title-Tokens Author-Tokens       Publisher-Tokens
# 13213  [fall, vintage, contemporary]     [j, lent]  [Vintage, Books, USA]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.66
#
# Choosen book:              ISBN                                      Book-Title Book-Author  \
# 6524  0525943749  Son of Rosemary: The Sequel to Rosemary's Baby     i levin
#
#      Year-Of-Publication Book-Publisher  \
# 6524                1997    Penguin USA
#
#                                  Title-Tokens Author-Tokens Publisher-Tokens
# 6524  [son, rosemary, sequel, rosemary, baby]    [i, levin]   [Penguin, USA]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.60
#
# Choosen book:              ISBN           Book-Title  Book-Author Year-Of-Publication  \
# 8249  0061057363  Ruins (The X-Files)  kj anderson                1997
#
#            Book-Publisher    Title-Tokens   Author-Tokens  \
# 8249  HarperEntertainment  [ruin, xfiles]  [kj, anderson]
#
#            Publisher-Tokens
# 8249  [HarperEntertainment]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.25
#
# Choosen book:              ISBN       Book-Title   Book-Author Year-Of-Publication  \
# 1561  034538184X  Degree of Guilt  rn patterson                1995
#
#         Book-Publisher     Title-Tokens    Author-Tokens     Publisher-Tokens
# 1561  Ballantine Books  [degree, guilt]  [rn, patterson]  [Ballantine, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.45
#
# Choosen book:              ISBN                                         Book-Title  \
# 6829  0312205481  A Fine and Bitter Snow : A Kate Shugak Novel (...
#
#      Book-Author Year-Of-Publication         Book-Publisher  \
# 6829  d stabenow                2002  St. Martin's Minotaur
#
#                                            Title-Tokens  Author-Tokens  \
# 6829  [fine, bitter, snow, kate, shugak, novel, kate...  [d, stabenow]
#
#                  Publisher-Tokens
# 6829  [St., Martin, 's, Minotaur]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.84
#
# Choosen book:              ISBN        Book-Title Book-Author Year-Of-Publication  \
# 8684  0380751399  Taking the Fifth    ja jance                1987
#
#      Book-Publisher     Title-Tokens Author-Tokens Publisher-Tokens
# 8684           Avon  [taking, fifth]   [ja, jance]           [Avon]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.46
#
# Choosen book:               ISBN  Book-Title   Book-Author Year-Of-Publication  \
# 22317  0452284368  Fresh Eggs  r levandoski                2003
#
#       Book-Publisher  Title-Tokens    Author-Tokens Publisher-Tokens
# 22317    Plume Books  [fresh, egg]  [r, levandoski]   [Plume, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.58
#
# Choosen book:               ISBN                                         Book-Title  \
# 14866  0440415829  Piping Down the Valleys Wild: Poetry for the Y...
#
#       Book-Author Year-Of-Publication  Book-Publisher  \
# 14866   n larrick                1999  Yearling Books
#
#                                      Title-Tokens Author-Tokens  \
# 14866  [piping, valley, wild, poetry, young, age]  [n, larrick]
#
#         Publisher-Tokens
# 14866  [Yearling, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.26
#
# Choosen book:               ISBN           Book-Title Book-Author Year-Of-Publication  \
# 19210  0918273838  Donald Duk: A Novel      f chin                1991
#
#            Book-Publisher          Title-Tokens Author-Tokens  \
# 19210  Coffee House Press  [donald, duk, novel]     [f, chin]
#
#              Publisher-Tokens
# 19210  [Coffee, House, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.86
#
# Choosen book:              ISBN       Book-Title Book-Author Year-Of-Publication  \
# 8736  0671034057  Now You See Her    l howard                1999
#
#      Book-Publisher Title-Tokens Author-Tokens Publisher-Tokens
# 8736   Pocket Books        [see]   [l, howard]  [Pocket, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.18
#
# Choosen book:               ISBN                  Book-Title Book-Author Year-Of-Publication  \
# 18421  0451181948  Midnight Is a Lonely Place   b erskine                1995
#
#       Book-Publisher               Title-Tokens Author-Tokens Publisher-Tokens
# 18421    Signet Book  [midnight, lonely, place]  [b, erskine]   [Signet, Book]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.70
#
# Choosen book:               ISBN        Book-Title Book-Author Year-Of-Publication  \
# 10862  0821772279  Realm of Shadows     s drake                2002
#
#                           Book-Publisher     Title-Tokens Author-Tokens  \
# 10862  Kensington Publishing Corporation  [realm, shadow]    [s, drake]
#
#                             Publisher-Tokens
# 10862  [Kensington, Publishing, Corporation]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.14
#
# Choosen book:               ISBN                                         Book-Title  \
# 20723  0385242719  Labyrinths of Reason : Paradox, Puzzles, and t...
#
#         Book-Author Year-Of-Publication Book-Publisher  \
# 20723  w poundstone                1989         Anchor
#
#                                             Title-Tokens    Author-Tokens  \
# 20723  [labyrinth, reason, paradox, puzzle, frailty, ...  [w, poundstone]
#
#       Publisher-Tokens
# 20723         [Anchor]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.78
#
# Choosen book:              ISBN            Book-Title Book-Author Year-Of-Publication  \
# 3127  0440102804  The Anodyne Necklace    m grimes                1990
#
#      Book-Publisher         Title-Tokens Author-Tokens Publisher-Tokens
# 3127           Dell  [anodyne, necklace]   [m, grimes]           [Dell]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.35
#
# Choosen book:               ISBN  Book-Title  Book-Author Year-Of-Publication Book-Publisher  \
# 18428  1551668386  Conspiracy  j cresswell                2001           Mira
#
#        Title-Tokens   Author-Tokens Publisher-Tokens
# 18428  [conspiracy]  [j, cresswell]           [Mira]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.65
#
# Choosen book:              ISBN            Book-Title Book-Author Year-Of-Publication  \
# 9143  0380802929  The Runaway Princess      c dodd                1999
#
#      Book-Publisher         Title-Tokens Author-Tokens Publisher-Tokens
# 9143           Avon  [runaway, princess]     [c, dodd]           [Avon]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.06
#
# Choosen book:              ISBN                                       Book-Title  \
# 3892  0446519138  Simple Abundance:  A Daybook of Comfort and Joy
#
#         Book-Author Year-Of-Publication Book-Publisher  \
# 3892  sb breathnach                1995   Warner Books
#
#                                     Title-Tokens     Author-Tokens  \
# 3892  [simple, abundance, daybook, comfort, joy]  [sb, breathnach]
#
#      Publisher-Tokens
# 3892  [Warner, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.14
#
# Choosen book:               ISBN                                         Book-Title  \
# 20019  0060609176  Meeting Jesus Again for the First Time : The H...
#
#       Book-Author Year-Of-Publication      Book-Publisher  \
# 20019     mj borg                1995  HarperSanFrancisco
#
#                                             Title-Tokens Author-Tokens  \
# 20019  [meeting, jesus, first, time, historical, jesu...    [mj, borg]
#
#            Publisher-Tokens
# 20019  [HarperSanFrancisco]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.41
#
# Choosen book:               ISBN                               Book-Title Book-Author  \
# 22484  0789306794  Feng Sh T: The Art of Domestic Disorder   a crosbie
#
#       Year-Of-Publication            Book-Publisher  \
# 22484                2002  Universe Publishing (NY)
#
#                               Title-Tokens Author-Tokens  \
# 22484  [feng, sh, art, domestic, disorder]  [a, crosbie]
#
#                        Publisher-Tokens
# 22484  [Universe, Publishing, (, NY, )]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.73
#
# Choosen book:              ISBN                                         Book-Title  \
# 2020  1853263974  Collected Works of Oscar Wilde: The Plays, the...
#
#      Book-Author Year-Of-Publication                       Book-Publisher  \
# 2020     o wilde                1998  NTC/Contemporary Publishing Company
#
#                                            Title-Tokens Author-Tokens  \
# 2020  [collected, work, oscar, wilde, play, poem, st...    [o, wilde]
#
#                              Publisher-Tokens
# 2020  [NTC/Contemporary, Publishing, Company]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.69
#
# Choosen book:               ISBN        Book-Title Book-Author Year-Of-Publication  \
# 23275  8420447625  Noche De Viernes    j sierra                1995
#
#                   Book-Publisher          Title-Tokens Author-Tokens  \
# 23275  Santillana USA Pub Co Inc  [noche, de, viernes]   [j, sierra]
#
#                       Publisher-Tokens
# 23275  [Santillana, USA, Pub, Co, Inc]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.76
#
# Choosen book:               ISBN          Book-Title Book-Author Year-Of-Publication  \
# 19753  0393045358  How the Mind Works    s pinker                1997
#
#             Book-Publisher  Title-Tokens Author-Tokens  \
# 19753  W W Norton & Co Inc  [mind, work]   [s, pinker]
#
#                  Publisher-Tokens
# 19753  [W, W, Norton, &, Co, Inc]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.00
#
# Choosen book:              ISBN                          Book-Title Book-Author  \
# 9406  069401236X  A Little Princess (Book and Charm)  fh burnett
#
#      Year-Of-Publication  Book-Publisher                     Title-Tokens  \
# 9406                1999  HarperFestival  [little, princess, book, charm]
#
#       Author-Tokens  Publisher-Tokens
# 9406  [fh, burnett]  [HarperFestival]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.43
#
# Choosen book:              ISBN                                         Book-Title  \
# 4894  039480029X  Hop on Pop (I Can Read It All by Myself Beginn...
#
#      Book-Author Year-Of-Publication                        Book-Publisher  \
# 4894     d seuss                1963  Random House Books for Young Readers
#
#                           Title-Tokens Author-Tokens  \
# 4894  [hop, pop, read, beginner, book]    [d, seuss]
#
#                                  Publisher-Tokens
# 4894  [Random, House, Books, for, Young, Readers]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.98
#
# Choosen book:              ISBN           Book-Title Book-Author Year-Of-Publication  \
# 6103  0060002077  A Gentleman's Honor   s laurens                2003
#
#      Book-Publisher        Title-Tokens Author-Tokens Publisher-Tokens
# 6103     Avon Books  [gentleman, honor]  [s, laurens]    [Avon, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.38
#
# Choosen book:               ISBN                               Book-Title Book-Author  \
# 22789  0962713708  Pearl and Bead Stringing With Henrietta  h virchick
#
#       Year-Of-Publication           Book-Publisher  \
# 22789                1990  Linecraft, Incorporated
#
#                               Title-Tokens  Author-Tokens  \
# 22789  [pearl, bead, stringing, henrietta]  [h, virchick]
#
#                    Publisher-Tokens
# 22789  [Linecraft, ,, Incorporated]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 8.72
#
# Choosen book:               ISBN      Book-Title Book-Author Year-Of-Publication  \
# 20432  0500280673  Celtic Borders    a meehan                1999
#
#         Book-Publisher      Title-Tokens Author-Tokens     Publisher-Tokens
# 20432  Thames & Hudson  [celtic, border]   [a, meehan]  [Thames, &, Hudson]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.49
#
# Choosen book:               ISBN     Book-Title Book-Author Year-Of-Publication  \
# 14473  0684845067  COURTNEY LOVE    pz brite                1997
#
#          Book-Publisher      Title-Tokens Author-Tokens      Publisher-Tokens
# 14473  Simon & Schuster  [courtney, love]   [pz, brite]  [Simon, &, Schuster]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.40
#
# Choosen book:              ISBN                      Book-Title Book-Author  \
# 5815  0440400759  Just As Long As We're Together     j blume
#
#      Year-Of-Publication  Book-Publisher      Title-Tokens Author-Tokens  \
# 5815                1988  Yearling Books  [long, together]    [j, blume]
#
#        Publisher-Tokens
# 5815  [Yearling, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.35
#
# Choosen book:              ISBN       Book-Title Book-Author Year-Of-Publication  \
# 7756  0439082110  Miles of Smiles    b lansky                1999
#
#      Book-Publisher   Title-Tokens Author-Tokens Publisher-Tokens
# 7756     Scholastic  [mile, smile]   [b, lansky]     [Scholastic]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.42
#
# Choosen book:               ISBN               Book-Title Book-Author Year-Of-Publication  \
# 22221  2070402991  Du Plus Loin De L'Oubli   p modiano                1999
#
#            Book-Publisher                  Title-Tokens Author-Tokens  \
# 22221  Gallimard Jeunesse  [du, plus, loin, de, loubli]  [p, modiano]
#
#             Publisher-Tokens
# 22221  [Gallimard, Jeunesse]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.92
#
# Choosen book:             ISBN                                         Book-Title  \
# 505  0345339703  The Fellowship of the Ring (The Lord of the Ri...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 505  jrr tolkien                1986        Del Rey
#
#                                 Title-Tokens   Author-Tokens Publisher-Tokens
# 505  [fellowship, ring, lord, ring, part, 1]  [jrr, tolkien]       [Del, Rey]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 8.33
#
# Choosen book:               ISBN  Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 12503  0330363239  Dirt music    t winton                2001        Picador
#
#         Title-Tokens Author-Tokens Publisher-Tokens
# 12503  [dirt, music]   [t, winton]        [Picador]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.42
#
# Choosen book:              ISBN           Book-Title  Book-Author Year-Of-Publication  \
# 2824  034528643X  Alchemy and Academe  a mccaffrey                1979
#
#      Book-Publisher        Title-Tokens   Author-Tokens   Publisher-Tokens
# 2824  Del Rey Books  [alchemy, academe]  [a, mccaffrey]  [Del, Rey, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.57
#
# Choosen book:              ISBN                                         Book-Title  \
# 7196  0812515609  People of the Mist (The First North Americans ...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 7196     ko gear                1998      Tor Books
#
#                                            Title-Tokens Author-Tokens  \
# 7196  [people, mist, first, north, american, series,...    [ko, gear]
#
#      Publisher-Tokens
# 7196     [Tor, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.67
#
# Choosen book:               ISBN Book-Title Book-Author Year-Of-Publication  Book-Publisher  \
# 17842  0805062734      Fludd    h mantel                2000  Owl Books (NY)
#
#       Title-Tokens Author-Tokens        Publisher-Tokens
# 17842      [fludd]   [h, mantel]  [Owl, Books, (, NY, )]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.96
#
# Choosen book:               ISBN                                     Book-Title Book-Author  \
# 11354  068484415X  CLIMBING THE MOUNTAIN : My Search For Meaning   k douglas
#
#       Year-Of-Publication    Book-Publisher  \
# 11354                1997  Simon & Schuster
#
#                                 Title-Tokens Author-Tokens  \
# 11354  [climbing, mountain, search, meaning]  [k, douglas]
#
#            Publisher-Tokens
# 11354  [Simon, &, Schuster]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.73
#
# Choosen book:              ISBN               Book-Title Book-Author Year-Of-Publication  \
# 4703  042511306X  The Sea King's Daughter  b michaels                1988
#
#                 Book-Publisher           Title-Tokens  Author-Tokens  \
# 4703  Berkley Publishing Group  [sea, king, daughter]  [b, michaels]
#
#                   Publisher-Tokens
# 4703  [Berkley, Publishing, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.19
#
# Choosen book:              ISBN                                         Book-Title  \
# 2371  0140373489  The Wonderful Story of Henry Sugar (Puffin Tee...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 2371      r dahl                1995   Puffin Books
#
#                                            Title-Tokens Author-Tokens  \
# 2371  [wonderful, story, henry, sugar, puffin, teena...     [r, dahl]
#
#      Publisher-Tokens
# 2371  [Puffin, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.89
#
# Choosen book:               ISBN          Book-Title Book-Author Year-Of-Publication  \
# 21229  0515106070  Always and Forever   c freeman                1991
#
#       Book-Publisher       Title-Tokens Author-Tokens Publisher-Tokens
# 21229     Jove Books  [always, forever]  [c, freeman]    [Jove, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.07
#
# Choosen book:               ISBN Book-Title Book-Author Year-Of-Publication  \
# 13410  0440236169    Birdman    m hayder                2000
#
#                 Book-Publisher Title-Tokens Author-Tokens  \
# 13410  Dell Publishing Company    [birdman]   [m, hayder]
#
#                   Publisher-Tokens
# 13410  [Dell, Publishing, Company]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.43
#
# Choosen book:               ISBN                                         Book-Title  \
# 10846  0486282414  Selected Canterbury Tales (Dover Thrift Editions)
#
#       Book-Author Year-Of-Publication      Book-Publisher  \
# 10846   g chaucer                1994  Dover Publications
#
#                                             Title-Tokens Author-Tokens  \
# 10846  [selected, canterbury, tale, dover, thrift, ed...  [g, chaucer]
#
#             Publisher-Tokens
# 10846  [Dover, Publications]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.95
#
# Choosen book:               ISBN Book-Title   Book-Author Year-Of-Publication Book-Publisher  \
# 22363  068984154X  Hard Love  e wittlinger                2001    Simon Pulse
#
#        Title-Tokens    Author-Tokens Publisher-Tokens
# 22363  [hard, love]  [e, wittlinger]   [Simon, Pulse]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.87
#
# Choosen book:              ISBN                                Book-Title    Book-Author  \
# 4803  0553213776  Kilmeny of the Orchard (Bantam Classics)  lm montgomery
#
#      Year-Of-Publication   Book-Publisher  \
# 4803                1989  Bantam Classics
#
#                              Title-Tokens     Author-Tokens  \
# 4803  [kilmeny, orchard, bantam, classic]  [lm, montgomery]
#
#         Publisher-Tokens
# 4803  [Bantam, Classics]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.03
#
# Choosen book:               ISBN                           Book-Title Book-Author  \
# 20502  0864426224  Lonely Planet Paris (Paris, 2nd Ed)  d robinson
#
#       Year-Of-Publication Book-Publisher  \
# 20502                1998  Lonely Planet
#
#                                   Title-Tokens  Author-Tokens  \
# 20502  [lonely, planet, paris, paris, 2nd, ed]  [d, robinson]
#
#        Publisher-Tokens
# 20502  [Lonely, Planet]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.01
#
# Choosen book:              ISBN    Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 1223  0446530891  Split Second  d baldacci                2003   Warner Books
#
#          Title-Tokens  Author-Tokens Publisher-Tokens
# 1223  [split, second]  [d, baldacci]  [Warner, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.06
#
# Choosen book:              ISBN   Book-Title  Book-Author Year-Of-Publication  \
# 1288  0060175532  Young Wives  o goldsmith                2000
#
#                 Book-Publisher   Title-Tokens   Author-Tokens  \
# 1288  HarperCollins Publishers  [young, wife]  [o, goldsmith]
#
#                  Publisher-Tokens
# 1288  [HarperCollins, Publishers]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.83
#
# Choosen book:              ISBN Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 2548  0553264613    Hot Ice   n roberts                2003         Bantam
#
#      Title-Tokens Author-Tokens Publisher-Tokens
# 2548   [hot, ice]  [n, roberts]         [Bantam]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.40
#
# Choosen book:               ISBN                                         Book-Title  \
# 17910  0140513221  Everything You Pretend to Know and Are Afraid ...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 17910     l padwa                1996  Penguin Books
#
#                                             Title-Tokens Author-Tokens  \
# 17910  [everything, pretend, know, afraid, someone, ask]    [l, padwa]
#
#        Publisher-Tokens
# 17910  [Penguin, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.38
#
# Choosen book:               ISBN                                         Book-Title  \
# 10566  0028604032  The New York Public Library Science Desk Refer...
#
#            Book-Author Year-Of-Publication                 Book-Publisher  \
# 10566  p barnessvarney                1995  MacMillan Publishing Company.
#
#                                             Title-Tokens       Author-Tokens  \
# 10566  [new, york, public, library, science, desk, re...  [p, barnessvarney]
#
#                           Publisher-Tokens
# 10566  [MacMillan, Publishing, Company, .]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.18
#
# Choosen book:              ISBN                                         Book-Title  \
# 2671  0140301690  Alice's Adventures in Wonderland and Through t...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 2671   l carroll                1996   Puffin Books
#
#                                            Title-Tokens Author-Tokens  \
# 2671  [alices, adventure, wonderland, looking, glass...  [l, carroll]
#
#      Publisher-Tokens
# 2671  [Puffin, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.89
#
# Choosen book:              ISBN                                Book-Title Book-Author  \
# 2238  0345394402  Dave Barry's Homes and Other Black Holes     d barry
#
#      Year-Of-Publication    Book-Publisher                       Title-Tokens  \
# 2238                1995  Ballantine Books  [dave, barrys, home, black, hole]
#
#      Author-Tokens     Publisher-Tokens
# 2238    [d, barry]  [Ballantine, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.75
#
# Choosen book:               ISBN  Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 19794  0380820560  Off Limits    m albert                2003           Avon
#
#       Title-Tokens Author-Tokens Publisher-Tokens
# 19794      [limit]   [m, albert]           [Avon]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.74
#
# Choosen book:              ISBN                                         Book-Title  \
# 7712  0515118907  The Man Who Cast Two Shadows (Kathleen Mallory...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 7712  c oconnell                1996     Jove Books
#
#                                            Title-Tokens  Author-Tokens  \
# 7712  [man, cast, two, shadow, kathleen, mallory, no...  [c, oconnell]
#
#      Publisher-Tokens
# 7712    [Jove, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.25
#
# Choosen book:               ISBN                          Book-Title Book-Author  \
# 23159  0310425115  Love Life for Every Married Couple     e wheat
#
#       Year-Of-Publication                Book-Publisher  \
# 23159                1980  Zondervan Publishing Company
#
#                                Title-Tokens Author-Tokens  \
# 23159  [love, life, every, married, couple]    [e, wheat]
#
#                        Publisher-Tokens
# 23159  [Zondervan, Publishing, Company]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.93
#
# Choosen book:               ISBN                                         Book-Title  \
# 12881  0446671339  The Quiet Room : A Journey Out of the Torment ...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 12881  l schiller                1996   Warner Books
#
#                                    Title-Tokens  Author-Tokens  \
# 12881  [quiet, room, journey, torment, madness]  [l, schiller]
#
#       Publisher-Tokens
# 12881  [Warner, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.92
#
# Choosen book:              ISBN    Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 3695  0756400082  Take a Thief    m lackey                2001      Daw Books
#
#        Title-Tokens Author-Tokens Publisher-Tokens
# 3695  [take, thief]   [m, lackey]     [Daw, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.77
#
# Choosen book:               ISBN Book-Title Book-Author Year-Of-Publication  \
# 13061  0006485936       Dust    ag slade                2001
#
#                  Book-Publisher Title-Tokens Author-Tokens  \
# 13061  HarperCollins Publishers       [dust]   [ag, slade]
#
#                   Publisher-Tokens
# 13061  [HarperCollins, Publishers]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.48
#
# Choosen book:              ISBN              Book-Title Book-Author Year-Of-Publication  \
# 4601  0446515868  Night Train to Memphis    e peters                1994
#
#         Book-Publisher             Title-Tokens Author-Tokens  \
# 4601  Warner Books Inc  [night, train, memphis]   [e, peters]
#
#           Publisher-Tokens
# 4601  [Warner, Books, Inc]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.28
#
# Choosen book:              ISBN       Book-Title Book-Author Year-Of-Publication  \
# 5033  0449223604  M Is for Malice   s grafton                1998
#
#      Book-Publisher Title-Tokens Author-Tokens  Publisher-Tokens
# 5033  Fawcett Books     [malice]  [s, grafton]  [Fawcett, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.05
#
# Choosen book:             ISBN        Book-Title Book-Author Year-Of-Publication  \
# 677  0553802542  Thursday's Child     s brown                2002
#
#     Book-Publisher       Title-Tokens Author-Tokens Publisher-Tokens
# 677   Bantam Books  [thursday, child]    [s, brown]  [Bantam, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.63
#
# Choosen book:             ISBN                                         Book-Title  \
# 574  0312978332  Name Dropping : What If Two Very Different Wom...
#
#     Book-Author Year-Of-Publication      Book-Publisher  \
# 574    j heller                2001  St. Martin's Press
#
#                                           Title-Tokens Author-Tokens  \
# 574  [name, dropping, two, different, woman, exact,...   [j, heller]
#
#              Publisher-Tokens
# 574  [St., Martin, 's, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.44
#
# Choosen book:              ISBN                           Book-Title Book-Author  \
# 9122  0802132758  Rosencrantz & Guildenstern Are Dead  t stoppard
#
#      Year-Of-Publication Book-Publisher                       Title-Tokens  \
# 9122                1991    Grove Press  [rosencrantz, guildenstern, dead]
#
#       Author-Tokens Publisher-Tokens
# 9122  [t, stoppard]   [Grove, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.44
#
# Choosen book:               ISBN   Book-Title   Book-Author Year-Of-Publication  \
# 13686  0060188952  Bread Alone  jr hendricks                2001
#
#                  Book-Publisher    Title-Tokens    Author-Tokens  \
# 13686  William Morrow & Company  [bread, alone]  [jr, hendricks]
#
#                     Publisher-Tokens
# 13686  [William, Morrow, &, Company]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.87
#
# Choosen book:              ISBN             Book-Title Book-Author Year-Of-Publication  \
# 9373  1575668807  Maggie Needs an Alibi  k michaels                2003
#
#                          Book-Publisher           Title-Tokens  Author-Tokens  \
# 9373  Kensington Publishing Corporation  [maggie, need, alibi]  [k, michaels]
#
#                            Publisher-Tokens
# 9373  [Kensington, Publishing, Corporation]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.31
#
# Choosen book:               ISBN                             Book-Title Book-Author  \
# 15052  0440944597  The Chocolate War (Laurel Leaf Books)   r cormier
#
#       Year-Of-Publication Book-Publisher  \
# 15052                1986    Laurel Leaf
#
#                                Title-Tokens Author-Tokens Publisher-Tokens
# 15052  [chocolate, war, laurel, leaf, book]  [r, cormier]   [Laurel, Leaf]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.87
#
# Choosen book:               ISBN                     Book-Title Book-Author  \
# 10139  8420430714  Todos Los Nombres (Alfaguara)  j saramago
#
#       Year-Of-Publication                     Book-Publisher  \
# 10139                1999  Alfaguara Ediciones, S.A. (Spain)
#
#                            Title-Tokens  Author-Tokens  \
# 10139  [todos, los, nombres, alfaguara]  [j, saramago]
#
#                                    Publisher-Tokens
# 10139  [Alfaguara, Ediciones, ,, S.A., (, Spain, )]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.49
#
# Choosen book:               ISBN    Book-Title Book-Author Year-Of-Publication  \
# 15804  0553573926  Vertical Run   jr garber                1996
#
#       Book-Publisher     Title-Tokens Author-Tokens Publisher-Tokens
# 15804   Bantam Books  [vertical, run]  [jr, garber]  [Bantam, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.96
#
# Choosen book:              ISBN                                   Book-Title Book-Author  \
# 1848  0060987529  Confessions of an Ugly Stepsister : A Novel   g maguire
#
#      Year-Of-Publication Book-Publisher  \
# 1848                2000    Regan Books
#
#                                Title-Tokens Author-Tokens Publisher-Tokens
# 1848  [confession, ugly, stepsister, novel]  [g, maguire]   [Regan, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.83
#
# Choosen book:              ISBN                                         Book-Title  \
# 4464  0886774861  Sword and Sorceress VIII: An Anthology of Hero...
#
#      Book-Author Year-Of-Publication    Book-Publisher  \
# 4464  mz bradley                1991  New Amer Library
#
#                                            Title-Tokens  Author-Tokens  \
# 4464  [sword, sorceress, viii, anthology, heroic, fa...  [mz, bradley]
#
#           Publisher-Tokens
# 4464  [New, Amer, Library]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.17
#
# Choosen book:              ISBN                      Book-Title Book-Author  \
# 5828  0440409462  Here's to You, Rachel Robinson     j blume
#
#      Year-Of-Publication Book-Publisher              Title-Tokens  \
# 5828                1994       Yearling  [here, rachel, robinson]
#
#      Author-Tokens Publisher-Tokens
# 5828    [j, blume]       [Yearling]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.48
#
# Choosen book:               ISBN                                   Book-Title Book-Author  \
# 11980  0886775515  His Conquering Sword (His Conquering Sword)   k elliott
#
#       Year-Of-Publication Book-Publisher  \
# 11980                1994      Daw Books
#
#                                  Title-Tokens Author-Tokens Publisher-Tokens
# 11980  [conquering, sword, conquering, sword]  [k, elliott]     [Daw, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.94
#
# Choosen book:               ISBN          Book-Title Book-Author Year-Of-Publication  \
# 21683  0747261148  Fruit of the Lemon     at levy                2002
#
#       Book-Publisher    Title-Tokens Author-Tokens Publisher-Tokens
# 21683   Abacus Press  [fruit, lemon]    [at, levy]  [Abacus, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.91
#
# Choosen book:              ISBN           Book-Title Book-Author Year-Of-Publication  \
# 9895  0741412780  The Great Pretender     m black                2002
#
#                 Book-Publisher        Title-Tokens Author-Tokens  \
# 9895  Infinity Publishing (PA)  [great, pretender]    [m, black]
#
#                       Publisher-Tokens
# 9895  [Infinity, Publishing, (, PA, )]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.35
#
# Choosen book:               ISBN Book-Title Book-Author Year-Of-Publication  \
# 17269  0399143661   Election  t perrotta                1998
#
#          Book-Publisher Title-Tokens  Author-Tokens      Publisher-Tokens
# 17269  Putnam Pub Group   [election]  [t, perrotta]  [Putnam, Pub, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.50
#
# Choosen book:              ISBN               Book-Title  Book-Author Year-Of-Publication  \
# 4377  0345257170  Illearth War Covenant 2  s donaldson                1978
#
#         Book-Publisher                  Title-Tokens   Author-Tokens  \
# 4377  Ballantine Books  [illearth, war, covenant, 2]  [s, donaldson]
#
#          Publisher-Tokens
# 4377  [Ballantine, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.03
#
# Choosen book:               ISBN                             Book-Title Book-Author  \
# 12539  0385499833  The Solace of Leaving Early : A Novel    h kimmel
#
#       Year-Of-Publication Book-Publisher                     Title-Tokens  \
# 12539                2002      Doubleday  [solace, leaving, early, novel]
#
#       Author-Tokens Publisher-Tokens
# 12539   [h, kimmel]      [Doubleday]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.33
#
# Choosen book:              ISBN           Book-Title Book-Author Year-Of-Publication  \
# 7707  3453023757  Sprengstoff. Roman.   r bachman                1996
#
#      Book-Publisher          Title-Tokens Author-Tokens Publisher-Tokens
# 7707          Heyne  [sprengstoff, roman]  [r, bachman]          [Heyne]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.93
#
# Choosen book:               ISBN     Book-Title Book-Author Year-Of-Publication  \
# 20678  0684859114  DAMASCUS GATE     r stone                1999
#
#       Book-Publisher      Title-Tokens Author-Tokens Publisher-Tokens
# 20678     Touchstone  [damascus, gate]    [r, stone]     [Touchstone]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.00
#
# Choosen book:              ISBN                                         Book-Title  \
# 2578  0373242026  Winning Hand (Silhouette Special Edition , No ...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 2578   n roberts                1998     Silhouette
#
#                                            Title-Tokens Author-Tokens  \
# 2578  [winning, hand, silhouette, special, edition, ...  [n, roberts]
#
#      Publisher-Tokens
# 2578     [Silhouette]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.73
#
# Choosen book:             ISBN                Book-Title Book-Author Year-Of-Publication  \
# 829  0316781010  Fortune's Rocks: A Novel    a shreve                1999
#
#      Book-Publisher            Title-Tokens Author-Tokens    Publisher-Tokens
# 829  Back Bay Books  [fortune, rock, novel]   [a, shreve]  [Back, Bay, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.79
#
# Choosen book:              ISBN                                 Book-Title Book-Author  \
# 8896  0064407721  Kissing the Witch: Old Tales in New Skins  e donoghue
#
#      Year-Of-Publication Book-Publisher  \
# 8896                1999   HarperTrophy
#
#                                 Title-Tokens  Author-Tokens Publisher-Tokens
# 8896  [kissing, witch, old, tale, new, skin]  [e, donoghue]   [HarperTrophy]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.76
#
# Choosen book:               ISBN                    Book-Title Book-Author  \
# 22271  0330028715  A Small Book of Grave Humour    f spiegl
#
#       Year-Of-Publication Book-Publisher                  Title-Tokens  \
# 22271                1989  Pan Macmillan  [small, book, grave, humour]
#
#       Author-Tokens  Publisher-Tokens
# 22271   [f, spiegl]  [Pan, Macmillan]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 3.56
#
# Choosen book:               ISBN                               Book-Title Book-Author  \
# 19930  0871138743  Triangle: The Fire That Changed America   dv drehle
#
#       Year-Of-Publication          Book-Publisher  \
# 19930                2003  Atlantic Monthly Press
#
#                              Title-Tokens Author-Tokens  \
# 19930  [triangle, fire, changed, america]  [dv, drehle]
#
#                  Publisher-Tokens
# 19930  [Atlantic, Monthly, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.15
#
# Choosen book:               ISBN        Book-Title Book-Author Year-Of-Publication  \
# 19509  1865082783  Love and vertigo       h teo                2000
#
#       Book-Publisher     Title-Tokens Author-Tokens   Publisher-Tokens
# 19509  Allen & Unwin  [love, vertigo]      [h, teo]  [Allen, &, Unwin]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.65
#
# Choosen book:              ISBN           Book-Title Book-Author Year-Of-Publication  \
# 6740  0553252704  The Parsifal Mosaic    r ludlum                1983
#
#      Book-Publisher        Title-Tokens Author-Tokens Publisher-Tokens
# 6740   Bantam Books  [parsifal, mosaic]   [r, ludlum]  [Bantam, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 8.46
#
# Choosen book:               ISBN                                         Book-Title  \
# 21104  157324175X  The Courage to Give: Inspiring Stories of Peop...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 21104   j waldman                1999   Conari Press
#
#                                             Title-Tokens Author-Tokens  \
# 21104  [courage, give, inspiring, story, people, triu...  [j, waldman]
#
#       Publisher-Tokens
# 21104  [Conari, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.93
#
# Choosen book:               ISBN Book-Title    Book-Author Year-Of-Publication  \
# 16367  0671024817     Wither  jg passarella                2000
#
#       Book-Publisher Title-Tokens     Author-Tokens Publisher-Tokens
# 16367         Pocket     [wither]  [jg, passarella]         [Pocket]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.56
#
# Choosen book:               ISBN                                         Book-Title  \
# 16160  006051406X  Molly Moon's Incredible Book of Hypnotism (Mol...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 16160      g byng                2003  HarperCollins
#
#                                             Title-Tokens Author-Tokens  \
# 16160  [molly, moon, incredible, book, hypnotism, mol...     [g, byng]
#
#       Publisher-Tokens
# 16160  [HarperCollins]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.08
#
# Choosen book:              ISBN                                         Book-Title  \
# 1040  0425161749  The Deadliest Game (Tom Clancy's Net Force; Yo...
#
#      Book-Author Year-Of-Publication            Book-Publisher  \
# 1040    t clancy                1999  Berkley Publishing Group
#
#                                            Title-Tokens Author-Tokens  \
# 1040  [deadliest, game, tom, clancys, net, force, yo...   [t, clancy]
#
#                   Publisher-Tokens
# 1040  [Berkley, Publishing, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.14
#
# Choosen book:               ISBN                               Book-Title Book-Author  \
# 22684  0877797080  Merriam Webster's Collegiate Dictionary     webster
#
#       Year-Of-Publication         Book-Publisher  \
# 22684                1993  Merriam-Webster, Inc.
#
#                                      Title-Tokens Author-Tokens  \
# 22684  [merriam, webster, collegiate, dictionary]     [webster]
#
#                    Publisher-Tokens
# 22684  [Merriam-Webster, ,, Inc, .]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.67
#
# Choosen book:              ISBN                          Book-Title Book-Author  \
# 5092  1400041503  Caramelo (Today Show Book Club #9)  s cisneros
#
#      Year-Of-Publication   Book-Publisher  \
# 5092                2003  Alfred A. Knopf
#
#                                 Title-Tokens  Author-Tokens  \
# 5092  [caramelo, today, show, book, club, 9]  [s, cisneros]
#
#          Publisher-Tokens
# 5092  [Alfred, A., Knopf]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.37
#
# Choosen book:               ISBN                                         Book-Title  \
# 15948  034537682X  Everything You Have Is Mine (Lauren Laurano My...
#
#          Book-Author Year-Of-Publication Book-Publisher  \
# 15948  s scoppettone                1993  Fawcett Books
#
#                                        Title-Tokens     Author-Tokens  \
# 15948  [everything, mine, lauren, laurano, mystery]  [s, scoppettone]
#
#        Publisher-Tokens
# 15948  [Fawcett, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.91
#
# Choosen book:              ISBN     Book-Title Book-Author Year-Of-Publication  \
# 1221  0446604844  Total Control  d baldacci                1997
#
#      Book-Publisher      Title-Tokens  Author-Tokens Publisher-Tokens
# 1221   Warner Books  [total, control]  [d, baldacci]  [Warner, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# ...
# 10257  0380711524  See Jane Run  j fielding                1992
#
#       Book-Publisher      Title-Tokens  Author-Tokens Publisher-Tokens
# 10257           Avon  [see, jane, run]  [j, fielding]           [Avon]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.97
#
# Choosen book:               ISBN    Book-Title Book-Author Year-Of-Publication  \
# 17226  0671875264  HANDLING SIN    m malone                1993
#
#                 Book-Publisher     Title-Tokens Author-Tokens  \
# 17226  Washington Square Press  [handling, sin]   [m, malone]
#
#                   Publisher-Tokens
# 17226  [Washington, Square, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.77
#
# Choosen book:               ISBN Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 12166  055357809X     Digger     j flynn                1998   Bantam Books
#
#       Title-Tokens Author-Tokens Publisher-Tokens
# 12166     [digger]    [j, flynn]  [Bantam, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.12
#
# Choosen book:               ISBN     Book-Title Book-Author Year-Of-Publication  \
# 19080  0864734263  Billie's Kiss      e knox                2002
#
#                   Book-Publisher   Title-Tokens Author-Tokens  \
# 19080  Victoria University Press  [billy, kiss]     [e, knox]
#
#                     Publisher-Tokens
# 19080  [Victoria, University, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.55
#
# Choosen book:              ISBN          Book-Title Book-Author Year-Of-Publication  \
# 5297  8420610445  Lobo Estepario, El     h hesse                1994
#
#      Book-Publisher           Title-Tokens Author-Tokens Publisher-Tokens
# 5297        Alianza  [lobo, estepario, el]    [h, hesse]        [Alianza]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.52
#
# Choosen book:               ISBN  Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 12522  0449222713  Black Opal      v holt                1994      Ivy Books
#
#         Title-Tokens Author-Tokens Publisher-Tokens
# 12522  [black, opal]     [v, holt]     [Ivy, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.62
#
# Choosen book:              ISBN                                         Book-Title  \
# 7014  014006690X  The Women of Brewster Place (Penguin Contempor...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 7014    g naylor                1983  Penguin Books
#
#                                            Title-Tokens Author-Tokens  \
# 7014  [woman, brewster, place, penguin, contemporary...   [g, naylor]
#
#       Publisher-Tokens
# 7014  [Penguin, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.67
#
# Choosen book:               ISBN                                       Book-Title  \
# 15439  0679748091  Ripley Under Water (Vintage Crime/Black Lizard)
#
#        Book-Author Year-Of-Publication     Book-Publisher  \
# 15439  p highsmith                1993  Vintage Books USA
#
#                                        Title-Tokens   Author-Tokens  \
# 15439  [ripley, water, vintage, crimeblack, lizard]  [p, highsmith]
#
#             Publisher-Tokens
# 15439  [Vintage, Books, USA]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.36
#
# Choosen book:               ISBN                                         Book-Title  \
# 22545  0385098855  How to Trace Your Family Tree: A Complete and ...
#
#          Book-Author Year-Of-Publication     Book-Publisher  \
# 22545  agr institute                1975  Main Street Books
#
#                                             Title-Tokens     Author-Tokens  \
# 22545  [trace, family, tree, complete, easy, understa...  [agr, institute]
#
#             Publisher-Tokens
# 22545  [Main, Street, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.21
#
# Choosen book:               ISBN                                         Book-Title  \
# 12570  0812575350  The Stainless Steel Rat Joins The Circus (Stai...
#
#       Book-Author Year-Of-Publication       Book-Publisher  \
# 12570  h harrison                2000  Tor Science Fiction
#
#                                             Title-Tokens  Author-Tokens  \
# 12570  [stainless, steel, rat, join, circus, stainles...  [h, harrison]
#
#               Publisher-Tokens
# 12570  [Tor, Science, Fiction]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.91
#
# Choosen book:              ISBN                                         Book-Title  \
# 1811  1558746226  A Second Chicken Soup for the Woman's Soul (Ch...
#
#      Book-Author Year-Of-Publication         Book-Publisher  \
# 1811  j canfield                1998  Health Communications
#
#                                            Title-Tokens  Author-Tokens  \
# 1811  [second, chicken, soup, woman, soul, chicken, ...  [j, canfield]
#
#               Publisher-Tokens
# 1811  [Health, Communications]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.75
#
# Choosen book:             ISBN                    Book-Title  Book-Author  \
# 443  0345260716  Have space suit--will travel  ra heinlein
#
#     Year-Of-Publication Book-Publisher               Title-Tokens  \
# 443                1977     Ballantine  [space, suitwill, travel]
#
#       Author-Tokens Publisher-Tokens
# 443  [ra, heinlein]     [Ballantine]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.18
#
# Choosen book:              ISBN                Book-Title Book-Author Year-Of-Publication  \
# 4419  2253044911  Les Dames du lac, tome 1  mz bradley                1988
#
#      Book-Publisher                  Title-Tokens  Author-Tokens  \
# 4419            LGF  [le, dame, du, lac, tome, 1]  [mz, bradley]
#
#      Publisher-Tokens
# 4419            [LGF]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.65
#
# Choosen book:               ISBN                                         Book-Title  \
# 11679  0811200124  Labyrinths: Selected Stories and Other Writing...
#
#       Book-Author Year-Of-Publication                         Book-Publisher  \
# 11679   jl borges                1964  New Directions Publishing Corporation
#
#                                             Title-Tokens Author-Tokens  \
# 11679  [labyrinth, selected, story, writing, new, dir...  [jl, borges]
#
#                                  Publisher-Tokens
# 11679  [New, Directions, Publishing, Corporation]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.87
#
# Choosen book:              ISBN         Book-Title Book-Author Year-Of-Publication  \
# 3057  0446356832  The Sands of Time   s sheldon                1989
#
#      Book-Publisher  Title-Tokens Author-Tokens Publisher-Tokens
# 3057   Warner Books  [sand, time]  [s, sheldon]  [Warner, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.65
#
# Choosen book:              ISBN                                         Book-Title  \
# 7410  0451521285  The Tragedy of Hamlet Prince of Denmark (Signe...
#
#         Book-Author Year-Of-Publication   Book-Publisher  \
# 7410  w shakespeare                1993  Signet Classics
#
#                                            Title-Tokens     Author-Tokens  \
# 7410  [tragedy, hamlet, prince, denmark, signet, cla...  [w, shakespeare]
#
#         Publisher-Tokens
# 7410  [Signet, Classics]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.01
#
# Choosen book:              ISBN         Book-Title Book-Author Year-Of-Publication  \
# 1467  0345302834  Castle Roogna #03   p anthony                1981
#
#      Book-Publisher          Title-Tokens Author-Tokens   Publisher-Tokens
# 1467  Del Rey Books  [castle, roogna, 03]  [p, anthony]  [Del, Rey, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.60
#
# Choosen book:               ISBN                                     Book-Title Book-Author  \
# 16136  0880387548  Kendermore (Dragonlance Saga Novel: Preludes)  m kirchoff
#
#       Year-Of-Publication Book-Publisher  \
# 16136                1989            TSR
#
#                                           Title-Tokens  Author-Tokens  \
# 16136  [kendermore, dragonlance, saga, novel, prelude]  [m, kirchoff]
#
#       Publisher-Tokens
# 16136            [TSR]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.25
#
# Choosen book:              ISBN                      Book-Title Book-Author  \
# 4276  0425174018  Hush Money (Spenser Mysteries)   rb parker
#
#      Year-Of-Publication            Book-Publisher  \
# 4276                2000  Berkley Publishing Group
#
#                          Title-Tokens Author-Tokens  \
# 4276  [hush, money, spenser, mystery]  [rb, parker]
#
#                   Publisher-Tokens
# 4276  [Berkley, Publishing, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.33
#
# Choosen book:              ISBN                         Book-Title Book-Author  \
# 8573  0425191230  Material Girl (Berkley Sensation)    j london
#
#      Year-Of-Publication            Book-Publisher  \
# 8573                2003  Berkley Publishing Group
#
#                               Title-Tokens Author-Tokens  \
# 8573  [material, girl, berkley, sensation]   [j, london]
#
#                   Publisher-Tokens
# 8573  [Berkley, Publishing, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.19
#
# Choosen book:               ISBN Book-Title   Book-Author Year-Of-Publication  \
# 13795  0671456547     Truman  d mccullough                1992
#
#          Book-Publisher Title-Tokens    Author-Tokens      Publisher-Tokens
# 13795  Simon & Schuster     [truman]  [d, mccullough]  [Simon, &, Schuster]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.28
#
# Choosen book:               ISBN                                       Book-Title  \
# 13480  0671002783  God on a Harley : Twelve Real Life Love Stories
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 13480     j brady                1996         Pocket
#
#                                          Title-Tokens Author-Tokens  \
# 13480  [god, harley, twelve, real, life, love, story]    [j, brady]
#
#       Publisher-Tokens
# 13480         [Pocket]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.74
#
# Choosen book:               ISBN Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 13789  0553579142  Cry Dance  k mitchell                2000   Bantam Books
#
#        Title-Tokens  Author-Tokens Publisher-Tokens
# 13789  [cry, dance]  [k, mitchell]  [Bantam, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.72
#
# Choosen book:              ISBN                                         Book-Title  \
# 1686  0449002985  Your Oasis on Flame Lake (Ballantine Reader's ...
#
#      Book-Author Year-Of-Publication    Book-Publisher  \
# 1686   l landvik                1998  Ballantine Books
#
#                                           Title-Tokens Author-Tokens  \
# 1686  [oasis, flame, lake, ballantine, reader, circle]  [l, landvik]
#
#          Publisher-Tokens
# 1686  [Ballantine, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.52
#
# Choosen book:              ISBN Book-Title Book-Author Year-Of-Publication  \
# 2313  0805054073   Timbuktu    p auster                1999
#
#             Book-Publisher Title-Tokens Author-Tokens  \
# 2313  Henry Holt & Company   [timbuktu]   [p, auster]
#
#                Publisher-Tokens
# 2313  [Henry, Holt, &, Company]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.69
#
# Choosen book:              ISBN          Book-Title     Book-Author Year-Of-Publication  \
# 5761  8420483591  Limpieza de sangre  a perezreverte                1998
#
#         Book-Publisher            Title-Tokens      Author-Tokens  \
# 5761  Santillana, S.A.  [limpieza, de, sangre]  [a, perezreverte]
#
#              Publisher-Tokens
# 5761  [Santillana, ,, S.A, .]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 8.18
#
# Choosen book:               ISBN                    Book-Title Book-Author  \
# 12178  0441010652  Something from the Nightside    sr green
#
#       Year-Of-Publication Book-Publisher            Title-Tokens  \
# 12178                2003      Ace Books  [something, nightside]
#
#       Author-Tokens Publisher-Tokens
# 12178   [sr, green]     [Ace, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.31
#
# Choosen book:               ISBN Book-Title Book-Author Year-Of-Publication  \
# 10095  0451206371   Rosamund     b small                2002
#
#              Book-Publisher Title-Tokens Author-Tokens  \
# 10095  New American Library   [rosamund]    [b, small]
#
#                Publisher-Tokens
# 10095  [New, American, Library]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.91
#
# Choosen book:              ISBN Book-Title Book-Author Year-Of-Publication  \
# 3508  0399146008      Shock      r cook                2001
#
#            Book-Publisher Title-Tokens Author-Tokens  \
# 3508  G. P. Putnam's Sons      [shock]     [r, cook]
#
#                 Publisher-Tokens
# 3508  [G., P., Putnam, 's, Sons]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.68
#
# Choosen book:               ISBN                                         Book-Title  \
# 16809  1562920960  God's Little Devotional Book (God's Little Dev...
#
#       Book-Author Year-Of-Publication    Book-Publisher  \
# 16809     h books                1995  Honor Books (OK)
#
#                                             Title-Tokens Author-Tokens  \
# 16809  [god, little, devotional, book, god, little, d...    [h, books]
#
#                Publisher-Tokens
# 16809  [Honor, Books, (, OK, )]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.77
#
# Choosen book:               ISBN                  Book-Title Book-Author Year-Of-Publication  \
# 13633  1551669137  A Wolf In Sheep's Clothing  j johnston                2002
#
#       Book-Publisher             Title-Tokens  Author-Tokens Publisher-Tokens
# 13633           Mira  [wolf, sheep, clothing]  [j, johnston]           [Mira]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.34
#
# Choosen book:              ISBN                        Book-Title Book-Author  \
# 1509  0553257749  Something Wicked / E.X. Ferrars.  r bradbury
#
#      Year-Of-Publication Book-Publisher                        Title-Tokens  \
# 1509                1983   Bantam Books  [something, wicked, e, x, ferrars]
#
#       Author-Tokens Publisher-Tokens
# 1509  [r, bradbury]  [Bantam, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 8.00
# R-squared: -3.70
# Mean Squared Error: 4.32
# Root Mean Squared Error: 2.08
# Mean Absolute Error: 1.73
