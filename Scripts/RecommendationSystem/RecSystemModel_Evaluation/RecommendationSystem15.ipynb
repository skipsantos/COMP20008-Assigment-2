# %%
import numpy as np
import pandas as pd
import nltk
import os
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

for dirname, _, filenames in os.walk('../../Data-Files'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/EODP2/BX-NewBooksRatings.csv
# /content/EODP2/BX-Books.csv
# /content/EODP2/BX-NewBooks.csv
# /content/EODP2/BX-Users.csv
# /content/EODP2/BX-NewBooksUsers.csv
# /content/EODP2/BX-Ratings.csv
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
import re

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer


def load_data(input_path):
    # Load and return all datasets
    ratings = pd.read_csv(os.path.join(input_path, 'BX-Ratings.csv'))
    new_ratings = pd.read_csv(os.path.join(input_path, 'BX-NewBooksRatings.csv'))
    books_old = pd.read_csv(os.path.join(input_path, 'BX-Books.csv'))
    new_books = pd.read_csv(os.path.join(input_path, 'BX-NewBooks.csv'))
    books = pd.concat([books_old, new_books]).drop_duplicates(subset=["Book-Title"], keep='first')
    ratings = pd.concat([ratings, new_ratings])
    return ratings, books

"""Function for age string preprocessing"""
def onlyNumber(age):
  try:
      string_age = str(age)
      cleaned_age = int(re.sub(r'[^0-9]', '', string_age))
      if cleaned_age < 2 or cleaned_age> 123:
        #oldest person in the world is 122 years old and the youngest is 2 years old
          return np.nan
      return cleaned_age
  except:
      return np.nan

def has_special_characters(s):
  s = str(s)
  return any(ord(char) > 127 for char in s)

def abbreviate(s):
  text = s.split()
  new_string = []
  for i in range(len(text)):
      if i < (len(text) - 1):
          new_string.append(text[i][0])
      else:
          new_string.append(text[i])
  return ' '.join(new_string)

# Joins together consecutive single characters in a string
def process_strings(s):
  text = s.split()
  curr = ''
  new_words = []
  # joining together single letters
  for word in text:
      if len(word) == 1:
          curr += word
      else:
          if curr:
              new_words.append(curr)
              curr = ''
          new_words.append(word)

  if curr:
      new_words.append(curr)

  return ' '.join(new_words)

# Preprocesses titles
def title_preprocess(doc, stop_words, lemmatizer):
  doc = str(doc)
  doc = doc.lower()
  # Fixing special cases (periods with no spaces)
  doc_special = re.sub(r'\.(?=\w)', '. ', doc)

  # Removing all punctuation
  doc_punct = re.sub(r'[^A-Za-z0-9\s]', '', doc_special)

  # Remove all instances of 'paperback' in titles
  processed_doc = re.sub(r'paperback\s*', '', doc_punct)

  # Tokenising, removing stop words, then lemmatizing the tokens
  tokens = word_tokenize(processed_doc)
  tokens = [w for w in tokens if not w in stop_words]
  lemmatized = [lemmatizer.lemmatize(w) for w in tokens]

  return ' '.join(lemmatized)

# Preprocesses publishers
def publisher_preprocess(doc, stop_words, lemmatizer):
  doc = doc.lower()
  # Fixing special cases (periods with no spaces)
  doc_special = re.sub(r'\.(?=\w)', '. ', doc)

  # Removing all punctuation
  doc_punct = re.sub(r'[^A-Za-z0-9\s]', '', doc_special)

  # Join single characters (initials)
  doc_joined = process_strings(doc_punct)

  # Removing irrelevant words in publishers
  processed_doc = re.sub(r'\b(?:paperback|books|press|publishing|paperbacks)\b', '', doc_joined)

  # Tokenising, removing stop words, then lemmatizing the tokens
  tokens = word_tokenize(processed_doc)
  tokens = [w for w in tokens if not w in stop_words]
  lemmatized = [lemmatizer.lemmatize(w) for w in tokens]
  return ' '.join(lemmatized)

def prepare_data(books):

    # Filter out all non ASCII characters
    books = books[~books['Book-Title'].apply(has_special_characters)]
    books = books[~books['Book-Author'].apply(has_special_characters)]
    books = books[~books['Book-Publisher'].apply(has_special_characters)]

    # Book Title preprocessing steps
    # Initialising lemmatizer, stopwords, and tfidf
    lemmatizer = WordNetLemmatizer()
    stop_words = set(stopwords.words('english'))

    processed_titles = []
    for i, title in enumerate(books['Book-Title']):
        processed_titles.append(title_preprocess(title, stop_words,lemmatizer))
    books['Title-Tokens'] = [word_tokenize(t) for t in processed_titles]

    # Author preprocessing steps
    # Setting all author names to lowercase
    books['Book-Author'] = books['Book-Author'].astype(str)
    books['Book-Author'] = books['Book-Author'].apply(lambda x: x.lower())

    # Fixing special cases (periods with no spaces)
    author_special = books['Book-Author'].apply(lambda x: re.sub(r'\.(?=\w)', '. ', x))

    # Removing All punctuations
    author_punct = author_special.apply(lambda x: re.sub(r'[^A-Za-z\s]', '', x))

    # Abbreviating then joining together single letters into one word (for name initials)
    books['Book-Author'] = author_punct.apply(abbreviate)
    books['Book-Author'] = books['Book-Author'].apply(process_strings)
    books['Author-Tokens'] = books['Book-Author'].apply(word_tokenize)

    # Publishing Year Preprocessing Steps
    # Convert all years outside plausible range to 0
    books.loc[~books['Year-Of-Publication'].between(1920, 2005), 'Year-Of-Publication'] = 0
    filtered_books = books[books['Year-Of-Publication'] != 0]

    # Get average year of publication for each author
    publish_years = filtered_books.groupby('Book-Author')['Year-Of-Publication'].mean().reset_index()

    # Replace 0 values with corresponding author mean
    books = books.merge(publish_years, on='Book-Author', suffixes=('', '_mean'))
    books['Year-Of-Publication'] = books.apply(lambda row: row['Year-Of-Publication_mean']
        if row['Year-Of-Publication'] == 0 else row['Year-Of-Publication'], axis=1)

    books['Year-Of-Publication'] = books['Year-Of-Publication'].astype(int)
    books.drop(columns='Year-Of-Publication_mean', inplace=True)

    # Publisher Preprocessing Steps
    processed_publishers = []
    for i, title in enumerate(books['Book-Publisher']):
        processed_publishers.append(publisher_preprocess(title, stop_words,lemmatizer))

    books['Publisher-Tokens'] = books['Book-Publisher'].apply(word_tokenize)
    return books.drop_duplicates(subset=["Book-Title"], keep='first').dropna()

def combine_tokens(books):

    tokens = ["Year-Of-Publication-Tokens","Title-Tokens", "Author-Tokens", "Publisher-Tokens"]
    books["Year-Of-Publication-Tokens"] = books["Year-Of-Publication"].astype(str).apply(lambda x: [x])

    # Combine the token arrays from different columns into a single array
    books['Combined-Tokens'] = books[tokens].apply(lambda x: np.concatenate(x), axis=1)

    # Create a new DataFrame with 'ISBN' and 'Combined-Tokens' columns
    df_tokens = books[['ISBN', 'Combined-Tokens']]
    return df_tokens

def prepare_tfidf(books):

    df_tokens = combine_tokens(books)

    # Apply TF-IDF vectorization to the combined token column
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_matrix = tfidf_vectorizer.fit_transform(df_tokens['Combined-Tokens'].apply(lambda x: ' '.join(x)))

    # Create a DataFrame with TF-IDF values and 'ISBN' as the index
    df_tfidf = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out(), index=df_tokens['ISBN'])
    return df_tfidf

def prepare_vector(books):

    df_tokens = combine_tokens(books)
    cv = CountVectorizer(max_features=500, stop_words="english")
    vectors_matrix = cv.fit_transform(df_tokens["Combined-Tokens"].apply(lambda x: ' '.join(x)))
    df_vector = pd.DataFrame(vectors_matrix.toarray(), columns=cv.get_feature_names_out(), index=df_tokens['ISBN'])

    return df_vector

def find_similar_books(book_id, books, vector, recommend_number = 15):
    # Calculate similarity and find similar books

    similarity = cosine_similarity(vector)
    try:
        book_idx = books.index[books['ISBN'] == book_id].tolist()[0]
        #default is set at recommending 10 books this value will also affect predicted rating
        similar_books = sorted(list(enumerate(similarity[book_idx])), key=lambda x: x[1], reverse=True)[1:recommend_number]

        return similar_books

    except IndexError:
        print("Book ID not found in dataset.")

        return []

def recommend_books_vector(ratings, books, similar_books):
    # predicting books rating based on the cosine similarity scores of the vector based word processing

    rating_sims = []
    for idx, sim_score in similar_books:
        similar_isbn = books.iloc[idx]['ISBN']
        if similar_isbn in books['ISBN'].values:
            book_title = books.iloc[idx]['Book-Title']
            book_author = books.iloc[idx]['Book-Author']
            isbn_ratings = ratings[ratings["ISBN"] == similar_isbn]
            book_year = books.iloc[idx]['Year-Of-Publication']
            book_publisher = books.iloc[idx]['Book-Publisher']
            if not isbn_ratings.empty:
                mean_rating = isbn_ratings['Book-Rating'].mean()
                adjusted_score = mean_rating * sim_score
                rating_sims.append(float(adjusted_score))
    if rating_sims:
        average_adjusted_score = sum(rating_sims) / len(rating_sims)
        print(f"\nPredicted Rating: {average_adjusted_score:.2f}")

        return average_adjusted_score

def recommend_books_tfidf(ratings, books, similar_books):
    # Recommend books based on the cosine similarity scores of the tfidf based word processing

    for idx, sim_score in similar_books:
        similar_isbn = books.iloc[idx]['ISBN']
        if similar_isbn in books['ISBN'].values:
            book_title = books.iloc[idx]['Book-Title']
            book_author = books.iloc[idx]['Book-Author']
            isbn_ratings = ratings[ratings["ISBN"] == similar_isbn]
            book_year = books.iloc[idx]['Year-Of-Publication']
            book_publisher = books.iloc[idx]['Book-Publisher']
            if not isbn_ratings.empty:
                print(f"{book_title} by {book_author} published in {book_year} by {book_publisher}")

def recommend( wanted_book,books,ratings, recommend_state = False):
    print("\nChoosen book: ",wanted_book)
    added_books = pd.concat([books,wanted_book])
    books = prepare_data(added_books)

    print("\nPreprocessed data finished\n")
    wanted_ISBN = wanted_book.iloc[0]['ISBN']

    #These section is for the rating prediction
    vector = prepare_vector(books)
    print("Vectorized data finished\n")

    similar_books_vector = find_similar_books(wanted_ISBN, books, vector)

    # These section is for recommendation section
    if recommend_state:
      tfidf_books = prepare_data(added_books)
      tfidf = prepare_tfidf(tfidf_books)
      similar_books_tfidf = find_similar_books(wanted_ISBN, tfidf_books, tfidf)
    print("Find Similarity finished\n")

    if similar_books_vector:
        #this section will calculate and return the recommend books

        if recommend_state:
          print("\nRecommend Book\n")
          recommend_books_tfidf(ratings, tfidf_books, similar_books_tfidf)

        #this section will calculate and return the predicted value
        return recommend_books_vector(ratings, books, similar_books_vector)

"""This is the recommendation model that use cosine similarity to recommend
    book based on the user input book which it will give the predicted rating
    and give recommending books based on the tfidf vector. The recommend functionality
    is very computing intensive so it is set as False by default. However you can
    try and run it with the recommend_state = True like the following cell.
    """
def RecommendationSystem(wanted_book,books,ratings,recommend_state =False):

    return recommend(wanted_book,books,ratings,recommend_state)

# %%
#Please don't forget to provide the file path to the load_data
ratings, books = load_data('../../Data-Files/Raw-Files')
#It also recommend to run this program in cloud based ipynb as it is very computing intensive
#Our group use the kaggle and Google Colab to run these and the setting is cpu runtime type with high-ram
#if using the free version it will not run as it exceed googlecolab ram limit
RecommendationSystem((pd.DataFrame({'ISBN': ['0425163091'],
                                    'Book-Title': ['Chocolate Jesus'],
                                    'Book-Author': ['s jaramillo'],
                                    'Year-Of-Publication': [1998],
                                    'Book-Publisher': ['Berkley Publishing Group']})),
                     books,ratings,recommend_state =True)
# Out:
# Choosen book:           ISBN       Book-Title  Book-Author  Year-Of-Publication  \
# 0  0425163091  Chocolate Jesus  s jaramillo                 1998
#
#              Book-Publisher
# 0  Berkley Publishing Group
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Recommend Book
#
# Chocolate Quake by n fairbanks published in 2003 by Berkley Publishing Group
# Jesus Freaks: DC Talk and The Voice of the Martyrs - Stories of Those Who Stood For Jesus, the Ultimate Jesus Freaks by d talk published in 1999 by Bethany House Publishers
# Here on Earth by a hoffman published in 1998 by Berkley Publishing Group
# N or M? by a christie published in 1996 by Berkley Publishing Group
# Meeting Jesus Again for the First Time : The Historical Jesus and the Heart of Contemporary Faith by mj borg published in 1995 by HarperSanFrancisco
# Practical Magic by a hoffman published in 1998 by Berkley Publishing Group
# Jesus' Son: Stories by d johnson published in 1993 by Perennial
# The Magician's Tale by d hunt published in 1998 by Berkley Publishing Group
# Detective: A Novel by a hailey published in 1998 by Berkley Publishing Group
# Contagion by r cook published in 1998 by Berkley Publishing Group
# Timequake by k vonnegut published in 1998 by Berkley Publishing Group
# The A.B.C. Murders by a christie published in 1993 by Berkley Publishing Group
# Second Nature by a hoffman published in 1998 by Berkley Publishing Group
# The President's Daughter by j higgins published in 1998 by Berkley Publishing Group
#
# Predicted Rating: 6.32
# 6.319929657780647

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
def delete_records_by_isbn(df, isbn):
    #Function for making train data set by delete the test data set out off the dataframe

    isbn_set = set(isbn['ISBN'])
    mask = (df['ISBN'].apply(lambda x: x not in isbn_set))
    updated_df = df[mask]
    return updated_df

def select_random_data(df, percentage):
    # Function for sampling a percentage of the dataframe using for test dataset

    return df.sample(n=int(len(df) * percentage))

def evaluate_model(percentage = 0.001): # this is fractional percentage 0.001 mean 0.1%
  #This function will evaluate the model which use mse, rmse, mae and r2 for evaluation
  ratings, books = load_data('/content/EODP2/')
  books = prepare_data(books)
  test_books = select_random_data(books,percentage)
  train_books = delete_records_by_isbn(books,test_books)
  train_ratings = delete_records_by_isbn(ratings,test_books)
  test_rating = ratings.groupby('ISBN')['Book-Rating'].mean().reset_index()
  test_rating.rename(columns={'Book-Rating': 'Avg-Book-Rating'}, inplace=True)
  test_rating = pd.merge(test_books,test_rating,on ="ISBN")
  pred_rate = []

  # Print the recommendations for each book
  for _, row in test_books.iterrows():
    row = (pd.DataFrame(row)).transpose()
    pred_rate.append(RecommendationSystem(row, train_books, train_ratings))
  #linear_rating = ratings.groupby('ISBN')['Book-Rating'].mean().reset_index()
  mse = mean_squared_error(test_rating['Avg-Book-Rating'], pred_rate)
  rmse = np.sqrt(mse)
  mae = mean_absolute_error(test_rating['Avg-Book-Rating'], pred_rate)
  r2 = r2_score(test_rating['Avg-Book-Rating'], pred_rate)
  print(f"R-squared: {r2:.2f}")
  print(f"Mean Squared Error: {mse:.2f}")
  print(f"Root Mean Squared Error: {rmse:.2f}")
  print(f"Mean Absolute Error: {mae:.2f}")

# %%
evaluate_model()
# Out:
# Choosen book:               ISBN       Book-Title  Book-Author Year-Of-Publication  \
# 11280  0345423615  The Silver Wolf  a borchardt                1999
#
#          Book-Publisher    Title-Tokens   Author-Tokens     Publisher-Tokens
# 11280  Ballantine Books  [silver, wolf]  [a, borchardt]  [Ballantine, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.99
#
# Choosen book:              ISBN Book-Title Book-Author Year-Of-Publication   Book-Publisher  \
# 2263  1573228737   Affinity    s waters                2002  Riverhead Books
#
#      Title-Tokens Author-Tokens    Publisher-Tokens
# 2263   [affinity]   [s, waters]  [Riverhead, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.64
#
# Choosen book:              ISBN  Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 1662  0553265520  Brainchild      j saul                1985   Bantam Books
#
#       Title-Tokens Author-Tokens Publisher-Tokens
# 1662  [brainchild]     [j, saul]  [Bantam, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.04
#
# Choosen book:               ISBN                 Book-Title Book-Author Year-Of-Publication  \
# 23141  0590423592  Spooky Rhymes and Riddles        hall                1990
#
#       Book-Publisher             Title-Tokens Author-Tokens Publisher-Tokens
# 23141     E P Dutton  [spooky, rhyme, riddle]        [hall]   [E, P, Dutton]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.49
#
# Choosen book:               ISBN  Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 23478  0441002552  Hard Drive     d pogue                1995      Ace Books
#
#         Title-Tokens Author-Tokens Publisher-Tokens
# 23478  [hard, drive]    [d, pogue]     [Ace, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.13
#
# Choosen book:               ISBN          Book-Title Book-Author Year-Of-Publication  \
# 13605  038549744X  English Passengers    m kneale                2001
#
#                Book-Publisher          Title-Tokens Author-Tokens  \
# 13605  Anchor Books/Doubleday  [english, passenger]   [m, kneale]
#
#                 Publisher-Tokens
# 13605  [Anchor, Books/Doubleday]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.00
#
# Choosen book:               ISBN                                      Book-Title Book-Author  \
# 22705  0440237920  The Gospel According to Larry (Readers Circle)  j tashjian
#
#       Year-Of-Publication     Book-Publisher  \
# 22705                2003  Laurel-Leaf Books
#
#                                      Title-Tokens  Author-Tokens  \
# 22705  [gospel, according, larry, reader, circle]  [j, tashjian]
#
#            Publisher-Tokens
# 22705  [Laurel-Leaf, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.82
#
# Choosen book:              ISBN            Book-Title Book-Author Year-Of-Publication  \
# 3127  0440102804  The Anodyne Necklace    m grimes                1990
#
#      Book-Publisher         Title-Tokens Author-Tokens Publisher-Tokens
# 3127           Dell  [anodyne, necklace]   [m, grimes]           [Dell]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.44
#
# Choosen book:               ISBN                              Book-Title Book-Author  \
# 18831  096291620X  Getting in Touch With Your Inner Bitch     e hilts
#
#       Year-Of-Publication Book-Publisher                    Title-Tokens  \
# 18831                1994    Sourcebooks  [getting, touch, inner, bitch]
#
#       Author-Tokens Publisher-Tokens
# 18831    [e, hilts]    [Sourcebooks]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.84
#
# Choosen book:             ISBN          Book-Title Book-Author Year-Of-Publication  \
# 384  0425114236  Accidental Tourist     a tyler                1988
#
#           Book-Publisher           Title-Tokens Author-Tokens  \
# 384  Penguin Putnam~mass  [accidental, tourist]    [a, tyler]
#
#            Publisher-Tokens
# 384  [Penguin, Putnam~mass]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.72
#
# Choosen book:               ISBN                                         Book-Title  \
# 17629  0201354632  JavaScript for the World Wide Web: Visual Quic...
#
#       Book-Author Year-Of-Publication  Book-Publisher  \
# 17629   t negrino                1999  Peachpit Press
#
#                                             Title-Tokens Author-Tokens  \
# 17629  [javascript, world, wide, web, visual, quickst...  [t, negrino]
#
#         Publisher-Tokens
# 17629  [Peachpit, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.53
#
# Choosen book:               ISBN                                         Book-Title  \
# 11254  0786914041  The Spine of the World (Forgotten Realms:  Pat...
#
#         Book-Author Year-Of-Publication        Book-Publisher  \
# 11254  ra salvatore                2000  Wizards of the Coast
#
#                                             Title-Tokens    Author-Tokens  \
# 11254  [spine, world, forgotten, realm, path, darknes...  [ra, salvatore]
#
#                 Publisher-Tokens
# 11254  [Wizards, of, the, Coast]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.00
#
# Choosen book:              ISBN      Book-Title Book-Author Year-Of-Publication  \
# 5601  0671007610  Olivia (Logan)  vc andrews                1999
#
#      Book-Publisher     Title-Tokens  Author-Tokens Publisher-Tokens
# 5601   Pocket Books  [olivia, logan]  [vc, andrews]  [Pocket, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.26
#
# Choosen book:              ISBN                             Book-Title    Book-Author  \
# 7225  1576730824  A Gathering Of Finches (Dreamcatcher)  j kirkpatrick
#
#      Year-Of-Publication Book-Publisher                      Title-Tokens  \
# 7225                1997      Multnomah  [gathering, finch, dreamcatcher]
#
#          Author-Tokens Publisher-Tokens
# 7225  [j, kirkpatrick]      [Multnomah]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.11
#
# Choosen book:              ISBN                                         Book-Title  \
# 8591  1593080026  The CALL OF THE WILD AND WHITE FANG (B&N Class...
#
#      Book-Author Year-Of-Publication  Book-Publisher  \
# 8591    j london                2003  Barnes & Noble
#
#                                            Title-Tokens Author-Tokens  \
# 8591  [call, wild, white, fang, bn, classic, mass, m...   [j, london]
#
#         Publisher-Tokens
# 8591  [Barnes, &, Noble]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 3.56
#
# Choosen book:               ISBN                             Book-Title Book-Author  \
# 18160  0679432965  My American Journey: An Autobiography   cl powell
#
#       Year-Of-Publication Book-Publisher                        Title-Tokens  \
# 18160                1995   Random House  [american, journey, autobiography]
#
#       Author-Tokens Publisher-Tokens
# 18160  [cl, powell]  [Random, House]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.40
#
# Choosen book:              ISBN                               Book-Title  Book-Author  \
# 8885  0312955510  The Heart of Justice (Heart of Justice)  wj coughlin
#
#      Year-Of-Publication      Book-Publisher  \
# 8885                1995  St. Martin's Press
#
#                           Title-Tokens   Author-Tokens  \
# 8885  [heart, justice, heart, justice]  [wj, coughlin]
#
#               Publisher-Tokens
# 8885  [St., Martin, 's, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.54
#
# Choosen book:               ISBN                                    Book-Title Book-Author  \
# 21217  0373511280  Dark Obsession (Reader's Choice Dreamscapes)   m stevens
#
#       Year-Of-Publication Book-Publisher  \
# 21217                2001     Silhouette
#
#                                          Title-Tokens Author-Tokens  \
# 21217  [dark, obsession, reader, choice, dreamscapes]  [m, stevens]
#
#       Publisher-Tokens
# 21217     [Silhouette]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.14
#
# Choosen book:               ISBN                                         Book-Title  \
# 16577  0380817187  Dim Sum Dead : A Madeline Bean Culinary Myster...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 16577    j farmer                2001           Avon
#
#                                             Title-Tokens Author-Tokens  \
# 16577  [dim, sum, dead, madeline, bean, culinary, mys...   [j, farmer]
#
#       Publisher-Tokens
# 16577           [Avon]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.97
#
# Choosen book:               ISBN                         Book-Title Book-Author  \
# 15845  0767903595  Clear Your Clutter With Feng Shui  k kingston
#
#       Year-Of-Publication  Book-Publisher                  Title-Tokens  \
# 15845                1999  Broadway Books  [clear, clutter, feng, shui]
#
#        Author-Tokens   Publisher-Tokens
# 15845  [k, kingston]  [Broadway, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.39
#
# Choosen book:               ISBN Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 13644  0451192192  The Store    b little                1998    Signet Book
#
#       Title-Tokens Author-Tokens Publisher-Tokens
# 13644      [store]   [b, little]   [Signet, Book]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.90
#
# Choosen book:               ISBN        Book-Title Book-Author Year-Of-Publication  \
# 12467  0441007147  Wrapt in Crystal     s shinn                2000
#
#       Book-Publisher      Title-Tokens Author-Tokens Publisher-Tokens
# 12467      Ace Books  [wrapt, crystal]    [s, shinn]     [Ace, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.46
#
# Choosen book:               ISBN                             Book-Title Book-Author  \
# 19858  0590324217  One Hundred One Fast Funny Food Jokes    p hirsch
#
#       Year-Of-Publication              Book-Publisher  \
# 19858                1984  Scholastic Paperbacks (Mm)
#
#                                        Title-Tokens Author-Tokens  \
# 19858  [one, hundred, one, fast, funny, food, joke]   [p, hirsch]
#
#                          Publisher-Tokens
# 19858  [Scholastic, Paperbacks, (, Mm, )]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.19
# R-squared: -5.98
# Mean Squared Error: 5.04
# Root Mean Squared Error: 2.24
# Mean Absolute Error: 1.95

# %%
evaluate_model(0.01)
# Out:
# Choosen book:              ISBN         Book-Title Book-Author Year-Of-Publication  \
# 9939  0743400380  Oz: Into the Wild    c golden                2002
#
#                      Book-Publisher Title-Tokens Author-Tokens  \
# 9939  Simon Spotlight Entertainment   [oz, wild]   [c, golden]
#
#                        Publisher-Tokens
# 9939  [Simon, Spotlight, Entertainment]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.56
#
# Choosen book:              ISBN                                         Book-Title  \
# 7316  0671010115  GONE FISHIN : Featuring an Original Easy Rawli...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 7316    w mosley                1998         Pocket
#
#                                            Title-Tokens Author-Tokens  \
# 7316  [gone, fishin, featuring, original, easy, rawl...   [w, mosley]
#
#      Publisher-Tokens
# 7316         [Pocket]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.24
#
# Choosen book:               ISBN                                Book-Title Book-Author  \
# 19353  0671035576  The New Yorker Book of Literary Cartoons   b mankoff
#
#       Year-Of-Publication Book-Publisher  \
# 19353                2000          Atria
#
#                                  Title-Tokens Author-Tokens Publisher-Tokens
# 19353  [new, yorker, book, literary, cartoon]  [b, mankoff]          [Atria]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.65
#
# Choosen book:               ISBN    Book-Title Book-Author Year-Of-Publication  \
# 15916  0446605050  The Intruder   p blauner                1997
#
#       Book-Publisher Title-Tokens Author-Tokens Publisher-Tokens
# 15916   Warner Books   [intruder]  [p, blauner]  [Warner, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.04
#
# Choosen book:              ISBN     Book-Title Book-Author Year-Of-Publication  \
# 1215  0446527165  Wish You Well  d baldacci                2000
#
#      Book-Publisher  Title-Tokens  Author-Tokens Publisher-Tokens
# 1215   Warner Books  [wish, well]  [d, baldacci]  [Warner, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.73
#
# Choosen book:               ISBN              Book-Title Book-Author Year-Of-Publication  \
# 10774  0440984459  The Sword in the Stone    th white                1978
#
#       Book-Publisher    Title-Tokens Author-Tokens Publisher-Tokens
# 10774     Laure Leaf  [sword, stone]   [th, white]    [Laure, Leaf]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 3.60
#
# Choosen book:              ISBN                                         Book-Title  \
# 8256  074347676X  The League of Extraordinary Gentlemen (Movie N...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 8256  kj anderson                2003    Pocket Star
#
#                                            Title-Tokens   Author-Tokens  \
# 8256  [league, extraordinary, gentleman, movie, nove...  [kj, anderson]
#
#      Publisher-Tokens
# 8256   [Pocket, Star]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.09
#
# Choosen book:              ISBN     Book-Title Book-Author Year-Of-Publication  \
# 2484  0515130389  Carolina Moon   n roberts                2001
#
#      Book-Publisher      Title-Tokens Author-Tokens Publisher-Tokens
# 2484     Jove Books  [carolina, moon]  [n, roberts]    [Jove, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.82
#
# Choosen book:               ISBN     Book-Title Book-Author Year-Of-Publication  \
# 18099  0821725025  Dakota Dreams   c obanyon                1988
#
#       Book-Publisher     Title-Tokens Author-Tokens Publisher-Tokens
# 18099    Zebra Books  [dakota, dream]  [c, obanyon]   [Zebra, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.92
#
# Choosen book:               ISBN                                      Book-Title Book-Author  \
# 12518  0449001504  The Wonder Worker (Ballantine Reader's Circle)   s howatch
#
#       Year-Of-Publication    Book-Publisher  \
# 12518                1998  Ballantine Books
#
#                                        Title-Tokens Author-Tokens  \
# 12518  [wonder, worker, ballantine, reader, circle]  [s, howatch]
#
#           Publisher-Tokens
# 12518  [Ballantine, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.04
#
# Choosen book:               ISBN      Book-Title  Book-Author Year-Of-Publication  \
# 11746  0451179897  House of Smoke  jf freedman                1996
#
#       Book-Publisher    Title-Tokens   Author-Tokens Publisher-Tokens
# 11746    Signet Book  [house, smoke]  [jf, freedman]   [Signet, Book]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.85
#
# Choosen book:              ISBN   Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 2529  0553265741  Sacred Sins   n roberts                1990   Bantam Books
#
#        Title-Tokens Author-Tokens Publisher-Tokens
# 2529  [sacred, sin]  [n, roberts]  [Bantam, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.30
#
# Choosen book:              ISBN                 Book-Title Book-Author Year-Of-Publication  \
# 5927  0679761837  A Natural History of Love  d ackerman                1995
#
#          Book-Publisher              Title-Tokens  Author-Tokens  \
# 5927  Vintage Books USA  [natural, history, love]  [d, ackerman]
#
#            Publisher-Tokens
# 5927  [Vintage, Books, USA]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.84
#
# Choosen book:               ISBN  Book-Title       Book-Author Year-Of-Publication  \
# 13574  344245204X  Livealbum.  bv stuckradbarre                2002
#
#       Book-Publisher Title-Tokens        Author-Tokens Publisher-Tokens
# 13574       Goldmann  [livealbum]  [bv, stuckradbarre]       [Goldmann]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.29
#
# Choosen book:              ISBN                                        Book-Title  \
# 4412  1852305606  Encyclopedia of Celtic Wisdom the Celtic Shamans
#
#      Book-Author Year-Of-Publication     Book-Publisher  \
# 4412  c matthews                2002  Element Books Inc
#
#                                         Title-Tokens  Author-Tokens  \
# 4412  [encyclopedia, celtic, wisdom, celtic, shaman]  [c, matthews]
#
#            Publisher-Tokens
# 4412  [Element, Books, Inc]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.69
#
# Choosen book:               ISBN                                         Book-Title  \
# 16254  0679724656  Beyond Good and Evil: Prelude to a Philosophy ...
#
#        Book-Author Year-Of-Publication     Book-Publisher  \
# 16254  f nietzsche                1989  Vintage Books USA
#
#                                             Title-Tokens   Author-Tokens  \
# 16254  [beyond, good, evil, prelude, philosophy, future]  [f, nietzsche]
#
#             Publisher-Tokens
# 16254  [Vintage, Books, USA]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.59
#
# Choosen book:              ISBN  Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 8567  0441167306  Dream Park     l niven                2003      Ace Books
#
#        Title-Tokens Author-Tokens Publisher-Tokens
# 8567  [dream, park]    [l, niven]     [Ace, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.10
#
# Choosen book:               ISBN                                         Book-Title  \
# 22118  0375504966  The Barbary Plague : The Black Death in Victor...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 22118     m chase                2003   Random House
#
#                                             Title-Tokens Author-Tokens  \
# 22118  [barbary, plague, black, death, victorian, san...    [m, chase]
#
#       Publisher-Tokens
# 22118  [Random, House]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.13
#
# Choosen book:              ISBN               Book-Title Book-Author Year-Of-Publication  \
# 6872  0671003518  The BRIDE - PROMOTIONAL   j garwood                1996
#
#      Book-Publisher          Title-Tokens Author-Tokens Publisher-Tokens
# 6872         Pocket  [bride, promotional]  [j, garwood]         [Pocket]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.61
#
# Choosen book:              ISBN                                         Book-Title  \
# 1884  0452284503  Oh, the Things I Know!: A Guide to Success, Or...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 1884   a franken                2003    Plume Books
#
#                                            Title-Tokens Author-Tokens  \
# 1884  [oh, thing, know, guide, success, failing, hap...  [a, franken]
#
#      Publisher-Tokens
# 1884   [Plume, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.14
#
# Choosen book:              ISBN Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 3611  0671441981  GHOST STY    p straub                1981         Pocket
#
#       Title-Tokens Author-Tokens Publisher-Tokens
# 3611  [ghost, sty]   [p, straub]         [Pocket]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.02
#
# Choosen book:              ISBN                                         Book-Title  \
# 4856  0060578955  The Way the Crow Flies: A Novel (Today Show Bo...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 4856  a macdonald                2003  HarperCollins
#
#                                            Title-Tokens   Author-Tokens  \
# 4856  [way, crow, fly, novel, today, show, book, clu...  [a, macdonald]
#
#      Publisher-Tokens
# 4856  [HarperCollins]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.87
#
# Choosen book:              ISBN                 Book-Title Book-Author Year-Of-Publication  \
# 2711  0316666343  The Lovely Bones: A Novel    a sebold                2002
#
#      Book-Publisher           Title-Tokens Author-Tokens    Publisher-Tokens
# 2711  Little, Brown  [lovely, bone, novel]   [a, sebold]  [Little, ,, Brown]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.49
#
# Choosen book:               ISBN           Book-Title Book-Author Year-Of-Publication  \
# 19060  1931514607  Paradise Kiss Vol 1    a yazawa                2002
#
#       Book-Publisher              Title-Tokens Author-Tokens Publisher-Tokens
# 19060       Tokyopop  [paradise, kiss, vol, 1]   [a, yazawa]       [Tokyopop]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.45
#
# Choosen book:               ISBN   Book-Title Book-Author Year-Of-Publication  \
# 15702  0394744209  The Assault   h mulisch                1986
#
#        Book-Publisher Title-Tokens Author-Tokens   Publisher-Tokens
# 15702  Pantheon Books    [assault]  [h, mulisch]  [Pantheon, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.11
#
# Choosen book:               ISBN         Book-Title Book-Author Year-Of-Publication  \
# 22946  0440217261  California Gothic  d etchison                1995
#
#                 Book-Publisher          Title-Tokens  Author-Tokens  \
# 22946  Dell Publishing Company  [california, gothic]  [d, etchison]
#
#                   Publisher-Tokens
# 22946  [Dell, Publishing, Company]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.58
#
# Choosen book:            ISBN                               Book-Title Book-Author  \
# 10  0399150749  The Opposite of Fate: A Book of Musings       a tan
#
#    Year-Of-Publication       Book-Publisher                    Title-Tokens  \
# 10                2003  G. P. Putnam's Sons  [opposite, fate, book, musing]
#
#    Author-Tokens            Publisher-Tokens
# 10      [a, tan]  [G., P., Putnam, 's, Sons]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.82
#
# Choosen book:               ISBN                                         Book-Title  \
# 20389  0553801031  The New Rabbi : A Congregation Searches for It...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 20389     s fried                2002         Bantam
#
#                                      Title-Tokens Author-Tokens  \
# 20389  [new, rabbi, congregation, search, leader]    [s, fried]
#
#       Publisher-Tokens
# 20389         [Bantam]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.99
#
# Choosen book:              ISBN                                         Book-Title  \
# 8313  0756401364  Long Hot Summoning (The Keeper's Chronicles, N...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 8313      t huff                2003      Daw Books
#
#                                            Title-Tokens Author-Tokens  \
# 8313  [long, hot, summoning, keeper, chronicle, numb...     [t, huff]
#
#      Publisher-Tokens
# 8313     [Daw, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.97
#
# Choosen book:              ISBN                                     Book-Title Book-Author  \
# 8378  0886779065  Mountain of Black Glass (Otherland, Volume 3)  t williams
#
#      Year-Of-Publication Book-Publisher  \
# 8378                2000      Daw Books
#
#                                         Title-Tokens  Author-Tokens  \
# 8378  [mountain, black, glass, otherland, volume, 3]  [t, williams]
#
#      Publisher-Tokens
# 8378     [Daw, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 3.99
#
# Choosen book:              ISBN  Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 1332  0553211374  Persuasion    j austen                1984   Bantam Books
#
#       Title-Tokens Author-Tokens Publisher-Tokens
# 1332  [persuasion]   [j, austen]  [Bantam, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.43
#
# Choosen book:               ISBN                  Book-Title Book-Author Year-Of-Publication  \
# 16603  0091831032  The last time I saw mother     aj chai                1995
#
#                Book-Publisher               Title-Tokens Author-Tokens  \
# 16603  Random House Australia  [last, time, saw, mother]    [aj, chai]
#
#                  Publisher-Tokens
# 16603  [Random, House, Australia]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.33
#
# Choosen book:               ISBN                                         Book-Title  \
# 16998  0425190064  The Thai Amulet: An Archaeological Mystery (Ar...
#
#       Book-Author Year-Of-Publication            Book-Publisher  \
# 16998  l hamilton                2003  Berkley Publishing Group
#
#                                             Title-Tokens  Author-Tokens  \
# 16998  [thai, amulet, archaeological, mystery, archae...  [l, hamilton]
#
#                    Publisher-Tokens
# 16998  [Berkley, Publishing, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.30
#
# Choosen book:              ISBN    Book-Title  Book-Author Year-Of-Publication  \
# 6617  055308013X  Private Eyes  j kellerman                1992
#
#              Book-Publisher    Title-Tokens   Author-Tokens  \
# 6617  Bantam Dell Pub Group  [private, eye]  [j, kellerman]
#
#                 Publisher-Tokens
# 6617  [Bantam, Dell, Pub, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.20
#
# Choosen book:               ISBN                Book-Title   Book-Author Year-Of-Publication  \
# 11855  0452281725  The Quilter's Apprentice  j chiaverini                2000
#
#       Book-Publisher            Title-Tokens    Author-Tokens Publisher-Tokens
# 11855    Plume Books  [quilters, apprentice]  [j, chiaverini]   [Plume, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.69
#
# Choosen book:               ISBN                                         Book-Title  \
# 15194  0380793660  Murder Gets a Life: : A Southern Sisters Myste...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 15194    a george                1999           Avon
#
#                                             Title-Tokens Author-Tokens  \
# 15194  [murder, get, life, southern, sister, mystery,...   [a, george]
#
#       Publisher-Tokens
# 15194           [Avon]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.39
#
# Choosen book:              ISBN             Book-Title  Book-Author Year-Of-Publication  \
# 2857  0345368924  All the Weyrs of Pern  a mccaffrey                1991
#
#         Book-Publisher   Title-Tokens   Author-Tokens     Publisher-Tokens
# 2857  Ballantine Books  [weyrs, pern]  [a, mccaffrey]  [Ballantine, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.27
#
# Choosen book:               ISBN                                         Book-Title  \
# 23147  1854582747  Work Your Way Around the World, 11th (Work You...
#
#       Book-Author Year-Of-Publication              Book-Publisher  \
# 23147  s griffith                2003  Vacation Work Publications
#
#                                             Title-Tokens  Author-Tokens  \
# 23147  [work, way, around, world, 11th, work, way, ar...  [s, griffith]
#
#                      Publisher-Tokens
# 23147  [Vacation, Work, Publications]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 3.44
#
# Choosen book:              ISBN              Book-Title Book-Author Year-Of-Publication  \
# 6726  0553579835  The Matarese Countdown    r ludlum                1998
#
#      Book-Publisher           Title-Tokens Author-Tokens Publisher-Tokens
# 6726   Bantam Books  [matarese, countdown]   [r, ludlum]  [Bantam, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.48
#
# Choosen book:               ISBN                 Book-Title Book-Author Year-Of-Publication  \
# 11004  843220708X  Donde El Corazon Te Lleve    s tamaro                1996
#
#               Book-Publisher                     Title-Tokens Author-Tokens  \
# 11004  Editorial Seix Barral  [donde, el, corazon, te, lleve]   [s, tamaro]
#
#                 Publisher-Tokens
# 11004  [Editorial, Seix, Barral]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.20
#
# Choosen book:              ISBN                                         Book-Title  \
# 8189  0060502312  Breaking All the Rules (Avon Light Contemporar...
#
#        Book-Author Year-Of-Publication Book-Publisher  \
# 8189  s civilbrown                2002           Avon
#
#                                            Title-Tokens    Author-Tokens  \
# 8189  [breaking, rule, avon, light, contemporary, ro...  [s, civilbrown]
#
#      Publisher-Tokens
# 8189           [Avon]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.42
#
# Choosen book:              ISBN                                Book-Title Book-Author  \
# 1448  0345352467  Centaur Aisle (Xanth Novels (Paperback))   p anthony
#
#      Year-Of-Publication Book-Publisher                    Title-Tokens  \
# 1448                1990  Del Rey Books  [centaur, aisle, xanth, novel]
#
#      Author-Tokens   Publisher-Tokens
# 1448  [p, anthony]  [Del, Rey, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.24
#
# Choosen book:              ISBN               Book-Title Book-Author Year-Of-Publication  \
# 6590  0061007153  A Quiver Full of Arrows    j archer                1993
#
#      Book-Publisher           Title-Tokens Author-Tokens Publisher-Tokens
# 6590    HarperTorch  [quiver, full, arrow]   [j, archer]    [HarperTorch]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.22
#
# Choosen book:               ISBN                 Book-Title Book-Author Year-Of-Publication  \
# 16384  0425132617  The M. D.: A Horror Story    tm disch                1992
#
#                  Book-Publisher     Title-Tokens Author-Tokens  \
# 16384  Berkley Publishing Group  [horror, story]   [tm, disch]
#
#                    Publisher-Tokens
# 16384  [Berkley, Publishing, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.80
#
# Choosen book:               ISBN   Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 15734  0812504690  Jungle Book   r kipling                1992      Tor Books
#
#          Title-Tokens Author-Tokens Publisher-Tokens
# 15734  [jungle, book]  [r, kipling]     [Tor, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.90
#
# Choosen book:               ISBN                 Book-Title Book-Author Year-Of-Publication  \
# 11864  0743243803  The Partly Cloudy Patriot    s vowell                2003
#
#          Book-Publisher               Title-Tokens Author-Tokens  \
# 11864  Simon & Schuster  [partly, cloudy, patriot]   [s, vowell]
#
#            Publisher-Tokens
# 11864  [Simon, &, Schuster]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.43
#
# Choosen book:              ISBN                              Book-Title Book-Author  \
# 6183  0679736042  Toujours Provence (Vintage Departures)     p mayle
#
#      Year-Of-Publication     Book-Publisher  \
# 6183                1992  Vintage Books USA
#
#                                   Title-Tokens Author-Tokens  \
# 6183  [toujours, provence, vintage, departure]    [p, mayle]
#
#            Publisher-Tokens
# 6183  [Vintage, Books, USA]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.19
#
# Choosen book:             ISBN              Book-Title Book-Author Year-Of-Publication  \
# 982  0451150635  Different Seasons M/TV      s king                1986
#
#     Book-Publisher              Title-Tokens Author-Tokens Publisher-Tokens
# 982    Signet Book  [different, season, mtv]     [s, king]   [Signet, Book]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.51
#
# Choosen book:               ISBN                                         Book-Title  \
# 14965  0671032569  Vectors : Double Helix #2 (Star Trek: The Next...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 14965    dw smith                1999      Star Trek
#
#                                             Title-Tokens Author-Tokens  \
# 14965  [vector, double, helix, 2, star, trek, next, g...   [dw, smith]
#
#       Publisher-Tokens
# 14965     [Star, Trek]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.27
#
# Choosen book:               ISBN                               Book-Title Book-Author  \
# 17290  0312282702  The Big Dig: A Carlotta Carlyle Mystery    l barnes
#
#       Year-Of-Publication         Book-Publisher  \
# 17290                2002  St. Martin's Minotaur
#
#                                  Title-Tokens Author-Tokens  \
# 17290  [big, dig, carlotta, carlyle, mystery]   [l, barnes]
#
#                   Publisher-Tokens
# 17290  [St., Martin, 's, Minotaur]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.41
#
# Choosen book:              ISBN    Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 8132  0380800268  In Your Arms    r rogers                1999           Avon
#
#      Title-Tokens Author-Tokens Publisher-Tokens
# 8132        [arm]   [r, rogers]           [Avon]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.57
#
# Choosen book:               ISBN    Book-Title Book-Author Year-Of-Publication  \
# 14837  0385333757  Losing Julia      j hull                2000
#
#               Book-Publisher     Title-Tokens Author-Tokens  \
# 14837  Bantam Dell Pub Group  [losing, julia]     [j, hull]
#
#                  Publisher-Tokens
# 14837  [Bantam, Dell, Pub, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.12
#
# Choosen book:               ISBN   Book-Title Book-Author Year-Of-Publication  \
# 16229  1853260258  The Odyssey       homer                1998
#
#                             Book-Publisher Title-Tokens Author-Tokens  \
# 16229  NTC/Contemporary Publishing Company    [odyssey]       [homer]
#
#                               Publisher-Tokens
# 16229  [NTC/Contemporary, Publishing, Company]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.37
#
# Choosen book:              ISBN Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 7653  0451203593   24 Hours      g iles                2001    Signet Book
#
#      Title-Tokens Author-Tokens Publisher-Tokens
# 7653   [24, hour]     [g, iles]   [Signet, Book]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.80
#
# Choosen book:               ISBN      Book-Title Book-Author Year-Of-Publication  \
# 14445  042514898X  Hangman's Root   sw albert                1995
#
#                  Book-Publisher     Title-Tokens Author-Tokens  \
# 14445  Berkley Publishing Group  [hangman, root]  [sw, albert]
#
#                    Publisher-Tokens
# 14445  [Berkley, Publishing, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.72
#
# Choosen book:              ISBN                        Book-Title Book-Author  \
# 2253  0893754013  Frankenstein (Watermill Classic)  mw shelley
#
#      Year-Of-Publication        Book-Publisher  \
# 2253                1993  Troll Communications
#
#                             Title-Tokens  Author-Tokens  \
# 2253  [frankenstein, watermill, classic]  [mw, shelley]
#
#              Publisher-Tokens
# 2253  [Troll, Communications]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.96
#
# Choosen book:              ISBN Book-Title  Book-Author Year-Of-Publication Book-Publisher  \
# 5041  2070364283   La Perle  j steinbeck                1973      Gallimard
#
#      Title-Tokens   Author-Tokens Publisher-Tokens
# 5041  [la, perle]  [j, steinbeck]      [Gallimard]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.95
#
# Choosen book:               ISBN                                 Book-Title Book-Author  \
# 10043  0373122772  The Disobedient Mistress  (Sister Brides)    l graham
#
#       Year-Of-Publication Book-Publisher  \
# 10043                2002      Harlequin
#
#                                  Title-Tokens Author-Tokens Publisher-Tokens
# 10043  [disobedient, mistress, sister, bride]   [l, graham]      [Harlequin]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.25
#
# Choosen book:               ISBN                             Book-Title Book-Author  \
# 21371  0679743650  13th Gen: Abort, Retry, Ignore, Fail?      n howe
#
#       Year-Of-Publication     Book-Publisher  \
# 21371                1993  Vintage Books USA
#
#                                   Title-Tokens Author-Tokens  \
# 21371  [13th, gen, abort, retry, ignore, fail]     [n, howe]
#
#             Publisher-Tokens
# 21371  [Vintage, Books, USA]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.99
#
# Choosen book:               ISBN                              Book-Title  Book-Author  \
# 13274  0316353299  Blue Highways : A Journey into America  wl heatmoon
#
#       Year-Of-Publication  Book-Publisher                       Title-Tokens  \
# 13274                1999  Back Bay Books  [blue, highway, journey, america]
#
#         Author-Tokens    Publisher-Tokens
# 13274  [wl, heatmoon]  [Back, Bay, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.88
#
# Choosen book:              ISBN Book-Title Book-Author Year-Of-Publication  \
# 5660  0671038184      Jewel      b lott                1999
#
#                Book-Publisher Title-Tokens Author-Tokens  \
# 5660  Washington Square Press      [jewel]     [b, lott]
#
#                  Publisher-Tokens
# 5660  [Washington, Square, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.99
#
# Choosen book:               ISBN  Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 12483  0765342308  Briar Rose     j yolen                2002       Tor Teen
#
#         Title-Tokens Author-Tokens Publisher-Tokens
# 12483  [briar, rose]    [j, yolen]      [Tor, Teen]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.02
#
# Choosen book:              ISBN             Book-Title Book-Author Year-Of-Publication  \
# 3189  0553289063  An Inconvenient Woman     d dunne                1991
#
#      Book-Publisher           Title-Tokens Author-Tokens Publisher-Tokens
# 3189   Bantam Books  [inconvenient, woman]    [d, dunne]  [Bantam, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.65
#
# Choosen book:               ISBN                                         Book-Title  \
# 15547  0671038869  The Long Program : Skating Toward Life's Victo...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 15547   p fleming                1999          Atria
#
#                                           Title-Tokens Author-Tokens  \
# 15547  [long, program, skating, toward, life, victory]  [p, fleming]
#
#       Publisher-Tokens
# 15547          [Atria]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.09
#
# Choosen book:              ISBN    Book-Title  Book-Author Year-Of-Publication  \
# 8164  0380808307  Just Imagine  se phillips                2001
#
#      Book-Publisher Title-Tokens   Author-Tokens Publisher-Tokens
# 8164           Avon    [imagine]  [se, phillips]           [Avon]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.93
#
# Choosen book:              ISBN                         Book-Title Book-Author  \
# 9410  0816725594  Secret Garden (Watermill Classic)  fh burnett
#
#      Year-Of-Publication        Book-Publisher  \
# 9410                1995  Troll Communications
#
#                               Title-Tokens  Author-Tokens  \
# 9410  [secret, garden, watermill, classic]  [fh, burnett]
#
#              Publisher-Tokens
# 9410  [Troll, Communications]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 3.61
#
# Choosen book:               ISBN                                         Book-Title  \
# 22948  059088008X  The Case of the U. S. Space Camp Mission (The ...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 22948     s staff                1996     Scholastic
#
#                                             Title-Tokens Author-Tokens  \
# 22948  [case, u, space, camp, mission, adventure, mar...    [s, staff]
#
#       Publisher-Tokens
# 22948     [Scholastic]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.41
#
# Choosen book:               ISBN            Book-Title Book-Author Year-Of-Publication  \
# 21753  0446394777  College Dorm Workout   jl vedral                1994
#
#       Book-Publisher              Title-Tokens Author-Tokens Publisher-Tokens
# 21753   Warner Books  [college, dorm, workout]  [jl, vedral]  [Warner, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.66
#
# Choosen book:              ISBN         Book-Title Book-Author Year-Of-Publication  \
# 9769  0440219760  The Transall Saga   g paulsen                1999
#
#      Book-Publisher      Title-Tokens Author-Tokens Publisher-Tokens
# 9769    Laurel Leaf  [transall, saga]  [g, paulsen]   [Laurel, Leaf]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.81
#
# Choosen book:             ISBN              Book-Title  Book-Author Year-Of-Publication  \
# 517  8845906884  Lo Hobbit / The Hobbit  jrr tolkien                2002
#
#     Book-Publisher          Title-Tokens   Author-Tokens Publisher-Tokens
# 517    Distribooks  [lo, hobbit, hobbit]  [jrr, tolkien]    [Distribooks]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.40
#
# Choosen book:               ISBN                           Book-Title Book-Author  \
# 10778  0380781042  Grail (The Pendragon Cycle, Book 5)  sr lawhead
#
#       Year-Of-Publication Book-Publisher                        Title-Tokens  \
# 10778                1998            Eos  [grail, pendragon, cycle, book, 5]
#
#        Author-Tokens Publisher-Tokens
# 10778  [sr, lawhead]            [Eos]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.51
#
# Choosen book:               ISBN                                  Book-Title Book-Author  \
# 22699  0373054327  Moon Of The Raven (Silhouette Desire, 432)     j thies
#
#       Year-Of-Publication Book-Publisher  \
# 22699                1988     Silhouette
#
#                                  Title-Tokens Author-Tokens Publisher-Tokens
# 22699  [moon, raven, silhouette, desire, 432]    [j, thies]     [Silhouette]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.47
#
# Choosen book:              ISBN                                   Book-Title Book-Author  \
# 8130  0380806304  Surrender to Love (Avon Historical Romance)    r rogers
#
#      Year-Of-Publication Book-Publisher  \
# 8130                1982           Avon
#
#                                       Title-Tokens Author-Tokens  \
# 8130  [surrender, love, avon, historical, romance]   [r, rogers]
#
#      Publisher-Tokens
# 8130           [Avon]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.62
#
# Choosen book:              ISBN Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 5188  0452264014     Fences    a wilson                1995    Plume Books
#
#      Title-Tokens Author-Tokens Publisher-Tokens
# 5188      [fence]   [a, wilson]   [Plume, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.84
#
# Choosen book:              ISBN                                         Book-Title  \
# 8636  0060004533  The Neal Pollack Anthology of American Literat...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 8636   n pollack                2002      Perennial
#
#                                            Title-Tokens Author-Tokens  \
# 8636  [neal, pollack, anthology, american, literatur...  [n, pollack]
#
#      Publisher-Tokens
# 8636      [Perennial]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.88
#
# Choosen book:              ISBN                Book-Title Book-Author Year-Of-Publication  \
# 5696  0754022471  Notes from a Big Country    b bryson                2000
#
#          Book-Publisher          Title-Tokens Author-Tokens  \
# 5696  Chivers Press Ltd  [note, big, country]   [b, bryson]
#
#            Publisher-Tokens
# 5696  [Chivers, Press, Ltd]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.03
#
# Choosen book:              ISBN      Book-Title Book-Author Year-Of-Publication  \
# 8150  050552502X  Silken Bondage      n ryan                2002
#
#      Book-Publisher       Title-Tokens Author-Tokens Publisher-Tokens
# 8150     Love Spell  [silken, bondage]     [n, ryan]    [Love, Spell]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.55
#
# Choosen book:               ISBN                       Book-Title Book-Author  \
# 20225  0385510098  Fagin the Jew : A Graphic Novel    w eisner
#
#       Year-Of-Publication Book-Publisher                  Title-Tokens  \
# 20225                2003      Doubleday  [fagin, jew, graphic, novel]
#
#       Author-Tokens Publisher-Tokens
# 20225   [w, eisner]      [Doubleday]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.43
#
# Choosen book:               ISBN                       Book-Title Book-Author  \
# 13550  0684849690  The SECRET DIARY OF ANNE BOLEYN   r maxwell
#
#       Year-Of-Publication Book-Publisher                   Title-Tokens  \
# 13550                1998     Touchstone  [secret, diary, anne, boleyn]
#
#       Author-Tokens Publisher-Tokens
# 13550  [r, maxwell]     [Touchstone]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.13
#
# Choosen book:               ISBN                       Book-Title Book-Author  \
# 21306  0373790139  Just A Little Sex... (Blaze, 9)       m lee
#
#       Year-Of-Publication Book-Publisher             Title-Tokens  \
# 21306                2001      Harlequin  [little, sex, blaze, 9]
#
#       Author-Tokens Publisher-Tokens
# 21306      [m, lee]      [Harlequin]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.38
#
# Choosen book:               ISBN               Book-Title Book-Author Year-Of-Publication  \
# 14285  0743235053  Haunted Ground: A Novel      e hart                2003
#
#       Book-Publisher              Title-Tokens Author-Tokens Publisher-Tokens
# 14285       Scribner  [haunted, ground, novel]     [e, hart]       [Scribner]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.33
#
# Choosen book:              ISBN                                         Book-Title  \
# 7798  0684833778  The BODACIOUS BOOK OF SUCCULENCE : DARING TO L...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 7798        sark                1998       Fireside
#
#                                            Title-Tokens Author-Tokens  \
# 7798  [bodacious, book, succulence, daring, live, su...        [sark]
#
#      Publisher-Tokens
# 7798       [Fireside]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.14
#
# Choosen book:               ISBN                                         Book-Title  \
# 20472  0375421726  Nigger - The Strange Career of a Troublesome Word
#
#       Book-Author Year-Of-Publication  Book-Publisher  \
# 20472   r kennedy                2002  Pantheon Books
#
#                                        Title-Tokens Author-Tokens  \
# 20472  [nigger, strange, career, troublesome, word]  [r, kennedy]
#
#         Publisher-Tokens
# 20472  [Pantheon, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.01
#
# Choosen book:               ISBN                          Book-Title Book-Author  \
# 11458  0394900189  Are You My Mother (Beginner Books)  pd eastman
#
#       Year-Of-Publication                        Book-Publisher  \
# 11458                1966  Random House Books for Young Readers
#
#                    Title-Tokens  Author-Tokens  \
# 11458  [mother, beginner, book]  [pd, eastman]
#
#                                   Publisher-Tokens
# 11458  [Random, House, Books, for, Young, Readers]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.86
#
# Choosen book:              ISBN             Book-Title Book-Author Year-Of-Publication  \
# 4699  0425096343  Be Buried in the Rain  b michaels                1990
#
#          Book-Publisher    Title-Tokens  Author-Tokens       Publisher-Tokens
# 4699  Berkley Pub Group  [buried, rain]  [b, michaels]  [Berkley, Pub, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.13
#
# Choosen book:               ISBN             Book-Title Book-Author Year-Of-Publication  \
# 17239  1565122038  Lamb in Love: A Novel     c brown                1999
#
#                        Book-Publisher         Title-Tokens Author-Tokens  \
# 17239  Algonquin Books of Chapel Hill  [lamb, love, novel]    [c, brown]
#
#                            Publisher-Tokens
# 17239  [Algonquin, Books, of, Chapel, Hill]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.45
#
# Choosen book:               ISBN Book-Title   Book-Author Year-Of-Publication Book-Publisher  \
# 22363  068984154X  Hard Love  e wittlinger                2001    Simon Pulse
#
#        Title-Tokens    Author-Tokens Publisher-Tokens
# 22363  [hard, love]  [e, wittlinger]   [Simon, Pulse]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.46
#
# Choosen book:               ISBN                                  Book-Title   Book-Author  \
# 12016  0140622160  Selected Poetry (Penguin Popular Classics)  w wordsworth
#
#       Year-Of-Publication     Book-Publisher  \
# 12016                1996  Penguin Books Ltd
#
#                                         Title-Tokens    Author-Tokens  \
# 12016  [selected, poetry, penguin, popular, classic]  [w, wordsworth]
#
#             Publisher-Tokens
# 12016  [Penguin, Books, Ltd]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.33
#
# Choosen book:               ISBN                                         Book-Title  \
# 22233  0684869543  The Official eBay Guide to Buying, Selling, an...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 22233   lf kaiser                1999       Fireside
#
#                                             Title-Tokens Author-Tokens  \
# 22233  [official, ebay, guide, buying, selling, colle...  [lf, kaiser]
#
#       Publisher-Tokens
# 22233       [Fireside]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.29
#
# Choosen book:               ISBN            Book-Title Book-Author Year-Of-Publication  \
# 17773  042518384X  Death at Epsom Downs     r paige                2002
#
#                  Book-Publisher          Title-Tokens Author-Tokens  \
# 17773  Berkley Publishing Group  [death, epsom, down]    [r, paige]
#
#                    Publisher-Tokens
# 17773  [Berkley, Publishing, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.66
#
# Choosen book:               ISBN                                 Book-Title Book-Author  \
# 22807  0064407373  Little House by Boston Bay (Little House)     m wiley
#
#       Year-Of-Publication Book-Publisher  \
# 22807                1999   HarperTrophy
#
#                                       Title-Tokens Author-Tokens  \
# 22807  [little, house, boston, bay, little, house]    [m, wiley]
#
#       Publisher-Tokens
# 22807   [HarperTrophy]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.28
#
# Choosen book:               ISBN                Book-Title Book-Author Year-Of-Publication  \
# 18419  0762101067  Best of Sisters In Crime   m wallace                1993
#
#                     Book-Publisher           Title-Tokens Author-Tokens  \
# 18419  Penguin Putnam~childrens Hc  [best, sister, crime]  [m, wallace]
#
#                       Publisher-Tokens
# 18419  [Penguin, Putnam~childrens, Hc]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 3.94
#
# Choosen book:               ISBN                                         Book-Title  \
# 21450  0670891622  A Massive Swelling:  Celebrity Re-Examined As ...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 21450    c wilson                2000   Viking Books
#
#                                             Title-Tokens Author-Tokens  \
# 21450  [massive, swelling, celebrity, reexamined, gro...   [c, wilson]
#
#       Publisher-Tokens
# 21450  [Viking, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.15
#
# Choosen book:               ISBN           Book-Title Book-Author Year-Of-Publication  \
# 19396  0862321107  Woman at Point Zero  ne saadawi                1984
#
#       Book-Publisher          Title-Tokens  Author-Tokens Publisher-Tokens
# 19396      Zed Books  [woman, point, zero]  [ne, saadawi]     [Zed, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.59
#
# Choosen book:              ISBN          Book-Title Book-Author Year-Of-Publication  \
# 2360  0880291230  Roald Dahl Omnibus      r dahl                1987
#
#      Book-Publisher            Title-Tokens Author-Tokens  Publisher-Tokens
# 2360  Marboro Books  [roald, dahl, omnibus]     [r, dahl]  [Marboro, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.87
#
# Choosen book:               ISBN                      Book-Title Book-Author  \
# 19378  0452283221  A Perfect Arrangement: A Novel     s berne
#
#       Year-Of-Publication Book-Publisher                   Title-Tokens  \
# 19378                2002    Plume Books  [perfect, arrangement, novel]
#
#       Author-Tokens Publisher-Tokens
# 19378    [s, berne]   [Plume, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.06
#
# Choosen book:               ISBN                           Book-Title Book-Author  \
# 13338  044096895X  The Pistachio Prescription: A Novel  p danziger
#
#       Year-Of-Publication Book-Publisher                      Title-Tokens  \
# 13338                1978   Bantam Books  [pistachio, prescription, novel]
#
#        Author-Tokens Publisher-Tokens
# 13338  [p, danziger]  [Bantam, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.33
#
# Choosen book:               ISBN                                         Book-Title  \
# 20252  0156005743  A Book of Luminous Things: An International An...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 20252    c milosz                1998  Harvest Books
#
#                                             Title-Tokens Author-Tokens  \
# 20252  [book, luminous, thing, international, antholo...   [c, milosz]
#
#        Publisher-Tokens
# 20252  [Harvest, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.01
#
# Choosen book:              ISBN   Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# ...
#
#           Book-Publisher            Title-Tokens Author-Tokens  \
# 11676  Alianza Editorial  [el, libro, de, arena]  [jl, borges]
#
#            Publisher-Tokens
# 11676  [Alianza, Editorial]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.76
#
# Choosen book:              ISBN                                         Book-Title  \
# 3225  0425194523  Raise the Titanic (Dirk Pitt Adventures (Paper...
#
#      Book-Author Year-Of-Publication            Book-Publisher  \
# 3225   c cussler                2004  Berkley Publishing Group
#
#                                  Title-Tokens Author-Tokens  \
# 3225  [raise, titanic, dirk, pitt, adventure]  [c, cussler]
#
#                   Publisher-Tokens
# 3225  [Berkley, Publishing, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.76
#
# Choosen book:              ISBN        Book-Title Book-Author Year-Of-Publication  \
# 7621  0399142487  McNally's Gamble   l sanders                1997
#
#                Book-Publisher        Title-Tokens Author-Tokens  \
# 7621  Putnam Publishing Group  [mcnallys, gamble]  [l, sanders]
#
#                  Publisher-Tokens
# 7621  [Putnam, Publishing, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.68
#
# Choosen book:              ISBN                                       Book-Title Book-Author  \
# 2493  0515132020  Heaven and Earth (Three Sisters Island Trilogy)   n roberts
#
#      Year-Of-Publication Book-Publisher  \
# 2493                2003     Jove Books
#
#                                          Title-Tokens Author-Tokens  \
# 2493  [heaven, earth, three, sister, island, trilogy]  [n, roberts]
#
#      Publisher-Tokens
# 2493    [Jove, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.89
#
# Choosen book:               ISBN                                         Book-Title  \
# 17255  0590446894  The Magic School Bus in the Time of the Dinosa...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 17255      j cole                1995     Scholastic
#
#                                             Title-Tokens Author-Tokens  \
# 17255  [magic, school, bus, time, dinosaur, magic, sc...     [j, cole]
#
#       Publisher-Tokens
# 17255     [Scholastic]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.95
#
# Choosen book:               ISBN                                  Book-Title Book-Author  \
# 23179  0811826880  Up to No Good: The Rascally Things Boys Do    k harmon
#
#       Year-Of-Publication   Book-Publisher                  Title-Tokens  \
# 23179                2000  Chronicle Books  [good, rascally, thing, boy]
#
#       Author-Tokens    Publisher-Tokens
# 23179   [k, harmon]  [Chronicle, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.75
#
# Choosen book:               ISBN   Book-Title Book-Author Year-Of-Publication  \
# 22269  0385485522  Buddha Kiss    p tasker                1997
#
#               Book-Publisher    Title-Tokens Author-Tokens  \
# 22269  Bantam Dell Pub Group  [buddha, kiss]   [p, tasker]
#
#                  Publisher-Tokens
# 22269  [Bantam, Dell, Pub, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.66
#
# Choosen book:               ISBN                                  Book-Title Book-Author  \
# 11418  0345439112  All Is Vanity (Ballantine Reader's Circle)   c schwarz
#
#       Year-Of-Publication    Book-Publisher  \
# 11418                2003  Ballantine Books
#
#                                Title-Tokens Author-Tokens     Publisher-Tokens
# 11418  [vanity, ballantine, reader, circle]  [c, schwarz]  [Ballantine, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.94
#
# Choosen book:              ISBN   Book-Title Book-Author Year-Of-Publication  \
# 9009  0345313909  Naked Sun 2    i asimov                1983
#
#         Book-Publisher     Title-Tokens Author-Tokens     Publisher-Tokens
# 9009  Ballantine Books  [naked, sun, 2]   [i, asimov]  [Ballantine, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.99
#
# Choosen book:               ISBN                                         Book-Title  \
# 12319  0312315228  Atkins for Life: The Complete Controlled Carb ...
#
#       Book-Author Year-Of-Publication      Book-Publisher  \
# 12319   rc atkins                2003  St. Martin's Press
#
#                                             Title-Tokens Author-Tokens  \
# 12319  [atkins, life, complete, controlled, carb, pro...  [rc, atkins]
#
#                Publisher-Tokens
# 12319  [St., Martin, 's, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.00
#
# Choosen book:               ISBN                  Book-Title Book-Author Year-Of-Publication  \
# 11697  0345260627  Splinter of the Mind's Eye   ad foster                1978
#
#          Book-Publisher           Title-Tokens Author-Tokens  \
# 11697  Ballantine Books  [splinter, mind, eye]  [ad, foster]
#
#           Publisher-Tokens
# 11697  [Ballantine, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 3.99
#
# Choosen book:               ISBN                                         Book-Title  \
# 15884  0671797042  Sins of Commission (Star Trek The Next Generat...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 15884    s wright                1994      Star Trek
#
#                                             Title-Tokens Author-Tokens  \
# 15884  [sin, commission, star, trek, next, generation...   [s, wright]
#
#       Publisher-Tokens
# 15884     [Star, Trek]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.32
#
# Choosen book:               ISBN         Book-Title Book-Author Year-Of-Publication  \
# 23233  1575660679  Apache Temptation   jr hudson                1996
#
#                           Book-Publisher          Title-Tokens Author-Tokens  \
# 23233  Kensington Publishing Corporation  [apache, temptation]  [jr, hudson]
#
#                             Publisher-Tokens
# 23233  [Kensington, Publishing, Corporation]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.59
#
# Choosen book:               ISBN                        Book-Title Book-Author  \
# 17494  0140278702  Lucky Jim (Essential.penguin S.)      k amis
#
#       Year-Of-Publication     Book-Publisher  \
# 17494                1998  Penguin Books Ltd
#
#                            Title-Tokens Author-Tokens       Publisher-Tokens
# 17494  [lucky, jim, essential, penguin]     [k, amis]  [Penguin, Books, Ltd]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.93
#
# Choosen book:              ISBN          Book-Title Book-Author Year-Of-Publication  \
# 9725  0394743180  A room with a view  em forster                1986
#
#      Book-Publisher  Title-Tokens  Author-Tokens  Publisher-Tokens
# 9725  Vintage Books  [room, view]  [em, forster]  [Vintage, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.34
#
# Choosen book:              ISBN                                  Book-Title Book-Author  \
# 9930  0671017136  Halloween Rain  (Buffy the Vampire Slayer)    c golden
#
#      Year-Of-Publication                 Book-Publisher  \
# 9930                1997  Simon Spotlight Entertainment
#
#                                    Title-Tokens Author-Tokens  \
# 9930  [halloween, rain, buffy, vampire, slayer]   [c, golden]
#
#                        Publisher-Tokens
# 9930  [Simon, Spotlight, Entertainment]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.37
#
# Choosen book:              ISBN       Book-Title    Book-Author Year-Of-Publication  \
# 7449  0671722638  HENRY IV PART 1  w shakespeare                1994
#
#                Book-Publisher          Title-Tokens     Author-Tokens  \
# 7449  Washington Square Press  [henry, iv, part, 1]  [w, shakespeare]
#
#                  Publisher-Tokens
# 7449  [Washington, Square, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.08
#
# Choosen book:               ISBN      Book-Title Book-Author Year-Of-Publication  \
# 11879  0441805833  Thieves' World    r asprin                1984
#
#             Book-Publisher    Title-Tokens Author-Tokens  \
# 11879  Penguin Putnam~mass  [thief, world]   [r, asprin]
#
#              Publisher-Tokens
# 11879  [Penguin, Putnam~mass]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.08
#
# Choosen book:               ISBN      Book-Title Book-Author Year-Of-Publication  \
# 15452  0553291955  The Thin Woman   d cannell                1992
#
#       Book-Publisher   Title-Tokens Author-Tokens Publisher-Tokens
# 15452      Crimeline  [thin, woman]  [d, cannell]      [Crimeline]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.38
#
# Choosen book:               ISBN                                         Book-Title  \
# 21971  1887374426  The Complete Candlemaker: Techniques, Projects...
#
#       Book-Author Year-Of-Publication       Book-Publisher  \
# 21971     n coney                1997  Sterling Pub Co Inc
#
#                                             Title-Tokens Author-Tokens  \
# 21971  [complete, candlemaker, technique, project, in...    [n, coney]
#
#                Publisher-Tokens
# 21971  [Sterling, Pub, Co, Inc]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.11
#
# Choosen book:              ISBN                                       Book-Title  \
# 7954  0439061644  The First Journey (Animorphs. Alternamorphs, 1)
#
#        Book-Author Year-Of-Publication                Book-Publisher  \
# 7954  ka applegate                1999  Apple Signature (Scholastic)
#
#                                        Title-Tokens    Author-Tokens  \
# 7954  [first, journey, animorphs, alternamorphs, 1]  [ka, applegate]
#
#                           Publisher-Tokens
# 7954  [Apple, Signature, (, Scholastic, )]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.31
#
# Choosen book:              ISBN                                         Book-Title  \
# 9976  0743400518  Avatar Book Two of Two (Star Trek: Deep Space ...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 9976    sd perry                2001      Star Trek
#
#                                            Title-Tokens Author-Tokens  \
# 9976  [avatar, book, two, two, star, trek, deep, spa...   [sd, perry]
#
#      Publisher-Tokens
# 9976     [Star, Trek]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.59
#
# Choosen book:              ISBN      Book-Title Book-Author Year-Of-Publication  \
# 6063  0375704558  Charlotte Gray    s faulks                2000
#
#          Book-Publisher       Title-Tokens Author-Tokens  \
# 6063  Vintage Books USA  [charlotte, gray]   [s, faulks]
#
#            Publisher-Tokens
# 6063  [Vintage, Books, USA]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.99
#
# Choosen book:               ISBN        Book-Title  Book-Author Year-Of-Publication  \
# 13615  0385493002  The Intuitionist  c whitehead                1999
#
#                Book-Publisher    Title-Tokens   Author-Tokens  \
# 13615  Anchor Books/Doubleday  [intuitionist]  [c, whitehead]
#
#                 Publisher-Tokens
# 13615  [Anchor, Books/Doubleday]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.12
#
# Choosen book:               ISBN             Book-Title Book-Author Year-Of-Publication  \
# 17216  0451401476  Sunglasses After Dark  na collins                1994
#
#               Book-Publisher      Title-Tokens  Author-Tokens  \
# 17216  New Amer Library (Mm)  [sunglass, dark]  [na, collins]
#
#                      Publisher-Tokens
# 17216  [New, Amer, Library, (, Mm, )]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.73
#
# Choosen book:              ISBN          Book-Title  Book-Author Year-Of-Publication  \
# 4755  0393319296  Invisible Monsters  c palahniuk                1999
#
#              Book-Publisher          Title-Tokens   Author-Tokens  \
# 4755  W.W. Norton & Company  [invisible, monster]  [c, palahniuk]
#
#                 Publisher-Tokens
# 4755  [W.W., Norton, &, Company]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.76
#
# Choosen book:              ISBN                          Book-Title Book-Author  \
# 2609  0061030244  Carpenter's Lady, The, NEW EDITION  b delinsky
#
#      Year-Of-Publication Book-Publisher                     Title-Tokens  \
# 2609                1999    HarperTorch  [carpenter, lady, new, edition]
#
#       Author-Tokens Publisher-Tokens
# 2609  [b, delinsky]    [HarperTorch]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.04
#
# Choosen book:               ISBN           Book-Title Book-Author Year-Of-Publication  \
# 13666  0786867647  Lucky Man: A Memoir      mj fox                2002
#
#       Book-Publisher          Title-Tokens Author-Tokens Publisher-Tokens
# 13666       Hyperion  [lucky, man, memoir]     [mj, fox]       [Hyperion]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.66
#
# Choosen book:               ISBN          Book-Title  Book-Author Year-Of-Publication  \
# 16991  0451458273  Archangel Protocol  l morehouse                2001
#
#       Book-Publisher           Title-Tokens   Author-Tokens Publisher-Tokens
# 16991            Roc  [archangel, protocol]  [l, morehouse]            [Roc]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.21
#
# Choosen book:               ISBN                                         Book-Title  \
# 19570  0062516582  The Legacy of Luna: The Story of a Tree, a Wom...
#
#       Book-Author Year-Of-Publication        Book-Publisher  \
# 19570     jb hill                2000  Harper San Francisco
#
#                                             Title-Tokens Author-Tokens  \
# 19570  [legacy, luna, story, tree, woman, struggle, s...    [jb, hill]
#
#                Publisher-Tokens
# 19570  [Harper, San, Francisco]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 3.48
#
# Choosen book:             ISBN       Book-Title Book-Author Year-Of-Publication  \
# 455  0375803483  Count Karlstein   p pullman                2000
#
#      Book-Publisher        Title-Tokens Author-Tokens   Publisher-Tokens
# 455  Yearling Books  [count, karlstein]  [p, pullman]  [Yearling, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.42
#
# Choosen book:              ISBN    Book-Title  Book-Author Year-Of-Publication  \
# 1114  0380700247  The Ghostway  t hillerman                1991
#
#      Book-Publisher Title-Tokens   Author-Tokens Publisher-Tokens
# 1114     Avon Books   [ghostway]  [t, hillerman]    [Avon, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.20
# R-squared: -4.52
# Mean Squared Error: 5.49
# Root Mean Squared Error: 2.34
# Mean Absolute Error: 2.02
