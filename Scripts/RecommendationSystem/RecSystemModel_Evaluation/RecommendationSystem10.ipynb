# %%
import numpy as np
import pandas as pd
import nltk
import os
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

for dirname, _, filenames in os.walk('../../Data-Files/Raw-Files'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/EODP2/BX-NewBooksRatings.csv
# /content/EODP2/BX-Books.csv
# /content/EODP2/BX-NewBooks.csv
# /content/EODP2/BX-Users.csv
# /content/EODP2/BX-NewBooksUsers.csv
# /content/EODP2/BX-Ratings.csv
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
import re

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer


def load_data(input_path):
    # Load and return all datasets
    ratings = pd.read_csv(os.path.join(input_path, 'BX-Ratings.csv'))
    new_ratings = pd.read_csv(os.path.join(input_path, 'BX-NewBooksRatings.csv'))
    books_old = pd.read_csv(os.path.join(input_path, 'BX-Books.csv'))
    new_books = pd.read_csv(os.path.join(input_path, 'BX-NewBooks.csv'))
    books = pd.concat([books_old, new_books]).drop_duplicates(subset=["Book-Title"], keep='first')
    ratings = pd.concat([ratings, new_ratings])
    return ratings, books

"""Function for age string preprocessing"""
def onlyNumber(age):
  try:
      string_age = str(age)
      cleaned_age = int(re.sub(r'[^0-9]', '', string_age))
      if cleaned_age < 2 or cleaned_age> 123:
        #oldest person in the world is 122 years old and the youngest is 2 years old
          return np.nan
      return cleaned_age
  except:
      return np.nan

def has_special_characters(s):
  s = str(s)
  return any(ord(char) > 127 for char in s)

def abbreviate(s):
  text = s.split()
  new_string = []
  for i in range(len(text)):
      if i < (len(text) - 1):
          new_string.append(text[i][0])
      else:
          new_string.append(text[i])
  return ' '.join(new_string)

# Joins together consecutive single characters in a string
def process_strings(s):
  text = s.split()
  curr = ''
  new_words = []
  # joining together single letters
  for word in text:
      if len(word) == 1:
          curr += word
      else:
          if curr:
              new_words.append(curr)
              curr = ''
          new_words.append(word)

  if curr:
      new_words.append(curr)

  return ' '.join(new_words)

# Preprocesses titles
def title_preprocess(doc, stop_words, lemmatizer):
  doc = str(doc)
  doc = doc.lower()
  # Fixing special cases (periods with no spaces)
  doc_special = re.sub(r'\.(?=\w)', '. ', doc)

  # Removing all punctuation
  doc_punct = re.sub(r'[^A-Za-z0-9\s]', '', doc_special)

  # Remove all instances of 'paperback' in titles
  processed_doc = re.sub(r'paperback\s*', '', doc_punct)

  # Tokenising, removing stop words, then lemmatizing the tokens
  tokens = word_tokenize(processed_doc)
  tokens = [w for w in tokens if not w in stop_words]
  lemmatized = [lemmatizer.lemmatize(w) for w in tokens]

  return ' '.join(lemmatized)

# Preprocesses publishers
def publisher_preprocess(doc, stop_words, lemmatizer):
  doc = doc.lower()
  # Fixing special cases (periods with no spaces)
  doc_special = re.sub(r'\.(?=\w)', '. ', doc)

  # Removing all punctuation
  doc_punct = re.sub(r'[^A-Za-z0-9\s]', '', doc_special)

  # Join single characters (initials)
  doc_joined = process_strings(doc_punct)

  # Removing irrelevant words in publishers
  processed_doc = re.sub(r'\b(?:paperback|books|press|publishing|paperbacks)\b', '', doc_joined)

  # Tokenising, removing stop words, then lemmatizing the tokens
  tokens = word_tokenize(processed_doc)
  tokens = [w for w in tokens if not w in stop_words]
  lemmatized = [lemmatizer.lemmatize(w) for w in tokens]
  return ' '.join(lemmatized)

def prepare_data(books):

    # Filter out all non ASCII characters
    books = books[~books['Book-Title'].apply(has_special_characters)]
    books = books[~books['Book-Author'].apply(has_special_characters)]
    books = books[~books['Book-Publisher'].apply(has_special_characters)]

    # Book Title preprocessing steps
    # Initialising lemmatizer, stopwords, and tfidf
    lemmatizer = WordNetLemmatizer()
    stop_words = set(stopwords.words('english'))

    processed_titles = []
    for i, title in enumerate(books['Book-Title']):
        processed_titles.append(title_preprocess(title, stop_words,lemmatizer))
    books['Title-Tokens'] = [word_tokenize(t) for t in processed_titles]

    # Author preprocessing steps
    # Setting all author names to lowercase
    books['Book-Author'] = books['Book-Author'].astype(str)
    books['Book-Author'] = books['Book-Author'].apply(lambda x: x.lower())

    # Fixing special cases (periods with no spaces)
    author_special = books['Book-Author'].apply(lambda x: re.sub(r'\.(?=\w)', '. ', x))

    # Removing All punctuations
    author_punct = author_special.apply(lambda x: re.sub(r'[^A-Za-z\s]', '', x))

    # Abbreviating then joining together single letters into one word (for name initials)
    books['Book-Author'] = author_punct.apply(abbreviate)
    books['Book-Author'] = books['Book-Author'].apply(process_strings)
    books['Author-Tokens'] = books['Book-Author'].apply(word_tokenize)

    # Publishing Year Preprocessing Steps
    # Convert all years outside plausible range to 0
    books.loc[~books['Year-Of-Publication'].between(1920, 2005), 'Year-Of-Publication'] = 0
    filtered_books = books[books['Year-Of-Publication'] != 0]

    # Get average year of publication for each author
    publish_years = filtered_books.groupby('Book-Author')['Year-Of-Publication'].mean().reset_index()

    # Replace 0 values with corresponding author mean
    books = books.merge(publish_years, on='Book-Author', suffixes=('', '_mean'))
    books['Year-Of-Publication'] = books.apply(lambda row: row['Year-Of-Publication_mean']
        if row['Year-Of-Publication'] == 0 else row['Year-Of-Publication'], axis=1)

    books['Year-Of-Publication'] = books['Year-Of-Publication'].astype(int)
    books.drop(columns='Year-Of-Publication_mean', inplace=True)

    # Publisher Preprocessing Steps
    processed_publishers = []
    for i, title in enumerate(books['Book-Publisher']):
        processed_publishers.append(publisher_preprocess(title, stop_words,lemmatizer))

    books['Publisher-Tokens'] = books['Book-Publisher'].apply(word_tokenize)
    return books.drop_duplicates(subset=["Book-Title"], keep='first').dropna()

def combine_tokens(books):

    tokens = ["Year-Of-Publication-Tokens","Title-Tokens", "Author-Tokens", "Publisher-Tokens"]
    books["Year-Of-Publication-Tokens"] = books["Year-Of-Publication"].astype(str).apply(lambda x: [x])

    # Combine the token arrays from different columns into a single array
    books['Combined-Tokens'] = books[tokens].apply(lambda x: np.concatenate(x), axis=1)

    # Create a new DataFrame with 'ISBN' and 'Combined-Tokens' columns
    df_tokens = books[['ISBN', 'Combined-Tokens']]
    return df_tokens

def prepare_tfidf(books):

    df_tokens = combine_tokens(books)

    # Apply TF-IDF vectorization to the combined token column
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_matrix = tfidf_vectorizer.fit_transform(df_tokens['Combined-Tokens'].apply(lambda x: ' '.join(x)))

    # Create a DataFrame with TF-IDF values and 'ISBN' as the index
    df_tfidf = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out(), index=df_tokens['ISBN'])
    return df_tfidf

def prepare_vector(books):

    df_tokens = combine_tokens(books)
    cv = CountVectorizer(max_features=500, stop_words="english")
    vectors_matrix = cv.fit_transform(df_tokens["Combined-Tokens"].apply(lambda x: ' '.join(x)))
    df_vector = pd.DataFrame(vectors_matrix.toarray(), columns=cv.get_feature_names_out(), index=df_tokens['ISBN'])

    return df_vector

def find_similar_books(book_id, books, vector, recommend_number = 10):
    # Calculate similarity and find similar books

    similarity = cosine_similarity(vector)
    try:
        book_idx = books.index[books['ISBN'] == book_id].tolist()[0]
        #default is set at recommending 10 books this value will also affect predicted rating
        similar_books = sorted(list(enumerate(similarity[book_idx])), key=lambda x: x[1], reverse=True)[1:recommend_number]

        return similar_books

    except IndexError:
        print("Book ID not found in dataset.")

        return []

def recommend_books_vector(ratings, books, similar_books):
    # predicting books rating based on the cosine similarity scores of the vector based word processing

    rating_sims = []
    for idx, sim_score in similar_books:
        similar_isbn = books.iloc[idx]['ISBN']
        if similar_isbn in books['ISBN'].values:
            book_title = books.iloc[idx]['Book-Title']
            book_author = books.iloc[idx]['Book-Author']
            isbn_ratings = ratings[ratings["ISBN"] == similar_isbn]
            book_year = books.iloc[idx]['Year-Of-Publication']
            book_publisher = books.iloc[idx]['Book-Publisher']
            if not isbn_ratings.empty:
                mean_rating = isbn_ratings['Book-Rating'].mean()
                adjusted_score = mean_rating * sim_score
                rating_sims.append(float(adjusted_score))
    if rating_sims:
        average_adjusted_score = sum(rating_sims) / len(rating_sims)
        print(f"\nPredicted Rating: {average_adjusted_score:.2f}")

        return average_adjusted_score

def recommend_books_tfidf(ratings, books, similar_books):
    # Recommend books based on the cosine similarity scores of the tfidf based word processing

    for idx, sim_score in similar_books:
        similar_isbn = books.iloc[idx]['ISBN']
        if similar_isbn in books['ISBN'].values:
            book_title = books.iloc[idx]['Book-Title']
            book_author = books.iloc[idx]['Book-Author']
            isbn_ratings = ratings[ratings["ISBN"] == similar_isbn]
            book_year = books.iloc[idx]['Year-Of-Publication']
            book_publisher = books.iloc[idx]['Book-Publisher']
            if not isbn_ratings.empty:
                print(f"{book_title} by {book_author} published in {book_year} by {book_publisher}")

def recommend( wanted_book,books,ratings, recommend_state = False):
    print("\nChoosen book: ",wanted_book)
    added_books = pd.concat([books,wanted_book])
    books = prepare_data(added_books)

    print("\nPreprocessed data finished\n")
    wanted_ISBN = wanted_book.iloc[0]['ISBN']

    #These section is for the rating prediction
    vector = prepare_vector(books)
    print("Vectorized data finished\n")

    similar_books_vector = find_similar_books(wanted_ISBN, books, vector)

    # These section is for recommendation section
    if recommend_state:
      tfidf_books = prepare_data(added_books)
      tfidf = prepare_tfidf(tfidf_books)
      similar_books_tfidf = find_similar_books(wanted_ISBN, tfidf_books, tfidf)
    print("Find Similarity finished\n")

    if similar_books_vector:
        #this section will calculate and return the recommend books

        if recommend_state:
          print("\nRecommend Book\n")
          recommend_books_tfidf(ratings, tfidf_books, similar_books_tfidf)

        #this section will calculate and return the predicted value
        return recommend_books_vector(ratings, books, similar_books_vector)

"""This is the recommendation model that use cosine similarity to recommend
    book based on the user input book which it will give the predicted rating
    and give recommending books based on the tfidf vector. The recommend functionality
    is very computing intensive so it is set as False by default. However you can
    try and run it with the recommend_state = True like the following cell.
    """
def RecommendationSystem(wanted_book,books,ratings,recommend_state =False):

    return recommend(wanted_book,books,ratings,recommend_state)

# %%
#Please don't forget to provide the file path to the load_data
ratings, books = load_data('../../Data-Files/Raw-Files')
#It also recommend to run this program in cloud based ipynb as it is very computing intensive
#Our group use the kaggle and Google Colab to run these and the setting is cpu runtime type with high-ram
#if using the free version it will not run as it exceed googlecolab ram limit
RecommendationSystem((pd.DataFrame({'ISBN': ['0425163091'],
                                    'Book-Title': ['Chocolate Jesus'],
                                    'Book-Author': ['s jaramillo'],
                                    'Year-Of-Publication': [1998],
                                    'Book-Publisher': ['Berkley Publishing Group']})),
                     books,ratings,recommend_state =True)
# Out:
# Choosen book:           ISBN       Book-Title  Book-Author  Year-Of-Publication  \
# 0  0425163091  Chocolate Jesus  s jaramillo                 1998
#
#              Book-Publisher
# 0  Berkley Publishing Group
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Recommend Book
#
# Chocolate Quake by n fairbanks published in 2003 by Berkley Publishing Group
# Jesus Freaks: DC Talk and The Voice of the Martyrs - Stories of Those Who Stood For Jesus, the Ultimate Jesus Freaks by d talk published in 1999 by Bethany House Publishers
# Here on Earth by a hoffman published in 1998 by Berkley Publishing Group
# N or M? by a christie published in 1996 by Berkley Publishing Group
# Meeting Jesus Again for the First Time : The Historical Jesus and the Heart of Contemporary Faith by mj borg published in 1995 by HarperSanFrancisco
# Practical Magic by a hoffman published in 1998 by Berkley Publishing Group
# Jesus' Son: Stories by d johnson published in 1993 by Perennial
# The Magician's Tale by d hunt published in 1998 by Berkley Publishing Group
# Detective: A Novel by a hailey published in 1998 by Berkley Publishing Group
#
# Predicted Rating: 6.14
# 6.141134595581353

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
def delete_records_by_isbn(df, isbn):
    #Function for making train data set by delete the test data set out off the dataframe

    isbn_set = set(isbn['ISBN'])
    mask = (df['ISBN'].apply(lambda x: x not in isbn_set))
    updated_df = df[mask]
    return updated_df

def select_random_data(df, percentage):
    # Function for sampling a percentage of the dataframe using for test dataset

    return df.sample(n=int(len(df) * percentage))

def evaluate_model(percentage = 0.001): # this is fractional percentage 0.001 mean 0.1%
  #This function will evaluate the model which use mse, rmse, mae and r2 for evaluation
  ratings, books = load_data('../../Data-Files/Raw-Files')
  books = prepare_data(books)
  test_books = select_random_data(books,percentage)
  train_books = delete_records_by_isbn(books,test_books)
  train_ratings = delete_records_by_isbn(ratings,test_books)
  test_rating = ratings.groupby('ISBN')['Book-Rating'].mean().reset_index()
  test_rating.rename(columns={'Book-Rating': 'Avg-Book-Rating'}, inplace=True)
  test_rating = pd.merge(test_books,test_rating,on ="ISBN")
  pred_rate = []

  # Print the recommendations for each book
  for _, row in test_books.iterrows():
    row = (pd.DataFrame(row)).transpose()
    pred_rate.append(RecommendationSystem(row, train_books, train_ratings))
  #linear_rating = ratings.groupby('ISBN')['Book-Rating'].mean().reset_index()
  mse = mean_squared_error(test_rating['Avg-Book-Rating'], pred_rate)
  rmse = np.sqrt(mse)
  mae = mean_absolute_error(test_rating['Avg-Book-Rating'], pred_rate)
  r2 = r2_score(test_rating['Avg-Book-Rating'], pred_rate)
  print(f"R-squared: {r2:.2f}")
  print(f"Mean Squared Error: {mse:.2f}")
  print(f"Root Mean Squared Error: {rmse:.2f}")
  print(f"Mean Absolute Error: {mae:.2f}")

# %%
evaluate_model()
# Out:
# Choosen book:               ISBN                               Book-Title Book-Author  \
# 20588  0802137040  Exploration of the Valley of the Amazon  wl herndon
#
#       Year-Of-Publication Book-Publisher                   Title-Tokens  \
# 20588                2000    Grove Press  [exploration, valley, amazon]
#
#        Author-Tokens Publisher-Tokens
# 20588  [wl, herndon]   [Grove, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.40
#
# Choosen book:              ISBN                                         Book-Title  \
# 5778  0375708278  Isaac's Storm: A Man, a Time, and the Deadlies...
#
#      Book-Author Year-Of-Publication     Book-Publisher  \
# 5778    e larson                2000  Vintage Books USA
#
#                                            Title-Tokens Author-Tokens  \
# 5778  [isaac, storm, man, time, deadliest, hurricane...   [e, larson]
#
#            Publisher-Tokens
# 5778  [Vintage, Books, USA]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.47
#
# Choosen book:               ISBN                               Book-Title Book-Author  \
# 11655  0140282777  Big Fish: A Novel of Mythic Proportions   d wallace
#
#       Year-Of-Publication Book-Publisher  \
# 11655                1999  Penguin Books
#
#                                  Title-Tokens Author-Tokens  Publisher-Tokens
# 11655  [big, fish, novel, mythic, proportion]  [d, wallace]  [Penguin, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.32
#
# Choosen book:               ISBN                          Book-Title Book-Author  \
# 20073  0373836007  Cold Feet (Harlequin Single Title)     b novak
#
#       Year-Of-Publication Book-Publisher  \
# 20073                2004      Harlequin
#
#                                  Title-Tokens Author-Tokens Publisher-Tokens
# 20073  [cold, foot, harlequin, single, title]    [b, novak]      [Harlequin]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.94
#
# Choosen book:              ISBN                                     Book-Title Book-Author  \
# 7154  0399128964  Dune (Dune Chronicles (Econo-Clad Hardcover))   f herbert
#
#      Year-Of-Publication           Book-Publisher  \
# 7154                1984  Putnam Publishing Group
#
#                                        Title-Tokens Author-Tokens  \
# 7154  [dune, dune, chronicle, econoclad, hardcover]  [f, herbert]
#
#                  Publisher-Tokens
# 7154  [Putnam, Publishing, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.81
#
# Choosen book:              ISBN                   Book-Title Book-Author Year-Of-Publication  \
# 5437  0375410767  The Family Orchard: A Novel       n eve                2000
#
#        Book-Publisher              Title-Tokens Author-Tokens  \
# 5437  Alfred A. Knopf  [family, orchard, novel]      [n, eve]
#
#          Publisher-Tokens
# 5437  [Alfred, A., Knopf]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.42
#
# Choosen book:               ISBN         Book-Title  Book-Author Year-Of-Publication  \
# 14180  1569312036  Ranma 1/2, Vol. 9  r takahashi                1997
#
#            Book-Publisher         Title-Tokens   Author-Tokens  \
# 14180  Viz Communications  [ranma, 12, vol, 9]  [r, takahashi]
#
#             Publisher-Tokens
# 14180  [Viz, Communications]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.86
#
# Choosen book:              ISBN Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 9478  0671654179    PALADIN  cj cherryh                1988           Baen
#
#      Title-Tokens  Author-Tokens Publisher-Tokens
# 9478    [paladin]  [cj, cherryh]           [Baen]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.21
#
# Choosen book:               ISBN               Book-Title Book-Author Year-Of-Publication  \
# 21738  0446675172  Like a Hole in the Head   j banbury                1999
#
#          Book-Publisher        Title-Tokens Author-Tokens     Publisher-Tokens
# 21738  Mysterious Press  [like, hole, head]  [j, banbury]  [Mysterious, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.09
#
# Choosen book:              ISBN         Book-Title Book-Author Year-Of-Publication  \
# 8280  0345447603  Trading in Danger      e moon                2003
#
#      Book-Publisher       Title-Tokens Author-Tokens Publisher-Tokens
# 8280        Del Rey  [trading, danger]     [e, moon]       [Del, Rey]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.56
#
# Choosen book:               ISBN             Book-Title Book-Author Year-Of-Publication  \
# 20936  0743223128  Ghost Image : A Novel    j gilder                2002
#
#          Book-Publisher           Title-Tokens Author-Tokens  \
# 20936  Simon & Schuster  [ghost, image, novel]   [j, gilder]
#
#            Publisher-Tokens
# 20936  [Simon, &, Schuster]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.28
#
# Choosen book:              ISBN           Book-Title Book-Author Year-Of-Publication  \
# 7214  051513306X  The Shape of Snakes   m walters                2002
#
#      Book-Publisher    Title-Tokens Author-Tokens Publisher-Tokens
# 7214     Jove Books  [shape, snake]  [m, walters]    [Jove, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.56
#
# Choosen book:              ISBN                                       Book-Title Book-Author  \
# 4850  0812558251  Snow White and Rose Red (The Fairy Tale Series)    pc wrede
#
#      Year-Of-Publication Book-Publisher  \
# 4850                1990      Tor Books
#
#                                        Title-Tokens Author-Tokens  \
# 4850  [snow, white, rose, red, fairy, tale, series]   [pc, wrede]
#
#      Publisher-Tokens
# 4850     [Tor, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 3.82
#
# Choosen book:               ISBN        Book-Title Book-Author Year-Of-Publication  \
# 17617  1887128964  Bomb the Suburbs  wu wimsatt                2001
#
#          Book-Publisher    Title-Tokens  Author-Tokens      Publisher-Tokens
# 17617  Soft Skull Press  [bomb, suburb]  [wu, wimsatt]  [Soft, Skull, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.57
#
# Choosen book:              ISBN                Book-Title Book-Author Year-Of-Publication  \
# 3590  0060924349  Maybe the Moon : A Novel    a maupin                1993
#
#      Book-Publisher          Title-Tokens Author-Tokens Publisher-Tokens
# 3590      Perennial  [maybe, moon, novel]   [a, maupin]      [Perennial]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.20
#
# Choosen book:              ISBN                                         Book-Title  \
# 7055  0439284031  Harry Potter Schoolbooks: Quidditch Through th...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 7055  jk rowling                2001     Scholastic
#
#                                            Title-Tokens  Author-Tokens  \
# 7055  [harry, potter, schoolbook, quidditch, age, fa...  [jk, rowling]
#
#      Publisher-Tokens
# 7055     [Scholastic]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.12
#
# Choosen book:              ISBN Book-Title Book-Author Year-Of-Publication  \
# 6805  325721846X  Die Taube   p suskind                1992
#
#              Book-Publisher  Title-Tokens Author-Tokens  \
# 6805  Distribooks Int'l+inc  [die, taube]  [p, suskind]
#
#                   Publisher-Tokens
# 6805  [Distribooks, Int, ', l+inc]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.21
#
# Choosen book:               ISBN                                         Book-Title  \
# 13154  0440216419  The 27-Ingredient Chili Con Carne Murders (Eug...
#
#       Book-Author Year-Of-Publication           Book-Publisher  \
# 13154   n pickard                1997  Dell Publishing Company
#
#                                             Title-Tokens Author-Tokens  \
# 13154  [27ingredient, chili, con, carne, murder, euge...  [n, pickard]
#
#                   Publisher-Tokens
# 13154  [Dell, Publishing, Company]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.26
#
# Choosen book:               ISBN                                  Book-Title Book-Author  \
# 13201  0671020803  Dark Allies (Star Trek New Frontier, No 8)     p david
#
#       Year-Of-Publication Book-Publisher  \
# 13201                1999      Star Trek
#
#                                      Title-Tokens Author-Tokens  \
# 13201  [dark, ally, star, trek, new, frontier, 8]    [p, david]
#
#       Publisher-Tokens
# 13201     [Star, Trek]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.61
#
# Choosen book:              ISBN  Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 3254  0440193613  Wanderlust     d steel                1987           Dell
#
#       Title-Tokens Author-Tokens Publisher-Tokens
# 3254  [wanderlust]    [d, steel]           [Dell]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.36
#
# Choosen book:               ISBN           Book-Title    Book-Author Year-Of-Publication  \
# 21549  0679725091  Freud for Beginners  r appignanesi                1990
#
#        Book-Publisher       Title-Tokens     Author-Tokens   Publisher-Tokens
# 21549  Pantheon Books  [freud, beginner]  [r, appignanesi]  [Pantheon, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.85
#
# Choosen book:               ISBN     Book-Title     Book-Author Year-Of-Publication  \
# 18395  0373765096  Cherokee Baby  s whitefeather                2003
#
#       Book-Publisher      Title-Tokens      Author-Tokens Publisher-Tokens
# 18395     Silhouette  [cherokee, baby]  [s, whitefeather]     [Silhouette]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.02
#
# Choosen book:              ISBN                                  Book-Title Book-Author  \
# 8167  0312989431  Deadly Caress (A Francesca Cahill Romance)     b joyce
#
#      Year-Of-Publication           Book-Publisher  \
# 8167                2003  St. Martin's Paperbacks
#
#                                       Title-Tokens Author-Tokens  \
# 8167  [deadly, caress, francesca, cahill, romance]    [b, joyce]
#
#                    Publisher-Tokens
# 8167  [St., Martin, 's, Paperbacks]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.62
# R-squared: -3.24
# Mean Squared Error: 4.68
# Root Mean Squared Error: 2.16
# Mean Absolute Error: 1.73

# %%
evaluate_model(0.01)
# Out:
# Choosen book:               ISBN                                         Book-Title  \
# 12787  0425166929  One Last Time: A Psychic Medium Speaks to Thos...
#
#       Book-Author Year-Of-Publication            Book-Publisher  \
# 12787    j edward                2000  Berkley Publishing Group
#
#                                             Title-Tokens Author-Tokens  \
# 12787  [one, last, time, psychic, medium, speaks, lov...   [j, edward]
#
#                    Publisher-Tokens
# 12787  [Berkley, Publishing, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.65
#
# Choosen book:               ISBN                                     Book-Title  Book-Author  \
# 11182  0515123293  The Last Heroes (Men at War (Paperback Jove))  web griffin
#
#       Year-Of-Publication Book-Publisher                  Title-Tokens  \
# 11182                1998     Jove Books  [last, hero, men, war, jove]
#
#         Author-Tokens Publisher-Tokens
# 11182  [web, griffin]    [Jove, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.88
#
# Choosen book:               ISBN                                         Book-Title  \
# 15767  0671010212  The Ramses 2: the Temple of a Million Years (R...
#
#       Book-Author Year-Of-Publication                     Book-Publisher  \
# 15767      c jacq                1998  Simon & Schuster (Trade Division)
#
#                                      Title-Tokens Author-Tokens  \
# 15767  [ramses, 2, temple, million, year, ramses]     [c, jacq]
#
#                                   Publisher-Tokens
# 15767  [Simon, &, Schuster, (, Trade, Division, )]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.31
#
# Choosen book:               ISBN                   Book-Title   Book-Author  \
# 20758  8403093004  Memorias de Un Homo Erectus  ma rodriguez
#
#       Year-Of-Publication                  Book-Publisher  \
# 20758                2002  Santillana Ediciones Generales
#
#                             Title-Tokens    Author-Tokens  \
# 20758  [memorias, de, un, homo, erectus]  [ma, rodriguez]
#
#                          Publisher-Tokens
# 20758  [Santillana, Ediciones, Generales]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.75
#
# Choosen book:               ISBN                              Book-Title Book-Author  \
# 18955  0141304340  Lisa, Bright and Dark: A Novel (Novel)   j neufeld
#
#       Year-Of-Publication Book-Publisher                        Title-Tokens  \
# 18955                1999   Puffin Books  [lisa, bright, dark, novel, novel]
#
#       Author-Tokens Publisher-Tokens
# 18955  [j, neufeld]  [Puffin, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.41
#
# Choosen book:               ISBN                                       Book-Title  \
# 18562  0152045562  Beware, Princess Elizabeth: A Young Royals Book
#
#       Book-Author Year-Of-Publication             Book-Publisher  \
# 18562     c meyer                2002  Gulliver Books Paperbacks
#
#                                             Title-Tokens Author-Tokens  \
# 18562  [beware, princess, elizabeth, young, royal, book]    [c, meyer]
#
#                     Publisher-Tokens
# 18562  [Gulliver, Books, Paperbacks]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.01
#
# Choosen book:               ISBN                                         Book-Title  \
# 23415  0373871627  Groom Worth Waithing For (Love Inspired, Novem...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 23415   c stovall                2001   Steeple Hill
#
#                                             Title-Tokens Author-Tokens  \
# 23415  [groom, worth, waithing, love, inspired, novem...  [c, stovall]
#
#       Publisher-Tokens
# 23415  [Steeple, Hill]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.11
#
# Choosen book:              ISBN              Book-Title Book-Author Year-Of-Publication  \
# 9945  067152609X  The Return (Star Trek)   w shatner                1997
#
#      Book-Publisher          Title-Tokens Author-Tokens Publisher-Tokens
# 9945      Star Trek  [return, star, trek]  [w, shatner]     [Star, Trek]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.40
#
# Choosen book:               ISBN Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 10816  1551667002    Skyward   ma monroe                2003     Mira Books
#
#       Title-Tokens Author-Tokens Publisher-Tokens
# 10816    [skyward]  [ma, monroe]    [Mira, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 8.01
#
# Choosen book:               ISBN      Book-Title Book-Author Year-Of-Publication  \
# 16004  0060183772  A God in Ruins      l uris                1999
#
#                  Book-Publisher Title-Tokens Author-Tokens  \
# 16004  HarperCollins Publishers  [god, ruin]     [l, uris]
#
#                   Publisher-Tokens
# 16004  [HarperCollins, Publishers]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.33
#
# Choosen book:               ISBN                                Book-Title Book-Author  \
# 11710  0425184285  Arkansas Traveler (Benni Harper Mystery)    e fowler
#
#       Year-Of-Publication            Book-Publisher  \
# 11710                2002  Berkley Publishing Group
#
#                                        Title-Tokens Author-Tokens  \
# 11710  [arkansas, traveler, benni, harper, mystery]   [e, fowler]
#
#                    Publisher-Tokens
# 11710  [Berkley, Publishing, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.16
#
# Choosen book:               ISBN                                         Book-Title  \
# 15150  0618164723  Fat Land: How Americans Became the Fattest Peo...
#
#       Book-Author Year-Of-Publication            Book-Publisher  \
# 15150   g critser                2003  Houghton Mifflin Company
#
#                                             Title-Tokens Author-Tokens  \
# 15150  [fat, land, american, became, fattest, people,...  [g, critser]
#
#                    Publisher-Tokens
# 15150  [Houghton, Mifflin, Company]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.73
#
# Choosen book:               ISBN                      Book-Title Book-Author  \
# 15183  0446523186  Belladonna: A Novel of Revenge    k moline
#
#       Year-Of-Publication Book-Publisher                  Title-Tokens  \
# 15183                1998   Warner Books  [belladonna, novel, revenge]
#
#       Author-Tokens Publisher-Tokens
# 15183   [k, moline]  [Warner, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.54
#
# Choosen book:               ISBN               Book-Title Book-Author Year-Of-Publication  \
# 12041  0395669588  The Hidden Life of Dogs   em thomas                1993
#
#                  Book-Publisher         Title-Tokens Author-Tokens  \
# 12041  Houghton Mifflin Company  [hidden, life, dog]  [em, thomas]
#
#                    Publisher-Tokens
# 12041  [Houghton, Mifflin, Company]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.31
#
# Choosen book:              ISBN       Book-Title Book-Author Year-Of-Publication  \
# 9469  0886779308  The Chanur Saga  cj cherryh                2000
#
#      Book-Publisher    Title-Tokens  Author-Tokens Publisher-Tokens
# 9469      Daw Books  [chanur, saga]  [cj, cherryh]     [Daw, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.69
#
# Choosen book:               ISBN                                    Book-Title Book-Author  \
# 20089  0966067630  Sluggy Freelance: Worship the Comic (Book 2)    p abrams
#
#       Year-Of-Publication Book-Publisher  \
# 20089                1999  Plan Nine Pub
#
#                                        Title-Tokens Author-Tokens  \
# 20089  [sluggy, freelance, worship, comic, book, 2]   [p, abrams]
#
#         Publisher-Tokens
# 20089  [Plan, Nine, Pub]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.07
#
# Choosen book:               ISBN Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 10423  0553293168   Ravished     a quick                1992         Bantam
#
#       Title-Tokens Author-Tokens Publisher-Tokens
# 10423   [ravished]    [a, quick]         [Bantam]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.84
#
# Choosen book:              ISBN Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 5328  0553250221     Tucker    l lamour                1981         Bantam
#
#      Title-Tokens Author-Tokens Publisher-Tokens
# 5328     [tucker]   [l, lamour]         [Bantam]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.72
#
# Choosen book:              ISBN          Book-Title Book-Author Year-Of-Publication  \
# 1642  0446527785  A Bend in the Road    n sparks                2001
#
#      Book-Publisher  Title-Tokens Author-Tokens Publisher-Tokens
# 1642   Warner Books  [bend, road]   [n, sparks]  [Warner, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.01
#
# Choosen book:              ISBN        Book-Title  Book-Author Year-Of-Publication  \
# 3964  0684801469  Farewell To Arms  e hemingway                1995
#
#      Book-Publisher     Title-Tokens   Author-Tokens Publisher-Tokens
# 3964       Scribner  [farewell, arm]  [e, hemingway]       [Scribner]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.48
#
# Choosen book:              ISBN                                         Book-Title  \
# 4736  0765343479  Chapel Noir: A Novel of Suspense featuring She...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 4736  cn douglas                2002    Forge Books
#
#                                            Title-Tokens  Author-Tokens  \
# 4736  [chapel, noir, novel, suspense, featuring, she...  [cn, douglas]
#
#      Publisher-Tokens
# 4736   [Forge, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.20
#
# Choosen book:               ISBN                                 Book-Title Book-Author  \
# 19348  0812590201  Cursed in the Blood (Catherine LeVendeur)    s newman
#
#       Year-Of-Publication Book-Publisher  \
# 19348                2000    Forge Books
#
#                                 Title-Tokens Author-Tokens Publisher-Tokens
# 19348  [cursed, blood, catherine, levendeur]   [s, newman]   [Forge, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.55
#
# Choosen book:               ISBN           Book-Title Book-Author Year-Of-Publication  \
# 18729  0671023225  The Einstein Papers     c dirgo                2000
#
#       Book-Publisher       Title-Tokens Author-Tokens Publisher-Tokens
# 18729         Pocket  [einstein, paper]    [c, dirgo]         [Pocket]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.37
#
# Choosen book:              ISBN                    Book-Title Book-Author  \
# 6073  0802135196  Valley of the Dolls: A Novel    j susann
#
#      Year-Of-Publication Book-Publisher           Title-Tokens Author-Tokens  \
# 6073                1997    Grove Press  [valley, doll, novel]   [j, susann]
#
#      Publisher-Tokens
# 6073   [Grove, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.95
#
# Choosen book:              ISBN                                Book-Title Book-Author  \
# 5276  0345430816  The Drawing of the Dark (Del Rey Impact)    t powers
#
#      Year-Of-Publication Book-Publisher                       Title-Tokens  \
# 5276                1999  Del Rey Books  [drawing, dark, del, rey, impact]
#
#      Author-Tokens   Publisher-Tokens
# 5276   [t, powers]  [Del, Rey, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.59
#
# Choosen book:              ISBN                                         Book-Title  \
# 7482  0451522605  The Winter's Tale (Signet Classic Shakespeare ...
#
#         Book-Author Year-Of-Publication   Book-Publisher  \
# 7482  w shakespeare                1988  Signet Classics
#
#                                            Title-Tokens     Author-Tokens  \
# 7482  [winter, tale, signet, classic, shakespeare, h...  [w, shakespeare]
#
#         Publisher-Tokens
# 7482  [Signet, Classics]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.90
#
# Choosen book:               ISBN                Book-Title Book-Author Year-Of-Publication  \
# 12470  044100928X  Summers at Castle Auburn     s shinn                2002
#
#       Book-Publisher              Title-Tokens Author-Tokens Publisher-Tokens
# 12470      Ace Books  [summer, castle, auburn]    [s, shinn]     [Ace, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.93
#
# Choosen book:              ISBN                   Book-Title Book-Author Year-Of-Publication  \
# 2188  3442440904  Neandertal. Tal des Lebens.   j darnton                1998
#
#      Book-Publisher                   Title-Tokens Author-Tokens  \
# 2188       Goldmann  [neandertal, tal, de, lebens]  [j, darnton]
#
#      Publisher-Tokens
# 2188       [Goldmann]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.87
#
# Choosen book:               ISBN                                Book-Title  Book-Author  \
# 11369  8838913447  La concessione del telefono (La Memoria)  a camilleri
#
#       Year-Of-Publication Book-Publisher  \
# 11369                1998       Sellerio
#
#                                         Title-Tokens   Author-Tokens  \
# 11369  [la, concessione, del, telefono, la, memoria]  [a, camilleri]
#
#       Publisher-Tokens
# 11369       [Sellerio]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.80
#
# Choosen book:               ISBN                                         Book-Title  \
# 19607  0141001445  The Malcontenta: A Kathy and Brock Mystery (Ka...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 19607  b maitland                2001  Penguin Books
#
#                                             Title-Tokens  Author-Tokens  \
# 19607  [malcontenta, kathy, brock, mystery, kathy, br...  [b, maitland]
#
#        Publisher-Tokens
# 19607  [Penguin, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.92
#
# Choosen book:               ISBN                                         Book-Title  \
# 22987  0471350974  The Inextinguishable Symphony: A True Story of...
#
#        Book-Author Year-Of-Publication Book-Publisher  \
# 22987  m goldsmith                2000          Wiley
#
#                                             Title-Tokens   Author-Tokens  \
# 22987  [inextinguishable, symphony, true, story, musi...  [m, goldsmith]
#
#       Publisher-Tokens
# 22987          [Wiley]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.06
#
# Choosen book:               ISBN       Book-Title Book-Author Year-Of-Publication  \
# 13877  0140361219  Winnie-The-Pooh    aa milne                1992
#
#       Book-Publisher     Title-Tokens Author-Tokens Publisher-Tokens
# 13877   Puffin Books  [winniethepooh]   [aa, milne]  [Puffin, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.49
#
# Choosen book:               ISBN                                         Book-Title  \
# 14644  0345347641  Deryni Checkmate (Chronicles of the Deryni, Vo...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 14644     k kurtz                1990  Del Rey Books
#
#                                          Title-Tokens Author-Tokens  \
# 14644  [deryni, checkmate, chronicle, deryni, vol, 2]    [k, kurtz]
#
#         Publisher-Tokens
# 14644  [Del, Rey, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.47
#
# Choosen book:              ISBN Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 2451  0449219569   Comeback   d francis                1994  Fawcett Books
#
#      Title-Tokens Author-Tokens  Publisher-Tokens
# 2451   [comeback]  [d, francis]  [Fawcett, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.33
#
# Choosen book:               ISBN                                    Book-Title Book-Author  \
# 10750  0425188132  State of War (Tom Clancy's Net Force, No. 7)     s perry
#
#       Year-Of-Publication            Book-Publisher  \
# 10750                2003  Berkley Publishing Group
#
#                                     Title-Tokens Author-Tokens  \
# 10750  [state, war, tom, clancys, net, force, 7]    [s, perry]
#
#                    Publisher-Tokens
# 10750  [Berkley, Publishing, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.65
#
# Choosen book:               ISBN Book-Title Book-Author Year-Of-Publication   Book-Publisher  \
# 12718  1573227161   Caucasia     d senna                1999  Riverhead Books
#
#       Title-Tokens Author-Tokens    Publisher-Tokens
# 12718   [caucasia]    [d, senna]  [Riverhead, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.43
#
# Choosen book:               ISBN              Book-Title Book-Author Year-Of-Publication  \
# 17412  0312255012  A Prayer for the Dying      s onan                2000
#
#       Book-Publisher     Title-Tokens Author-Tokens Publisher-Tokens
# 17412        Picador  [prayer, dying]     [s, onan]        [Picador]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.95
#
# Choosen book:              ISBN                                         Book-Title  \
# 5985  0451410378  The Silent Bride (April Woo Suspense Novels (P...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 5985     l glass                2002     Onyx Books
#
#                                       Title-Tokens Author-Tokens  \
# 5985  [silent, bride, april, woo, suspense, novel]    [l, glass]
#
#      Publisher-Tokens
# 5985    [Onyx, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.53
#
# Choosen book:               ISBN                                         Book-Title  \
# 22537  0679463038  The Progress Paradox : How Life Gets Better Wh...
#
#          Book-Author Year-Of-Publication Book-Publisher  \
# 22537  g easterbrook                2003   Random House
#
#                                             Title-Tokens     Author-Tokens  \
# 22537  [progress, paradox, life, get, better, people,...  [g, easterbrook]
#
#       Publisher-Tokens
# 22537  [Random, House]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.47
#
# Choosen book:             ISBN       Book-Title Book-Author Year-Of-Publication  \
# 964  0451150317  Firestarter (R)      s king                1981
#
#     Book-Publisher      Title-Tokens Author-Tokens Publisher-Tokens
# 964    Signet Book  [firestarter, r]     [s, king]   [Signet, Book]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.85
#
# Choosen book:               ISBN                     Book-Title Book-Author  \
# 10210  0671743902  SEE YOU LATER : SEE YOU LATER      c pike
#
#       Year-Of-Publication Book-Publisher              Title-Tokens  \
# 10210                1991    Simon Pulse  [see, later, see, later]
#
#       Author-Tokens Publisher-Tokens
# 10210     [c, pike]   [Simon, Pulse]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.43
#
# Choosen book:               ISBN         Book-Title Book-Author Year-Of-Publication  \
# 11950  0330281240  On the Black Hill   b chatwin                1989
#
#       Book-Publisher   Title-Tokens Author-Tokens   Publisher-Tokens
# 11950  Pan Books Ltd  [black, hill]  [b, chatwin]  [Pan, Books, Ltd]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.30
#
# Choosen book:               ISBN                                         Book-Title  \
# 15078  0451172310  A Cat by Any Other Name (Alice Nestleton Myste...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 15078   l adamson                1994    Signet Book
#
#                                  Title-Tokens Author-Tokens Publisher-Tokens
# 15078  [cat, name, alice, nestleton, mystery]  [l, adamson]   [Signet, Book]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.24
#
# Choosen book:               ISBN                                    Book-Title Book-Author  \
# 23375  0375421319  The Bear's Embrace: A True Story of Survival   pv tighem
#
#       Year-Of-Publication Book-Publisher  \
# 23375                2001       Pantheon
#
#                                  Title-Tokens Author-Tokens Publisher-Tokens
# 23375  [bear, embrace, true, story, survival]  [pv, tighem]       [Pantheon]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.93
#
# Choosen book:               ISBN     Book-Title  Book-Author Year-Of-Publication  \
# 15521  0060914289  The Egg and I  b macdonald                1987
#
#       Book-Publisher Title-Tokens   Author-Tokens Publisher-Tokens
# 15521      Perennial        [egg]  [b, macdonald]      [Perennial]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.37
#
# Choosen book:              ISBN                                         Book-Title  \
# 9278  0525945008  The Burglar in the Rye: A Bernie Rhodenbarr My...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 9278     l block                1999    Penguin USA
#
#                                      Title-Tokens Author-Tokens  \
# 9278  [burglar, rye, bernie, rhodenbarr, mystery]    [l, block]
#
#      Publisher-Tokens
# 9278   [Penguin, USA]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.62
#
# Choosen book:              ISBN                                   Book-Title Book-Author  \
# 7689  0740732986  When Body Language Goes Bad: A Dilbert Book     s adams
#
#      Year-Of-Publication             Book-Publisher  \
# 7689                2003  Andrews McMeel Publishing
#
#                                   Title-Tokens Author-Tokens  \
# 7689  [body, language, go, bad, dilbert, book]    [s, adams]
#
#                    Publisher-Tokens
# 7689  [Andrews, McMeel, Publishing]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.33
#
# Choosen book:              ISBN             Book-Title Book-Author Year-Of-Publication  \
# 3781  0060558865  Ella Enchanted (rack)   gc levine                2004
#
#      Book-Publisher             Title-Tokens Author-Tokens Publisher-Tokens
# 3781           Avon  [ella, enchanted, rack]  [gc, levine]           [Avon]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.38
#
# Choosen book:               ISBN                                   Book-Title   Book-Author  \
# 22288  0312967012  A Veiled Antiquity (A Torie O'Shea Mystery)  r macpherson
#
#       Year-Of-Publication            Book-Publisher  \
# 22288                1999  St. Martin's Dead Letter
#
#                                      Title-Tokens    Author-Tokens  \
# 22288  [veiled, antiquity, torie, oshea, mystery]  [r, macpherson]
#
#                       Publisher-Tokens
# 22288  [St., Martin, 's, Dead, Letter]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.07
#
# Choosen book:              ISBN                                   Book-Title Book-Author  \
# 7119  0375727566  Yeats Is Dead! (Vintage Crime/Black Lizard)   j oconnor
#
#      Year-Of-Publication     Book-Publisher  \
# 7119                2002  Vintage Books USA
#
#                                     Title-Tokens Author-Tokens  \
# 7119  [yeats, dead, vintage, crimeblack, lizard]  [j, oconnor]
#
#            Publisher-Tokens
# 7119  [Vintage, Books, USA]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.22
#
# Choosen book:              ISBN    Book-Title Book-Author Year-Of-Publication  \
# 1458  0380713098  Tatham Mound   p anthony                1992
#
#                           Book-Publisher     Title-Tokens Author-Tokens  \
# 1458  Harper Mass Market Paperbacks (Mm)  [tatham, mound]  [p, anthony]
#
#                                   Publisher-Tokens
# 1458  [Harper, Mass, Market, Paperbacks, (, Mm, )]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.88
#
# Choosen book:               ISBN              Book-Title Book-Author Year-Of-Publication  \
# 20575  0590417363  Fourth Grade Is a Jinx   c mckenna                1995
#
#       Book-Publisher           Title-Tokens Author-Tokens Publisher-Tokens
# 20575     Scholastic  [fourth, grade, jinx]  [c, mckenna]     [Scholastic]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.68
#
# Choosen book:               ISBN                                         Book-Title  \
# 11712  0425162397  Goose in the Pond (Benni Harper Mysteries (Pap...
#
#       Book-Author Year-Of-Publication            Book-Publisher  \
# 11712    e fowler                1998  Berkley Publishing Group
#
#                                 Title-Tokens Author-Tokens  \
# 11712  [goose, pond, benni, harper, mystery]   [e, fowler]
#
#                    Publisher-Tokens
# 11712  [Berkley, Publishing, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.26
#
# Choosen book:              ISBN                 Book-Title Book-Author Year-Of-Publication  \
# 7295  0312980302  The Last Time I Saw Paris     e adler                2002
#
#                Book-Publisher              Title-Tokens Author-Tokens  \
# 7295  St. Martin's Paperbacks  [last, time, saw, paris]    [e, adler]
#
#                    Publisher-Tokens
# 7295  [St., Martin, 's, Paperbacks]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.91
#
# Choosen book:              ISBN                                      Book-Title Book-Author  \
# 2235  0517799529  Dave Barry's Gift Guide to End All Gift Guides     d barry
#
#      Year-Of-Publication    Book-Publisher  \
# 2235                1994  Random House Inc
#
#                                        Title-Tokens Author-Tokens  \
# 2235  [dave, barrys, gift, guide, end, gift, guide]    [d, barry]
#
#           Publisher-Tokens
# 2235  [Random, House, Inc]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.55
#
# Choosen book:               ISBN           Book-Title Book-Author Year-Of-Publication  \
# 21074  1591820642  Rave Master, Book 1   h mashima                2002
#
#       Book-Publisher             Title-Tokens Author-Tokens Publisher-Tokens
# 21074       Tokyopop  [rave, master, book, 1]  [h, mashima]       [Tokyopop]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.71
#
# Choosen book:               ISBN                                         Book-Title  \
# 10214  0671872680  The RED DICE (LAST VAMPIRE 3) : THE RED DICE (...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 10214      c pike                1995    Simon Pulse
#
#                                             Title-Tokens Author-Tokens  \
# 10214  [red, dice, last, vampire, 3, red, dice, last,...     [c, pike]
#
#       Publisher-Tokens
# 10214   [Simon, Pulse]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.08
#
# Choosen book:               ISBN          Book-Title Book-Author Year-Of-Publication  \
# 12634  0451208668  The Opposite Shore     m stahl                2003
#
#              Book-Publisher       Title-Tokens Author-Tokens  \
# 12634  New American Library  [opposite, shore]    [m, stahl]
#
#                Publisher-Tokens
# 12634  [New, American, Library]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.65
#
# Choosen book:               ISBN                         Book-Title Book-Author  \
# 10288  0590431978  Scary Stories to Tell In the Dark  a schwartz
#
#       Year-Of-Publication  Book-Publisher                Title-Tokens  \
# 10288                1987  Scholastic Inc  [scary, story, tell, dark]
#
#        Author-Tokens   Publisher-Tokens
# 10288  [a, schwartz]  [Scholastic, Inc]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.26
#
# Choosen book:               ISBN Book-Title   Book-Author Year-Of-Publication  \
# 19337  1401300057  Firehouse  d halberstam                2002
#
#        Book-Publisher Title-Tokens    Author-Tokens   Publisher-Tokens
# 19337  Hyperion Press  [firehouse]  [d, halberstam]  [Hyperion, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.45
#
# Choosen book:              ISBN                                      Book-Title Book-Author  \
# 8460  0679723692  Cathedral (Vintage Contemporaries (Paperback))    r carver
#
#      Year-Of-Publication     Book-Publisher  \
# 8460                1989  Vintage Books USA
#
#                             Title-Tokens Author-Tokens       Publisher-Tokens
# 8460  [cathedral, vintage, contemporary]   [r, carver]  [Vintage, Books, USA]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.97
#
# Choosen book:               ISBN                                         Book-Title  \
# 13300  0886776791  Return to Avalon: A Celebration of Marion Zimm...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 13300  j roberson                1996      Daw Books
#
#                                             Title-Tokens  Author-Tokens  \
# 13300  [return, avalon, celebration, marion, zimmer, ...  [j, roberson]
#
#       Publisher-Tokens
# 13300     [Daw, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.32
#
# Choosen book:              ISBN Book-Title Book-Author Year-Of-Publication  \
# 3079  0877956324      Glitz   e leonard                1985
#
#           Book-Publisher Title-Tokens Author-Tokens         Publisher-Tokens
# 3079  Arbor House Pub Co      [glitz]  [e, leonard]  [Arbor, House, Pub, Co]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.66
#
# Choosen book:              ISBN Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 3947  0140168125    Big Sur   j kerouac                1992  Penguin Books
#
#      Title-Tokens Author-Tokens  Publisher-Tokens
# 3947   [big, sur]  [j, kerouac]  [Penguin, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.56
#
# Choosen book:              ISBN           Book-Title Book-Author Year-Of-Publication  \
# 8627  0425186857  From This Moment on   l kurland                2002
#
#                 Book-Publisher Title-Tokens Author-Tokens  \
# 8627  Berkley Publishing Group     [moment]  [l, kurland]
#
#                   Publisher-Tokens
# 8627  [Berkley, Publishing, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.15
#
# Choosen book:              ISBN      Book-Title Book-Author Year-Of-Publication  \
# 3446  0553579606  Ashes to Ashes      t hoag                2000
#
#      Book-Publisher Title-Tokens Author-Tokens Publisher-Tokens
# 3446         Bantam   [ash, ash]     [t, hoag]         [Bantam]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.26
#
# Choosen book:               ISBN                                         Book-Title  \
# 19733  0671774778  Section 31:  Rogue (Star Trek The Next Generat...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 19733   a mangels                2001      Star Trek
#
#                                             Title-Tokens Author-Tokens  \
# 19733  [section, 31, rogue, star, trek, next, generat...  [a, mangels]
#
#       Publisher-Tokens
# 19733     [Star, Trek]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.77
#
# Choosen book:              ISBN                                         Book-Title  \
# 8520  0786865091  Don't Sweat the Small Stuff in Love : Simple W...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 8520   r carlson                1999       Hyperion
#
#                                            Title-Tokens Author-Tokens  \
# 8520  [dont, sweat, small, stuff, love, simple, way,...  [r, carlson]
#
#      Publisher-Tokens
# 8520       [Hyperion]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.63
#
# Choosen book:              ISBN                    Book-Title Book-Author  \
# 7079  0060506679  Every Secret Thing : A Novel   l lippman
#
#      Year-Of-Publication  Book-Publisher                   Title-Tokens  \
# 7079                2003  William Morrow  [every, secret, thing, novel]
#
#      Author-Tokens   Publisher-Tokens
# 7079  [l, lippman]  [William, Morrow]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.20
#
# Choosen book:               ISBN                          Book-Title Book-Author  \
# 22035  1853262110  Beau Geste (Wordsworth Collection)      p wren
#
#       Year-Of-Publication                       Book-Publisher  \
# 22035                1998  NTC/Contemporary Publishing Company
#
#                                 Title-Tokens Author-Tokens  \
# 22035  [beau, geste, wordsworth, collection]     [p, wren]
#
#                               Publisher-Tokens
# 22035  [NTC/Contemporary, Publishing, Company]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.31
#
# Choosen book:               ISBN   Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 18751  0441007406  Dog Eat Dog  jj carroll                2000      Ace Books
#
#           Title-Tokens  Author-Tokens Publisher-Tokens
# 18751  [dog, eat, dog]  [jj, carroll]     [Ace, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.17
#
# Choosen book:               ISBN                                         Book-Title  \
# 20477  0575075546  The Soddit : or, Cashing in Again (Gollancz SF...
#
#         Book-Author Year-Of-Publication Book-Publisher  \
# 20477  arrr roberts                2003       Gollancz
#
#                           Title-Tokens    Author-Tokens Publisher-Tokens
# 20477  [soddit, cashing, gollancz, sf]  [arrr, roberts]       [Gollancz]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.58
#
# Choosen book:               ISBN   Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 16360  0553572261  Saints Rest   t gifford                1997   Bantam Books
#
#         Title-Tokens Author-Tokens Publisher-Tokens
# 16360  [saint, rest]  [t, gifford]  [Bantam, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.14
#
# Choosen book:               ISBN                                         Book-Title  \
# 22775  0486228029  The Malleus Maleficarum of Heinrich Kramer and...
#
#         Book-Author Year-Of-Publication      Book-Publisher  \
# 22775  h institoris                1971  Dover Publications
#
#                                             Title-Tokens    Author-Tokens  \
# 22775  [malleus, maleficarum, heinrich, kramer, james...  [h, institoris]
#
#             Publisher-Tokens
# 22775  [Dover, Publications]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.58
#
# Choosen book:               ISBN Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 16732  0590427717   Blitzcat   r westall                1994     Scholastic
#
#       Title-Tokens Author-Tokens Publisher-Tokens
# 16732   [blitzcat]  [r, westall]     [Scholastic]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.96
#
# Choosen book:               ISBN       Book-Title Book-Author Year-Of-Publication  \
# 17714  0786012374  The Next to Die    k obrien                2001
#
#                           Book-Publisher Title-Tokens Author-Tokens  \
# 17714  Kensington Publishing Corporation  [next, die]   [k, obrien]
#
#                             Publisher-Tokens
# 17714  [Kensington, Publishing, Corporation]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.67
#
# Choosen book:               ISBN                                         Book-Title  \
# 22096  0446530662  Showing Mary: How Women Can Share Prayers, Wis...
#
#       Book-Author Year-Of-Publication     Book-Publisher  \
# 22096    rj weems                2002  Walk Worthy Press
#
#                                             Title-Tokens Author-Tokens  \
# 22096  [showing, mary, woman, share, prayer, wisdom, ...   [rj, weems]
#
#             Publisher-Tokens
# 22096  [Walk, Worthy, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.38
#
# Choosen book:               ISBN               Book-Title Book-Author Year-Of-Publication  \
# 17529  0312975716  Murder on the Lusitania     c allen                2000
#
#               Book-Publisher         Title-Tokens Author-Tokens  \
# 17529  St. Martin's Minotaur  [murder, lusitania]    [c, allen]
#
#                   Publisher-Tokens
# 17529  [St., Martin, 's, Minotaur]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.47
#
# Choosen book:              ISBN                                         Book-Title  \
# 7048  043965548X  Harry Potter and the Prisoner of Azkaban (Harr...
#
#      Book-Author Year-Of-Publication         Book-Publisher  \
# 7048  jk rowling                2004  Scholastic Paperbacks
#
#                                            Title-Tokens  Author-Tokens  \
# 7048  [harry, potter, prisoner, azkaban, harry, potter]  [jk, rowling]
#
#               Publisher-Tokens
# 7048  [Scholastic, Paperbacks]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.96
#
# Choosen book:               ISBN                                         Book-Title  \
# 11952  0805067205  Balsamic Dreams: A Short But Self-important Hi...
#
#       Book-Author Year-Of-Publication        Book-Publisher  \
# 11952   j queenan                2001  Henry Holt & Company
#
#                                             Title-Tokens Author-Tokens  \
# 11952  [balsamic, dream, short, selfimportant, histor...  [j, queenan]
#
#                 Publisher-Tokens
# 11952  [Henry, Holt, &, Company]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.29
#
# Choosen book:               ISBN      Book-Title Book-Author Year-Of-Publication  \
# 21038  0380818655  Another Summer  g bockoven                2001
#
#       Book-Publisher       Title-Tokens  Author-Tokens Publisher-Tokens
# 21038    HarperTorch  [another, summer]  [g, bockoven]    [HarperTorch]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.85
#
# Choosen book:               ISBN                                         Book-Title  \
# 18256  0060961325  The Celluloid Closet: Homosexuality in the Movies
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 18256     v russo                1987      Perennial
#
#                                     Title-Tokens Author-Tokens  \
# 18256  [celluloid, closet, homosexuality, movie]    [v, russo]
#
#       Publisher-Tokens
# 18256      [Perennial]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.17
#
# Choosen book:               ISBN                                         Book-Title  \
# 22322  0340794682  Samurai William: The Adventurer Who Unlocked J...
#
#       Book-Author Year-Of-Publication                       Book-Publisher  \
# 22322    g milton                2003  Hodder & Stoughton General Division
#
#                                           Title-Tokens Author-Tokens  \
# 22322  [samurai, william, adventurer, unlocked, japan]   [g, milton]
#
#                                 Publisher-Tokens
# 22322  [Hodder, &, Stoughton, General, Division]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.31
#
# Choosen book:              ISBN                              Book-Title  Book-Author  \
# 1123  0060161183  Talking God (Harper Novel of Suspense)  t hillerman
#
#      Year-Of-Publication Book-Publisher  \
# 1123                1989  Harpercollins
#
#                                  Title-Tokens   Author-Tokens Publisher-Tokens
# 1123  [talking, god, harper, novel, suspense]  [t, hillerman]  [Harpercollins]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.30
#
# Choosen book:              ISBN        Book-Title Book-Author Year-Of-Publication  \
# 2871  0385319037  Animal Husbandry    l zigman                2001
#
#      Book-Publisher         Title-Tokens Author-Tokens Publisher-Tokens
# 2871          Delta  [animal, husbandry]   [l, zigman]          [Delta]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.95
#
# Choosen book:              ISBN               Book-Title Book-Author Year-Of-Publication  \
# 2393  0142001740  The Secret Life of Bees     sm kidd                2003
#
#      Book-Publisher         Title-Tokens Author-Tokens  Publisher-Tokens
# 2393  Penguin Books  [secret, life, bee]    [sm, kidd]  [Penguin, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.93
#
# Choosen book:              ISBN           Book-Title Book-Author Year-Of-Publication  \
# 1777  0345440064  Death of a Stranger     a perry                2003
#
#      Book-Publisher       Title-Tokens Author-Tokens Publisher-Tokens
# 1777        Fawcett  [death, stranger]    [a, perry]        [Fawcett]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.26
#
# Choosen book:               ISBN  Book-Title Book-Author Year-Of-Publication  Book-Publisher  \
# 10572  8495501112  Son De Mar    m vicent                2002  Suma de Letras
#
#          Title-Tokens Author-Tokens    Publisher-Tokens
# 10572  [son, de, mar]   [m, vicent]  [Suma, de, Letras]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.32
#
# Choosen book:              ISBN                                         Book-Title  \
# 1304  0670033332  Olivia Joules and the Overactive Imagination (...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 1304  h fielding                2004   Viking Books
#
#                                            Title-Tokens  Author-Tokens  \
# 1304  [olivia, joule, overactive, imagination, field...  [h, fielding]
#
#      Publisher-Tokens
# 1304  [Viking, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.01
#
# Choosen book:              ISBN                                         Book-Title  \
# 3152  0451198948  Warrior's Song (Coulter, Catherine. Medieval S...
#
#      Book-Author Year-Of-Publication Book-Publisher  \
# 3152   c coulter                2004    Signet Book
#
#                                            Title-Tokens Author-Tokens  \
# 3152  [warrior, song, coulter, catherine, medieval, ...  [c, coulter]
#
#      Publisher-Tokens
# 3152   [Signet, Book]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.75
#
# Choosen book:               ISBN                                   Book-Title Book-Author  \
# 13173  0671520474  The Captain's Daughter (Star Trek, Book 76)     p david
#
#       Year-Of-Publication Book-Publisher  \
# 13173                1995      Star Trek
#
#                                     Title-Tokens Author-Tokens  \
# 13173  [captain, daughter, star, trek, book, 76]    [p, david]
#
#       Publisher-Tokens
# 13173     [Star, Trek]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.04
#
# Choosen book:               ISBN                                         Book-Title  \
# 14443  0425140989  Thyme of Death: A China Bayles Mystery (West C...
#
#       Book-Author Year-Of-Publication            Book-Publisher  \
# 14443   sw albert                1994  Berkley Publishing Group
#
#                                             Title-Tokens Author-Tokens  \
# 14443  [thyme, death, china, bayles, mystery, west, c...  [sw, albert]
#
#                    Publisher-Tokens
# 14443  [Berkley, Publishing, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.45
#
# Choosen book:               ISBN                    Book-Title  Book-Author  \
# 15291  0385314337  The Giant's House: A Romance  e mccracken
#
#       Year-Of-Publication         Book-Publisher             Title-Tokens  \
# 15291                1996  Bantam Dell Pub Group  [giant, house, romance]
#
#         Author-Tokens            Publisher-Tokens
# 15291  [e, mccracken]  [Bantam, Dell, Pub, Group]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.98
#
# Choosen book:               ISBN                                 Book-Title Book-Author  \
# 13943  0373790783  The Diva Diaries (Harlequin Blaze, No 74)    k anders
#
#       Year-Of-Publication Book-Publisher                         Title-Tokens  \
# 13943                2003      Harlequin  [diva, diary, harlequin, blaze, 74]
#
#       Author-Tokens Publisher-Tokens
# 13943   [k, anders]      [Harlequin]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.22
#
# Choosen book:               ISBN            Book-Title Book-Author Year-Of-Publication  \
# 19254  0698115554  Princess Smartypants      b cole                1997
#
#        Book-Publisher             Title-Tokens Author-Tokens  \
# 19254  PaperStar Book  [princess, smartypants]     [b, cole]
#
#         Publisher-Tokens
# 19254  [PaperStar, Book]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.38
#
# Choosen book:               ISBN         Book-Title Book-Author Year-Of-Publication  \
# ...
#
#                 Publisher-Tokens
# 16457  [Wizards, of, the, Coast]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.66
#
# Choosen book:               ISBN            Book-Title Book-Author Year-Of-Publication  \
# 16915  0312199511  Quarantine : A Novel     j crace                1999
#
#       Book-Publisher         Title-Tokens Author-Tokens Publisher-Tokens
# 16915        Picador  [quarantine, novel]    [j, crace]        [Picador]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.26
#
# Choosen book:               ISBN                                         Book-Title  \
# 17889  0060014342  In the Wake of the Plague: The Black Death and...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 17889    n cantor                2002      Perennial
#
#                                     Title-Tokens Author-Tokens  \
# 17889  [wake, plague, black, death, world, made]   [n, cantor]
#
#       Publisher-Tokens
# 17889      [Perennial]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.55
#
# Choosen book:               ISBN Book-Title Book-Author Year-Of-Publication  Book-Publisher  \
# 20927  0786012668  Cold Fear    r mofina                2001  Pinnacle Books
#
#        Title-Tokens Author-Tokens   Publisher-Tokens
# 20927  [cold, fear]   [r, mofina]  [Pinnacle, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.19
#
# Choosen book:              ISBN                            Book-Title Book-Author  \
# 1185  0440918642  Daughters of Eve (Laurel Leaf Books)    l duncan
#
#      Year-Of-Publication Book-Publisher                         Title-Tokens  \
# 1185                1990     Laure Leaf  [daughter, eve, laurel, leaf, book]
#
#      Author-Tokens Publisher-Tokens
# 1185   [l, duncan]    [Laure, Leaf]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.71
#
# Choosen book:               ISBN        Book-Title Book-Author Year-Of-Publication  \
# 21339  067144834X  CINDERELLA COMPL   c dowling                1982
#
#       Book-Publisher         Title-Tokens Author-Tokens Publisher-Tokens
# 21339         Pocket  [cinderella, compl]  [c, dowling]         [Pocket]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.15
#
# Choosen book:               ISBN                      Book-Title Book-Author  \
# 21721  0761129030  97 Ways to Make Your Dog Smile  j langbehn
#
#       Year-Of-Publication      Book-Publisher                 Title-Tokens  \
# 21721                2003  Workman Publishing  [97, way, make, dog, smile]
#
#        Author-Tokens       Publisher-Tokens
# 21721  [j, langbehn]  [Workman, Publishing]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.91
#
# Choosen book:               ISBN                       Book-Title Book-Author  \
# 11750  0743255224  Name All the Animals : A Memoir     a smith
#
#       Year-Of-Publication Book-Publisher            Title-Tokens  \
# 11750                2004       Scribner  [name, animal, memoir]
#
#       Author-Tokens Publisher-Tokens
# 11750    [a, smith]       [Scribner]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.73
#
# Choosen book:               ISBN    Book-Title Book-Author Year-Of-Publication  \
# 11967  0812521080  Tread Softly    r laymon                1987
#
#       Book-Publisher     Title-Tokens Author-Tokens Publisher-Tokens
# 11967      Tor Books  [tread, softly]   [r, laymon]     [Tor, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.57
#
# Choosen book:               ISBN   Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 12309  0006548830  Information      m amis                1992       Flamingo
#
#         Title-Tokens Author-Tokens Publisher-Tokens
# 12309  [information]     [m, amis]       [Flamingo]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.35
#
# Choosen book:              ISBN     Book-Title Book-Author Year-Of-Publication  \
# 1477  0345335090  Ogre Ogre #05   p anthony                1982
#
#      Book-Publisher      Title-Tokens Author-Tokens   Publisher-Tokens
# 1477  Del Rey Books  [ogre, ogre, 05]  [p, anthony]  [Del, Rey, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 7.17
#
# Choosen book:              ISBN                 Book-Title Book-Author Year-Of-Publication  \
# 1481  0812502574  Serpent's Silver (Kelvin)   p anthony                1989
#
#      Book-Publisher               Title-Tokens Author-Tokens Publisher-Tokens
# 1481      Tor Books  [serpent, silver, kelvin]  [p, anthony]     [Tor, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.16
#
# Choosen book:              ISBN      Book-Title Book-Author Year-Of-Publication  \
# 7588  2070388905  Comme un roman    d pennac                1995
#
#      Book-Publisher        Title-Tokens Author-Tokens Publisher-Tokens
# 7588      Gallimard  [comme, un, roman]   [d, pennac]      [Gallimard]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.66
#
# Choosen book:              ISBN    Book-Title Book-Author Year-Of-Publication Book-Publisher  \
# 5477  0373833512  Waiting Game   ja krentz                1998      Harlequin
#
#          Title-Tokens Author-Tokens Publisher-Tokens
# 5477  [waiting, game]  [ja, krentz]      [Harlequin]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.24
#
# Choosen book:               ISBN                                         Book-Title  \
# 21816  0385502737  The Good, the Bad & the Difference: How to Tel...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 21816     r cohen                2002      Doubleday
#
#                                             Title-Tokens Author-Tokens  \
# 21816  [good, bad, difference, tell, right, wrong, ev...    [r, cohen]
#
#       Publisher-Tokens
# 21816      [Doubleday]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 3.93
#
# Choosen book:              ISBN                                         Book-Title  \
# 6732  0312981589  Robert Ludlum's The Cassandra Compact (A Cover...
#
#      Book-Author Year-Of-Publication           Book-Publisher  \
# 6732    r ludlum                2002  St. Martin's Paperbacks
#
#                                            Title-Tokens Author-Tokens  \
# 6732  [robert, ludlums, cassandra, compact, coverton...   [r, ludlum]
#
#                    Publisher-Tokens
# 6732  [St., Martin, 's, Paperbacks]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.83
#
# Choosen book:               ISBN                                Book-Title Book-Author  \
# 20047  0440220297  Life in the Fat Lane (Laurel-Leaf Books)   c bennett
#
#       Year-Of-Publication Book-Publisher                         Title-Tokens  \
# 20047                1999    Laurel Leaf  [life, fat, lane, laurelleaf, book]
#
#       Author-Tokens Publisher-Tokens
# 20047  [c, bennett]   [Laurel, Leaf]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.09
#
# Choosen book:               ISBN                                         Book-Title  \
# 12030  0553239430  Sweet Valley High #05: All Night Long (Sweet V...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 12030    f pascal                1984   Bantam Books
#
#                                             Title-Tokens Author-Tokens  \
# 12030  [sweet, valley, high, 05, night, long, sweet, ...   [f, pascal]
#
#       Publisher-Tokens
# 12030  [Bantam, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.08
#
# Choosen book:               ISBN                                         Book-Title  \
# 21987  0761122745  Non Campus Mentis: World History According to ...
#
#         Book-Author Year-Of-Publication      Book-Publisher  \
# 21987  a henriksson                2001  Workman Publishing
#
#                                             Title-Tokens    Author-Tokens  \
# 21987  [non, campus, mentis, world, history, accordin...  [a, henriksson]
#
#             Publisher-Tokens
# 21987  [Workman, Publishing]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.93
#
# Choosen book:               ISBN                                         Book-Title  \
# 23482  0933149166  Children With Autism: A Parents' Guide (Specia...
#
#       Book-Author Year-Of-Publication  Book-Publisher  \
# 23482   md powers                1989  Woodbine House
#
#                                             Title-Tokens Author-Tokens  \
# 23482  [child, autism, parent, guide, special, need, ...  [md, powers]
#
#         Publisher-Tokens
# 23482  [Woodbine, House]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 3.63
#
# Choosen book:               ISBN      Book-Title Book-Author Year-Of-Publication  \
# 10125  0156004011  The Stone Raft  j saramago                1996
#
#       Book-Publisher   Title-Tokens  Author-Tokens  Publisher-Tokens
# 10125  Harvest Books  [stone, raft]  [j, saramago]  [Harvest, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.34
#
# Choosen book:               ISBN                            Book-Title Book-Author  \
# 18434  0679745068  Et Tu, Babe (Vintage Contemporaries)    m leyner
#
#       Year-Of-Publication     Book-Publisher  \
# 18434                1993  Vintage Books USA
#
#                                 Title-Tokens Author-Tokens  \
# 18434  [et, tu, babe, vintage, contemporary]   [m, leyner]
#
#             Publisher-Tokens
# 18434  [Vintage, Books, USA]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.55
#
# Choosen book:              ISBN                                         Book-Title  \
# 9704  0060186380  Call Each River Jordan: A Novel of Historical ...
#
#      Book-Author Year-Of-Publication            Book-Publisher  \
# 9704     o parry                2001  William Morrow & Company
#
#                                            Title-Tokens Author-Tokens  \
# 9704  [call, river, jordan, novel, historical, suspe...    [o, parry]
#
#                    Publisher-Tokens
# 9704  [William, Morrow, &, Company]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.88
#
# Choosen book:               ISBN     Book-Title Book-Author Year-Of-Publication  \
# 13422  0060936231  Soul Mountain  g xingjian                2001
#
#       Book-Publisher      Title-Tokens  Author-Tokens Publisher-Tokens
# 13422      Perennial  [soul, mountain]  [g, xingjian]      [Perennial]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.92
#
# Choosen book:              ISBN Book-Title Book-Author Year-Of-Publication  \
# 3408  0330331973  River God     w smith                1994
#
#           Book-Publisher  Title-Tokens Author-Tokens          Publisher-Tokens
# 3408  St. Martin's Press  [river, god]    [w, smith]  [St., Martin, 's, Press]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.30
#
# Choosen book:               ISBN                                         Book-Title  \
# 17245  0590414291  The Magic School Bus Lost in the Solar System ...
#
#       Book-Author Year-Of-Publication Book-Publisher  \
# 17245      j cole                1992     Scholastic
#
#                                             Title-Tokens Author-Tokens  \
# 17245  [magic, school, bus, lost, solar, system, magi...     [j, cole]
#
#       Publisher-Tokens
# 17245     [Scholastic]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.49
#
# Choosen book:               ISBN     Book-Title Book-Author Year-Of-Publication  \
# 14592  0689717830  Bright Shadow         avi                1994
#
#       Book-Publisher      Title-Tokens Author-Tokens Publisher-Tokens
# 14592        Aladdin  [bright, shadow]         [avi]        [Aladdin]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.06
#
# Choosen book:               ISBN                                        Book-Title  \
# 11251  0345391527  The Demon Spirit (The DemonWars Trilogy, Book 2)
#
#         Book-Author Year-Of-Publication Book-Publisher  \
# 11251  ra salvatore                1999        Del Rey
#
#                                        Title-Tokens    Author-Tokens  \
# 11251  [demon, spirit, demonwars, trilogy, book, 2]  [ra, salvatore]
#
#       Publisher-Tokens
# 11251       [Del, Rey]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.63
#
# Choosen book:              ISBN              Book-Title Book-Author Year-Of-Publication  \
# 6120  0440131480  Breakfast of Champions  k vonnegut                1991
#
#                Book-Publisher           Title-Tokens  Author-Tokens  \
# 6120  Dell Publishing Company  [breakfast, champion]  [k, vonnegut]
#
#                  Publisher-Tokens
# 6120  [Dell, Publishing, Company]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.79
#
# Choosen book:              ISBN                                     Book-Title Book-Author  \
# 1724  0590442805  Clifford's Kitten (Clifford, the Big Red Dog)  n bridwell
#
#      Year-Of-Publication   Book-Publisher  \
# 1724                1994  Cartwheel Books
#
#                                       Title-Tokens  Author-Tokens  \
# 1724  [cliffords, kitten, clifford, big, red, dog]  [n, bridwell]
#
#         Publisher-Tokens
# 1724  [Cartwheel, Books]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.99
#
# Choosen book:             ISBN             Book-Title Book-Author Year-Of-Publication  \
# 473  0140113096  In the Skin of a Lion  m ondaatje                1989
#
#     Book-Publisher  Title-Tokens  Author-Tokens Publisher-Tokens
# 473    Penguin USA  [skin, lion]  [m, ondaatje]   [Penguin, USA]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 6.54
#
# Choosen book:               ISBN                                         Book-Title  \
# 21369  0060086661  Lily Dale: The True Story of the Town that tal...
#
#       Book-Author Year-Of-Publication      Book-Publisher  \
# 21369    c wicker                2003  HarperSanFrancisco
#
#                                       Title-Tokens Author-Tokens  \
# 21369  [lily, dale, true, story, town, talk, dead]   [c, wicker]
#
#            Publisher-Tokens
# 21369  [HarperSanFrancisco]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 4.41
#
# Choosen book:               ISBN             Book-Title  Book-Author Year-Of-Publication  \
# 22311  0743220102  Wrong Rooms: A Memoir  m sanderson                2003
#
#                           Book-Publisher           Title-Tokens  \
# 22311  Simon & Schuster (Trade Division)  [wrong, room, memoir]
#
#         Author-Tokens                             Publisher-Tokens
# 22311  [m, sanderson]  [Simon, &, Schuster, (, Trade, Division, )]
#
# Preprocessed data finished
#
# Vectorized data finished
#
# Find Similarity finished
#
#
# Predicted Rating: 5.76
# R-squared: -4.46
# Mean Squared Error: 5.03
# Root Mean Squared Error: 2.24
# Mean Absolute Error: 1.94
